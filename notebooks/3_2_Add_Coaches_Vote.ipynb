# %%
import pandas as pd
import json

# %%
with open('../data/raw/AFLCA_votes.json', 'r') as f:
    AFLCA_votes_dict = json.load(f)

# %%
errors = 0

for year in AFLCA_votes_dict:
    for round in AFLCA_votes_dict[year]:
        for game in AFLCA_votes_dict[year][round]:

            teams_list = game.split(' ')
            team1 = teams_list[0]
            team2 = teams_list[1]
            try:
                data = pd.read_csv(f'../data/curated/OriginalData_AddDerived/{year} Round {round} {team1} v {team2} (O).csv')
            except:
                data = pd.read_csv(f'../data/curated/OriginalData_AddDerived/{year} Round {round} {team2} v {team1} (O).csv')
                print('Teams reversed')
                print(year, round, game)
                print(votes_data)

            votes_data = AFLCA_votes_dict[year][round][game]

            AFLCA_votes = list()
            for player in data['Player']:
                if player.lower() in votes_data:
                    AFLCA_votes.append(votes_data[player.lower()])
                else:
                    AFLCA_votes.append(0)

            if sum(AFLCA_votes) != 30: # validation
                print('Did not sum up to 30:', sum(AFLCA_votes))
                print(year, round, game)
                print(votes_data, '\n')

                errors += 1

            data['AFLCA_votes'] = AFLCA_votes

            data.to_csv(f'../data/curated/AFLCAVotes/{year} Round {round} {team1} v {team2} (O).csv', index = False)

print(errors)
# Out:
# Did not sum up to 30: 29
# 2015 3 WestCoast Fremantle
# {'lachie neale': 10, 'stephen hill': 8, 'danyle pearce': 5, 'nathan fyfe': 3, 'luke mcpharlin': 2, 'zac clarke': 1, 'garrick ibbotson': 1}
#
# Did not sum up to 30: 28
# 2015 4 Geelong NorthMelbourne
# {'todd goldstein': 10, 'ben cunnington': 4, 'jed bews': 4, 'robbie tarrant': 4, 'joel selwood': 3, 'sam wright': 2, 'jack ziebell': 2, 'jared rivers': 1}
#
# Did not sum up to 30: 28
# 2015 5 Sydney WesternBulldogs
# {'liam picken': 9, 'daniel hannebery': 8, 'robert murphy': 7, 'michael pyke': 2, 'marcus bontempelli': 2, 'easton wood': 1, 'luke dahlhaus': 1}
#
# Did not sum up to 30: 29
# 2015 7 Hawthorn Melbourne
# {'sam mitchell': 7, 'liam shiels': 7, 'jarryd roughead': 5, 'cyril rioli': 5, 'bradley hill': 2, 'shaun burgoyne': 2, 'will langford': 1, 'billy hartung': 1}
#
# Did not sum up to 30: 28
# 2015 13 Carlton GoldCoast
# {'tom bell': 10, 'marc murphy': 8, 'zach tuohy': 6, 'andrew carrazzo': 3, 'chris yarran': 2, 'tom lynch': 1}
#
# Did not sum up to 30: 34
# 2015 17 Adelaide GoldCoast
# {'patrick dangerfield': 9, 'charlie cameron': 6, 'scott thompson': 5, 'tom lynch': 4, 'harley bennell': 3, 'rory laird': 3}
#
# Did not sum up to 30: 29
# 2015 17 Essendon PortAdelaide
# {'travis boak': 10, 'cale hooker': 7, 'chad wingard': 6, 'robbie gray': 3, 'oliver wines': 2, 'brendon goddard': 1, "nick o'brien": 1}
#
# Did not sum up to 30: 21
# 2015 21 Collingwood Richmond
# {'ty vickery': 9, 'dustin martin': 6, 'alex rance': 5, 'brandon ellis': 4, 'ivan maric': 3, 'taylor hunt': 2, 'bachar houli': 1}
#
# Did not sum up to 30: 32
# 2016 1 NorthMelbourne Adelaide
# {'todd goldstein': 6, 'josh jenkins': 6, 'ben cunnington': 5, 'jack ziebell': 5, 'robbie tarrant': 4, 'jarrad waite': 2, 'scott thompson': 2}
#
# Did not sum up to 30: 23
# 2016 8 Richmond Sydney
# {'dustin martin': 8, 'ben griffiths': 7, 'anthony miles': 6, 'daniel hannebery': 6, 'lance franklin': 3}
#
# Did not sum up to 30: 38
# 2016 9 GoldCoast Adelaide
# {'tom lynch': 8, 'taylor walker': 7, 'rory sloane': 6, 'brodie smith': 4, 'daniel talia': 4, 'rory atkins': 1}
#
# Did not sum up to 30: 34
# 2016 14 Adelaide NorthMelbourne
# {'matt crouch': 9, 'rory sloane': 9, 'scott thompson': 4, 'tom lynch': 3, 'ben cunnington': 2, 'jake lever': 2, 'daniel talia': 1}
#
# Did not sum up to 30: 23
# 2016 17 Richmond Essendon
# {'dustin martin': 10, 'ben griffiths': 7, 'zachary merrett': 7, 'trent cotchin': 4, 'orazio fantasia': 1, 'brendon goddard': 1}
#
# Did not sum up to 30: 29
# 2016 20 Fremantle WestCoast
# {'joshua kennedy': 10, 'chris masten': 4, 'luke shuey': 4, 'mark lecras': 3, 'shannon hurn': 3, 'stephen hill': 2, 'matthew priddis': 2, 'jeremy mcgovern': 1, 'tommy sheridan': 1}
#
# Did not sum up to 30: 27
# 2017 9 Melbourne NorthMelbourne
# {'ben brown': 10, 'ben cunnington': 8, 'scott thompson': 4, 'todd goldstein': 3, 'mitch hannan': 3, 'michael hibberd': 2}
#
# Did not sum up to 30: 27
# 2017 14 Brisbane GWS
# {'dylan shiel': 9, 'jonathon patton': 9, 'jeremy cameron': 6, 'sam reid': 3, 'lachie whitfield': 2, 'tom rockliff': 1}
#
# Did not sum up to 30: 26
# 2017 15 Fremantle StKilda
# {'michael walters': 10, 'sebastian ross': 6, 'nick suban': 4, 'jack billings': 4, 'jake carlisle': 3, 'jade gresham': 2, 'tim membrey': 1}
#
# Did not sum up to 30: 35
# 2018 6 Adelaide GoldCoast
# {'wayne milera': 10, 'tom lynch': 5, 'david swallow': 5, 'daniel talia': 4, 'matt crouch': 4, 'richard douglas': 1, 'rory atkins': 1}
#
# Did not sum up to 30: 29
# 2018 7 Sydney NorthMelbourne
# {'shaun higgins': 9, 'mason wood': 9, 'josh p. kennedy': 4, 'callum sinclair': 3, 'ben jacobs': 2, 'heath grundy': 2, 'ed vickers-willis': 1}
#
# Did not sum up to 30: 29
# 2018 17 Hawthorn Brisbane
# {'hugh mccluggage': 7, 'dayne beams': 7, 'stefan martin': 5, "jaeger o'meara": 5, 'joshua walker': 5, 'nick robertson': 1}
#
# Did not sum up to 30: 28
# 2018 22 WestCoast Melbourne
# {'max gawn': 10, 'jake melksham': 8, 'james harmes': 6, 'angus brayshaw': 2, 'mitch hannan': 2, 'elliot yeo': 1, 'willie rioli': 1}
#
# Did not sum up to 30: 29
# 2019 8 Carlton Collingwood
# {'patrick cripps': 10, 'brodie grundy': 7, 'tom phillips': 5, 'steele sidebottom': 4, 'jordan de goey': 2, 'caleb marchbank': 1, 'callum l brown': 1}
#
# Did not sum up to 30: 29
# 2019 11 GWS GoldCoast
# {'stephen coniglio': 10, 'joshua kelly': 7, 'jeremy cameron': 7, 'jacob hopper': 4, 'sam reid': 1, 'nicholas holman': 1}
#
# Did not sum up to 30: 29
# 2020 18 Essendon Melbourne
# {'christian petracca': 10, 'bayley fritsch': 8, 'zachary merrett': 4, 'max gawn': 3, 'steven may': 2, 'jayden hunt': 2, 'mitch w brown': 1}
#
# Did not sum up to 30: 28
# 2021 3 Carlton Fremantle
# {'harry mckay': 9, 'liam jones': 8, 'sam walsh': 6, 'patrick cripps': 5, 'lachie fogarty': 2}
#
# Did not sum up to 30: 27
# 2022 10 WesternBulldogs GoldCoast
# {'bailey smith': 8, 'ed richards': 6, 'marcus bontempelli': 5, 'jackson macrae': 3, 'joel s-jeffrey': 3, 'david swallow': 2, 'bailey williams': 2, 'aaron naughton': 1}
#
# Did not sum up to 30: 31
# 2022 11 WestCoast WesternBulldogs
# {'timothy english': 10, 'adam treloar': 6, 'tim kelly': 5, 'josh dunkley': 4, 'bailey dale': 3, 'jackson macrae': 1, 'bailey williams': 1}
#
# 27
