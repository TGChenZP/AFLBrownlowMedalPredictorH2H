# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'RFR'
TUNING_MODEL = 'guanganb'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import GuangAnB_H2H

# %%
guangan = GuangAnB_H2H.GuangAnB()
# Out:
# GuangAn Initialised

# %%
from sklearn.ensemble import RandomForestRegressor as RFR

# %%
guangan.read_in_model(RFR, 'Regression')
# Out:
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestRegressor'>, which is a Regression model

# %%
guangan.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': set(range(25, 401)),
    'max_depth': set(range(3, 193)),
    'max_samples': (0.4, 0.85),
    'max_features': (0.4, 0.85),
    'ccp_alpha': (-8, -1)
}

# %%
guangan.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
guangan.read_in_transform({'ccp_alpha': '10^'})
# Out:
# Updated transform dictionary: {'n_estimators': False, 'max_depth': False, 'max_samples': False, 'max_features': False, 'ccp_alpha': '10^'}

# %%
guangan.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
guangan.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  guangan.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv', f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 2249 rows
# True

# %%
guangan.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
guangan.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
guangan.train_other_info = train_other_info
guangan.val_other_info = val_other_info
guangan.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
guangan.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5975
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.63
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6478
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6059
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5964
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.7375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.7375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.7375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.7375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.7375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.5818
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.7375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.5891
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.7375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.5818
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.7375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5891
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.5954
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.5891
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.5954
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5891
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.7375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6205
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.7375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.5954
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.7375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6048
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.7375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5901
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.7375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6226
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.7375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6279
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.7375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6006
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.7375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5964
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6426
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6405
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6038
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.586
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 190, 'max_depth': 15, 'max_samples': 0.765625, 'max_features': 0.7093750000000001, 'ccp_alpha': -4.9375, 'features': 33}, which had val score of 0.5975
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6048
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6048
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.5964
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.5964
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6184
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6122
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6184
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6122
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6216
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6226
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6048
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6279
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6426
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6164
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6226
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6205
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.5943
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.5943
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6164
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6164
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6027
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6027
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6226
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6027
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6258
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6027
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6247
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6426
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.608
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.608
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6226
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 27}, which had val score of 0.6027
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 27}, which had val score of 0.6153
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6237
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 190, 'max_depth': 15, 'max_samples': 0.8218749999999999, 'max_features': 0.653125, 'ccp_alpha': -5.8125, 'features': 29}, which had val score of 0.6059
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6132
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6122
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6122
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6048
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6205
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6279
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6426
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6111
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6216
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6164
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.608
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6174
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6205
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6237
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -6.25, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 3, 'max_samples': 0.85, 'max_features': 0.625, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# ...
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6017
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6258
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5933
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6153
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.5996
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5943
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6247
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6363
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.5985
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5975
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6342
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6289
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6059
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 166, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5954
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6426
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6101
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6405
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6038
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.586
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6237
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.5996
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.6048
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6143
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6279
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.5996
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 27, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5901
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6164
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6069
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5985
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6195
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6184
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.5996
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.79375, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5943
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6321
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6153
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.6006
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.68125, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5943
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 31}, which had val score of 0.6237
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -5.375, 'features': 35}, which had val score of 0.6268
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 31}, which had val score of 0.5996
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 51, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -4.5, 'features': 35}, which had val score of 0.5891
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# Already Trained and Tested combination {'n_estimators': 190, 'max_depth': 39, 'max_samples': 0.8218749999999999, 'max_features': 0.7093750000000001, 'ccp_alpha': -4.9375, 'features': 33}, which had val score of 0.6405
#         Current best combo: (119, 98, 0.85, 0.7375, -8.0, 35) with val score 0.6488.
#         Has trained 2249 combinations so far
# TUNING FINISHED

# %%
guangan.view_best_combo_and_score()
# Out:
# Max Score:
#  0.6488469601677149
# Max Test Score:
#  0.648847
# Max Combo Index:
#  (119, 98, 0.85, 0.7375, -8.0, 35)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 119, 'max_depth': 98, 'max_samples': 0.85, 'max_features': 0.7375, 'ccp_alpha': -8.0, 'features': 35}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances', 'Tackles Inside 50', 'Rebound 50s', 'One Percenters', 'Goal Assists', 'Uncontested Possessions', 'Frees Agains', 'Inside 50s', 'Frees For', 'Metres Gained', 'Score Involvements', 'Behind Assists', 'Tackles Outside 50', 'Tackles', 'Clangers', 'Uncontested Marks', 'Marks Outside 50', 'Kicks', 'Turnovers', 'Marks', 'Time On Ground %', 'Effective Disposals', 'HomeAway', 'Winloss')
# # Combos Checked: 2249
