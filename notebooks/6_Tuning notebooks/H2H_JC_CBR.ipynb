# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'CBR'
TUNING_MODEL = 'jiaocheng'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import JiaoCheng_H2H

# %%
jiaocheng = JiaoCheng_H2H.JiaoCheng()
# Out:
# JiaoCheng Initialised

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.2)
# Installing collected packages: catboost
# Successfully installed catboost-1.2

# %%
from catboost import CatBoostRegressor as CBR

# %%
jiaocheng.read_in_model(CBR, 'Regression')
# Out:
# Successfully read in model <class 'catboost.core.CatBoostRegressor'>, which is a Regression model

# %%
jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {

    'n_estimators': (25, 50, 100, 200, 400),
    'max_depth': (2, 4, 8, 16),
    'subsample': (0.4, 0.55, 0.7, 0.85),
    'colsample_bylevel': (0.4, 0.55, 0.7, 0.85),
    'max_bin': (64, 256),
    'reg_lambda': (0.0001, 0.001, 0.01, 0.1, 1),
    'learning_rate': (0.001, 0.01, 0.1, 1, 10),

}

# %%
jiaocheng.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'verbose': False})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
jiaocheng.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
jiaocheng.set_tuning_order(['features', 'max_depth', 'max_bin', 'colsample_bylevel', 'subsample', 'n_estimators', 'reg_lambda', 'learning_rate'])

# %%
jiaocheng.set_hyperparameter_default_values({
    'features': 0,
    'n_estimators': 50,
    'max_depth': 16,
    'subsample': 0.7,
    'colsample_bylevel': 0.7,
    'max_bin': 256,
    'reg_lambda': 0.01,
    'learning_rate': 0.1,}
  )

# %%
try:
  jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 58 rows
# True

# %%
jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
jiaocheng.train_other_info = train_other_info
jiaocheng.val_other_info = val_other_info
jiaocheng.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
jiaocheng.tune()
# Out:
# Default combo: [1, 3, 2, 2, 1, 2, 2, 0]
#
#
# ROUND 1
#
# Round 2
# Hyperparameter: features (index: 7)
#
# As new Best Combo (1, 3, 2, 2, 1, 2, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 0), which had val score of 0.5828
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 0) with val score 0.5828.
#         Has trained 58 of 576000 combinations so far
# As new Best Combo (1, 3, 2, 2, 1, 2, 2, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 1), which had val score of 0.5933
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 1) with val score 0.5933.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 2), which had val score of 0.5901
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 1) with val score 0.5933.
#         Has trained 58 of 576000 combinations so far
# As new Best Combo (1, 3, 2, 2, 1, 2, 2, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 3), which had val score of 0.5943
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 3) with val score 0.5943.
#         Has trained 58 of 576000 combinations so far
# As new Best Combo (1, 3, 2, 2, 1, 2, 2, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 4), which had val score of 0.6006
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 4) with val score 0.6006.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 5), which had val score of 0.5985
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 4) with val score 0.6006.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 6), which had val score of 0.5996
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 4) with val score 0.6006.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 7), which had val score of 0.5828
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 4) with val score 0.6006.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 8), which had val score of 0.5891
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 4) with val score 0.6006.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 9), which had val score of 0.5566
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 4) with val score 0.6006.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 10), which had val score of 0.5818
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 4) with val score 0.6006.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 11), which had val score of 0.5901
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 4) with val score 0.6006.
#         Has trained 58 of 576000 combinations so far
# As new Best Combo (1, 3, 2, 2, 1, 2, 2, 12) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 12), which had val score of 0.6017
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 12) with val score 0.6017.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 13), which had val score of 0.5828
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 12) with val score 0.6017.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 14), which had val score of 0.5755
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 12) with val score 0.6017.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 15), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 12) with val score 0.6017.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 16), which had val score of 0.5713
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 12) with val score 0.6017.
#         Has trained 58 of 576000 combinations so far
# As new Best Combo (1, 3, 2, 2, 1, 2, 2, 17) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 17), which had val score of 0.6059
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 17) with val score 0.6059.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 18), which had val score of 0.5891
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 17) with val score 0.6059.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 19), which had val score of 0.5681
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 17) with val score 0.6059.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 20), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 17) with val score 0.6059.
#         Has trained 58 of 576000 combinations so far
# As new Best Combo (1, 3, 2, 2, 1, 2, 2, 21) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 22), which had val score of 0.5964
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 23), which had val score of 0.5797
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 24), which had val score of 0.5922
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 25), which had val score of 0.5744
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 26), which had val score of 0.5964
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 27), which had val score of 0.5713
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 28), which had val score of 0.5755
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 29), which had val score of 0.5818
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 30), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 31), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 32), which had val score of 0.5692
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 33), which had val score of 0.5723
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 34), which had val score of 0.587
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 35), which had val score of 0.586
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 1, 2, 2, 21), which had val score of 0.5807
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 2, 2, 21), which had val score of 0.5639
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 2, 2, 21), which had val score of 0.5818
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_bin (index: 4)
#
# Already Trained and Tested combination (1, 3, 2, 2, 0, 2, 2, 21), which had val score of 0.5922
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (1, 3, 2, 0, 1, 2, 2, 21), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 1, 1, 2, 2, 21), which had val score of 0.566
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 1, 2, 2, 21), which had val score of 0.586
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 3, 0, 2, 1, 2, 2, 21), which had val score of 0.5933
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 1, 2, 1, 2, 2, 21), which had val score of 0.5744
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 3, 2, 1, 2, 2, 21), which had val score of 0.5849
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.5849
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.5818
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_lambda (index: 5)
#
# Already Trained and Tested combination (1, 3, 2, 2, 1, 0, 2, 21), which had val score of 0.5996
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 1, 2, 21), which had val score of 0.5996
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 3, 2, 21), which had val score of 0.5901
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 4, 2, 21), which had val score of 0.5744
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 6)
#
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 0, 21), which had val score of 0.5765
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 1, 21), which had val score of 0.5828
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 3, 21), which had val score of 0.5451
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 4, 21), which had val score of 0.0
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 3
# Hyperparameter: features (index: 7)
#
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 0), which had val score of 0.5828
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 1), which had val score of 0.5933
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 2), which had val score of 0.5901
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 3), which had val score of 0.5943
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 4), which had val score of 0.6006
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 5), which had val score of 0.5985
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 6), which had val score of 0.5996
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 7), which had val score of 0.5828
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 8), which had val score of 0.5891
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 9), which had val score of 0.5566
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 10), which had val score of 0.5818
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 11), which had val score of 0.5901
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 12), which had val score of 0.6017
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 13), which had val score of 0.5828
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 14), which had val score of 0.5755
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 15), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 16), which had val score of 0.5713
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 17), which had val score of 0.6059
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 18), which had val score of 0.5891
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 19), which had val score of 0.5681
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 20), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 22), which had val score of 0.5964
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 23), which had val score of 0.5797
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 24), which had val score of 0.5922
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 25), which had val score of 0.5744
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 26), which had val score of 0.5964
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 27), which had val score of 0.5713
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 28), which had val score of 0.5755
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 29), which had val score of 0.5818
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 30), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 31), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 32), which had val score of 0.5692
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 33), which had val score of 0.5723
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 34), which had val score of 0.587
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 35), which had val score of 0.586
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 1, 2, 2, 21), which had val score of 0.5807
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 2, 2, 21), which had val score of 0.5639
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 2, 2, 21), which had val score of 0.5818
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_bin (index: 4)
#
# Already Trained and Tested combination (1, 3, 2, 2, 0, 2, 2, 21), which had val score of 0.5922
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (1, 3, 2, 0, 1, 2, 2, 21), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 1, 1, 2, 2, 21), which had val score of 0.566
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 1, 2, 2, 21), which had val score of 0.586
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 3, 0, 2, 1, 2, 2, 21), which had val score of 0.5933
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 1, 2, 1, 2, 2, 21), which had val score of 0.5744
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 3, 2, 1, 2, 2, 21), which had val score of 0.5849
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.5849
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.5839
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.5818
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: reg_lambda (index: 5)
#
# Already Trained and Tested combination (1, 3, 2, 2, 1, 0, 2, 21), which had val score of 0.5996
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 1, 2, 21), which had val score of 0.5996
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 3, 2, 21), which had val score of 0.5901
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 4, 2, 21), which had val score of 0.5744
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate (index: 6)
#
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 0, 21), which had val score of 0.5765
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 1, 21), which had val score of 0.5828
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 2, 21), which had val score of 0.6153
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 3, 21), which had val score of 0.5451
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 2, 4, 21), which had val score of 0.0
#         Current best combo: (1, 3, 2, 2, 1, 2, 2, 21) with val score 0.6153.
#         Has trained 58 of 576000 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 1, 2, 2, 21) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.615304
# Max Test Score:
#  0.615304
# Max Combo Index:
#  (1, 3, 2, 2, 1, 2, 2, 21) out of [5, 4, 4, 4, 2, 5, 5, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 16, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'max_bin': 256, 'reg_lambda': 0.01, 'learning_rate': 0.1, 'features': 21}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances', 'Tackles Inside 50', 'Rebound 50s', 'One Percenters', 'Goal Assists', 'Uncontested Possessions', 'Frees Agains', 'Inside 50s', 'Frees For', 'Metres Gained')
# % Combos Checked: 58 out of 576000 which is 0.010069%

# %%
jiaocheng.view_best_combo_and_score()
# Out:
# Max Score:
#  0.615304
# Max Test Score:
#  0.615304
# Max Combo Index:
#  (1, 3, 2, 2, 1, 2, 2, 21) out of [5, 4, 4, 4, 2, 5, 5, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 16, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'max_bin': 256, 'reg_lambda': 0.01, 'learning_rate': 0.1, 'features': 21}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances', 'Tackles Inside 50', 'Rebound 50s', 'One Percenters', 'Goal Assists', 'Uncontested Possessions', 'Frees Agains', 'Inside 50s', 'Frees For', 'Metres Gained')
# % Combos Checked: 58 out of 576000 which is 0.010069%
