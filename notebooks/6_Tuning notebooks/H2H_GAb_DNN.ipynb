# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'DNN'
TUNING_MODEL = 'guangan'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import GuangAnB_H2H

# %%
guangan = GuangAnB_H2H.GuangAnB()
# Out:
# GuangAn Initialised

# %%
from models.DenseNeuralNetwork import DNN_shrink_sk as DNN

# %%
guangan.read_in_model(DNN, 'Regression')
# Out:
# Successfully read in model <class 'models.DenseNeuralNetwork.DNN_shrink_sk'>, which is a Regression model

# %%
guangan.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_hidden_layers': {1, 2, 3, 4, 5},
    'alpha': (-8, -1),
    'learning_rate_init': (-4, -1),
    'activation': ('relu', 'logistic')

}

# %%
guangan.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
guangan.read_in_transform({'learning_rate_init': '10^', 'alpha': '10^'})
# Out:
# Updated transform dictionary: {'n_hidden_layers': False, 'alpha': '10^', 'learning_rate_init': '10^', 'activation': False}

# %%
guangan.read_in_categorical(['activation'])
# Out:
# Updated categorical dictionary: {'n_hidden_layers': False, 'alpha': False, 'learning_rate_init': False, 'activation': True}
# Updated original bounds dict: [({1, 2, 3, 4, 5}, 'n_hidden_layers'), ((-8, -1), 'alpha'), ((-4, -1), 'learning_rate_init'), ({'values': ('logistic', 'relu')}, 'activation')]

# %%
guangan.set_non_tuneable_hyperparameters({'random_state': 19260817, 'max_iter': 1000, 'learning_rate': 'adaptive', 'batch_size': 'auto'})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
guangan.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  guangan.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv', f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 475 rows
# True

# %%
guangan.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
guangan.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
guangan.train_other_info = train_other_info
guangan.val_other_info = val_other_info
guangan.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
guangan.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5765
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.566
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5252
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.586
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5922
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 2, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 27}, which had val score of 0.5377
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5828
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5524
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5828
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5901
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5398
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5702
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5723
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5692
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 2, 'alpha': -6.25, 'learning_rate_init': -1.75, 'activation': 'logistic', 'features': 9}, which had val score of 0.5744
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5283
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5524
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 35}, which had val score of 0.5765
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5252
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5901
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 35}, which had val score of 0.5818
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.586
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5702
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 35}, which had val score of 0.5702
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5922
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5692
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 35}, which had val score of 0.5629
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 2, 'alpha': -6.25, 'learning_rate_init': -1.75, 'activation': 'logistic', 'features': 27}, which had val score of 0.5786
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5765
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5828
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5618
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5776
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5839
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5849
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5786
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5639
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 2, 'alpha': -2.75, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5881
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5765
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.566
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5252
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5618
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.5755
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5839
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5849
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5922
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5849
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.5776
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5639
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5765
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 2, 'alpha': -2.75, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 27}, which had val score of 0.5577
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5828
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5901
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5776
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5839
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5723
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.521
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5723
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5692
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5786
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5639
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5786
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.565
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 2, 'alpha': -2.75, 'learning_rate_init': -1.75, 'activation': 'logistic', 'features': 9}, which had val score of 0.5618
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5252
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5901
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 35}, which had val score of 0.5818
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5839
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5849
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.521
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 1, 'alpha': -1, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 35}, which had val score of 0.543
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5922
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5692
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 35}, which had val score of 0.5629
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5639
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5765
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.565
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -1, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 35}, which had val score of 0.5514
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 2, 'alpha': -2.75, 'learning_rate_init': -1.75, 'activation': 'logistic', 'features': 27}, which had val score of 0.5734
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5566
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5639
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5482
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5566
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5639
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5545
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.587
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.586
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.5472
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5922
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5566
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.6006
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5482
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.5765
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 18}, which had val score of 0.5566
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -4, 'activation': 'logistic', 'features': 35}, which had val score of 0.5985
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5545
#         Current best combo: (5, -8, -4, 'logistic', 35) with val score 0.6006.
#         Has trained 475 combinations so far
# As new Best Combo (5, -4.5, -2.5, 'logistic', 35) was read in, best_clf is set to None
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 35}, which had val score of 0.6132
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 27}, which had val score of 0.5587
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5587
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5472
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5398
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -8, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5702
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5587
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 0}, which had val score of 0.5723
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -4.5, 'learning_rate_init': -1, 'activation': 'logistic', 'features': 18}, which had val score of 0.5692
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5639
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -8, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5482
#         Current best combo: (5, -4.5, -2.5, 'logistic', 35) with val score 0.6132.
#         Has trained 475 combinations so far
# ...
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 531 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -4.0, 'activation': 'logistic', 'features': 9}, which had val score of 0.5881
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 531 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -4.0, 'activation': 'logistic', 'features': 18}, which had val score of 0.5566
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 531 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 531 combinations so far
# Trained and Tested combination 532: {'n_hidden_layers': [5], 'alpha': [3.1622776601683795e-05], 'learning_rate_init': [0.0005623413251903491], 'activation': ['logistic'], 'features': [18]}, taking 399.52 seconds to get val score of 0.5671
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -5.375, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 14}, which had val score of 0.5734
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 532 combinations so far
# Trained and Tested combination 533: {'n_hidden_layers': [5], 'alpha': [4.216965034285822e-06], 'learning_rate_init': [0.00023713737056616554], 'activation': ['logistic'], 'features': [14]}, taking 131.84 seconds to get val score of 0.5702
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.587
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5734
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 9}, which had val score of 0.5608
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.587
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5734
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 9}, which had val score of 0.5671
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5639
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 9}, which had val score of 0.5587
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 0}, which had val score of 0.5639
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 533 combinations so far
# Trained and Tested combination 534: {'n_hidden_layers': [5], 'alpha': [3.1622776601683795e-05], 'learning_rate_init': [0.0031622776601683794], 'activation': ['logistic'], 'features': [9]}, taking 245.24 seconds to get val score of 0.5618
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -5.375, 'learning_rate_init': -2.875, 'activation': 'logistic', 'features': 5}, which had val score of 0.6017
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 534 combinations so far
# Trained and Tested combination 535: {'n_hidden_layers': [5], 'alpha': [4.216965034285822e-06], 'learning_rate_init': [0.001333521432163324], 'activation': ['logistic'], 'features': [5]}, taking 81.95 seconds to get val score of 0.5954
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.587
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 18}, which had val score of 0.5681
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 9}, which had val score of 0.5608
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5786
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.587
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 18}, which had val score of 0.5734
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 9}, which had val score of 0.5671
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5618
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 18}, which had val score of 0.5566
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 9}, which had val score of 0.5587
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5367
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 18}, which had val score of 0.5671
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 9}, which had val score of 0.5618
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -2.5, 'activation': 'logistic', 'features': 18}, which had val score of 0.5545
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -5.375, 'learning_rate_init': -2.875, 'activation': 'logistic', 'features': 14}, which had val score of 0.5639
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 535 combinations so far
# Trained and Tested combination 536: {'n_hidden_layers': [5], 'alpha': [4.216965034285822e-06], 'learning_rate_init': [0.001333521432163324], 'activation': ['logistic'], 'features': [14]}, taking 352.67 seconds to get val score of 0.5692
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205
# Begin Cruise
# Cruise Round
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -8.0, 'learning_rate_init': -4.0, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -8.0, 'learning_rate_init': -4.0, 'activation': 'logistic', 'features': 9}, which had val score of 0.5797
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -8.0, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -8.0, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.587
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -4.0, 'activation': 'logistic', 'features': 0}, which had val score of 0.5681
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -4.0, 'activation': 'logistic', 'features': 9}, which had val score of 0.5797
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 0}, which had val score of 0.5744
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.587
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 4, 'alpha': -7.125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}, which had val score of 0.5985
#         Current best combo: (5, -8.0, -1.75, 'logistic', 35) with val score 0.6205.
#         Has trained 536 combinations so far
# TUNING FINISHED

# %%
guangan.view_best_combo_and_score()
# Out:
# Max Score:
#  0.6205450733752621
# Max Test Score:
#  0.620545
# Max Combo Index:
#  (5, -8.0, -1.75, 'logistic', 35)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 5, 'alpha': -8.0, 'learning_rate_init': -1.75, 'activation': 'logistic', 'features': 35}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances', 'Tackles Inside 50', 'Rebound 50s', 'One Percenters', 'Goal Assists', 'Uncontested Possessions', 'Frees Agains', 'Inside 50s', 'Frees For', 'Metres Gained', 'Score Involvements', 'Behind Assists', 'Tackles Outside 50', 'Tackles', 'Clangers', 'Uncontested Marks', 'Marks Outside 50', 'Kicks', 'Turnovers', 'Marks', 'Time On Ground %', 'Effective Disposals', 'HomeAway', 'Winloss')
# # Combos Checked: 536
