# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'ELR'
TUNING_MODEL = 'jiaocheng'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import JiaoCheng_H2H

# %%
jiaocheng = JiaoCheng_H2H.JiaoCheng()
# Out:
# JiaoCheng Initialised

# %%
from models.EnsembleLinearRegression import Ensemble_Lasso as ELR

# %%
jiaocheng.read_in_model(ELR, 'Regression')
# Out:
# Successfully read in model <class 'models.EnsembleLinearRegression.Ensemble_Lasso'>, which is a Regression model

# %%
jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'alpha': (0.0001, 0.01, 1, 10, 100),
    'ensemble_n_estimators': (25, 50, 100, 200, 400),
    'ensemble_max_features': (0.4, 0.55, 0.7, 0.85),
    'ensemble_max_samples': (0.4, 0.55, 0.7, 0.85),
    'ensemble_weighted': (True, False)
}

# %%
jiaocheng.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
jiaocheng.hyperparameters
# Out:
# ['alpha',
#  'ensemble_n_estimators',
#  'ensemble_max_features',
#  'ensemble_max_samples',
#  'ensemble_weighted']

# %%
jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
jiaocheng.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
jiaocheng.set_tuning_order(['features', 'ensemble_n_estimators', 'ensemble_max_features', 'ensemble_max_samples', 'alpha', 'ensemble_weighted'])

# %%
jiaocheng.set_hyperparameter_default_values({
    'features': 0,
    'ensemble_n_estimators': 50,
    'ensemble_max_features': 0.7,
    'ensemble_max_samples': 0.7,
    'alpha': 0.01,
    'ensemble_weighted': True}
  )

# %%
try:
  jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 90 rows
# True

# %%
jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
jiaocheng.train_other_info = train_other_info
jiaocheng.val_other_info = val_other_info
jiaocheng.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
jiaocheng.tune()
# Out:
# Default combo: [1, 1, 2, 2, 1, 0]
#
#
# ROUND 1
#
# Round 2
# Hyperparameter: features (index: 5)
#
# As new Best Combo (1, 1, 2, 2, 1, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 1, 0), which had val score of 0.5755
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 1), which had val score of 0.5535
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 2), which had val score of 0.5723
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 3), which had val score of 0.566
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 4), which had val score of 0.565
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 5), which had val score of 0.5681
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 6), which had val score of 0.5713
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 7), which had val score of 0.5681
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 8), which had val score of 0.5713
#         Current best combo: (1, 1, 2, 2, 1, 0) with val score 0.5755.
#         Has trained 90 of 28800 combinations so far
# As new Best Combo (1, 1, 2, 2, 1, 9) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 1, 9), which had val score of 0.5776
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 10), which had val score of 0.5681
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 11), which had val score of 0.5776
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 12), which had val score of 0.5713
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 13), which had val score of 0.5713
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 14), which had val score of 0.5713
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 15), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 16), which had val score of 0.5671
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 17), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 18), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 19), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 20), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 21), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 22), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 23), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 24), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 25), which had val score of 0.5702
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 26), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 27), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 28), which had val score of 0.5702
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 29), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 30), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 31), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 32), which had val score of 0.5734
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 33), which had val score of 0.5702
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 34), which had val score of 0.5702
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 35), which had val score of 0.5744
#         Current best combo: (1, 1, 2, 2, 1, 9) with val score 0.5776.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 1, 9) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ensemble_n_estimators (index: 1)
#
# As new Best Combo (1, 0, 2, 2, 1, 9) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 2, 2, 1, 9), which had val score of 0.5797
#         Current best combo: (1, 0, 2, 2, 1, 9) with val score 0.5797.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 9), which had val score of 0.5776
#         Current best combo: (1, 0, 2, 2, 1, 9) with val score 0.5797.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 9), which had val score of 0.5713
#         Current best combo: (1, 0, 2, 2, 1, 9) with val score 0.5797.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 9), which had val score of 0.5681
#         Current best combo: (1, 0, 2, 2, 1, 9) with val score 0.5797.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 1, 9), which had val score of 0.5681
#         Current best combo: (1, 0, 2, 2, 1, 9) with val score 0.5797.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 1, 9) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ensemble_max_features (index: 2)
#
# As new Best Combo (1, 0, 0, 2, 1, 9) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 1, 2, 1, 9), which had val score of 0.5891
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 1, 9), which had val score of 0.5797
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 3, 2, 1, 9), which had val score of 0.5713
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ensemble_max_samples (index: 3)
#
# Already Trained and Tested combination (1, 0, 0, 0, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 1, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 3, 1, 9), which had val score of 0.5975
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 0, 0, 2, 1, 9), which had val score of 0.5975
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (2, 0, 0, 2, 1, 9), which had val score of 0.5577
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (3, 0, 0, 2, 1, 9), which had val score of 0.2117
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (4, 0, 0, 2, 1, 9), which had val score of 0.2117
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ensemble_weighted (index: 4)
#
# Already Trained and Tested combination (1, 0, 0, 2, 0, 9), which had val score of 0.544
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 3
# Hyperparameter: features (index: 5)
#
# Already Trained and Tested combination (1, 0, 0, 2, 1, 0), which had val score of 0.565
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 1), which had val score of 0.5597
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 2), which had val score of 0.5723
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 3), which had val score of 0.5755
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 4), which had val score of 0.5671
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 5), which had val score of 0.5692
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 6), which had val score of 0.5681
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 7), which had val score of 0.5755
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 8), which had val score of 0.5692
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 10), which had val score of 0.5828
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 11), which had val score of 0.5912
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 12), which had val score of 0.5922
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 13), which had val score of 0.5828
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 14), which had val score of 0.5786
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 15), which had val score of 0.586
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 16), which had val score of 0.5797
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 17), which had val score of 0.5891
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 18), which had val score of 0.588
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 19), which had val score of 0.586
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 20), which had val score of 0.5839
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 21), which had val score of 0.5996
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 22), which had val score of 0.5765
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 23), which had val score of 0.586
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 24), which had val score of 0.588
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 25), which had val score of 0.5828
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 26), which had val score of 0.5849
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 27), which had val score of 0.5839
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 28), which had val score of 0.5807
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 29), which had val score of 0.5828
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 30), which had val score of 0.5681
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 31), which had val score of 0.5786
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 32), which had val score of 0.5681
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 33), which had val score of 0.588
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 34), which had val score of 0.5849
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 35), which had val score of 0.565
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: ensemble_n_estimators (index: 1)
#
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 1, 0, 2, 1, 9), which had val score of 0.5786
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 2, 0, 2, 1, 9), which had val score of 0.5692
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 3, 0, 2, 1, 9), which had val score of 0.5786
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 4, 0, 2, 1, 9), which had val score of 0.5744
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: ensemble_max_features (index: 2)
#
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 1, 2, 1, 9), which had val score of 0.5891
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 1, 9), which had val score of 0.5797
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 3, 2, 1, 9), which had val score of 0.5713
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: ensemble_max_samples (index: 3)
#
# Already Trained and Tested combination (1, 0, 0, 0, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 1, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 3, 1, 9), which had val score of 0.5975
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 0, 0, 2, 1, 9), which had val score of 0.5975
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (2, 0, 0, 2, 1, 9), which had val score of 0.5577
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (3, 0, 0, 2, 1, 9), which had val score of 0.2117
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (4, 0, 0, 2, 1, 9), which had val score of 0.2117
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: ensemble_weighted (index: 4)
#
# Already Trained and Tested combination (1, 0, 0, 2, 0, 9), which had val score of 0.544
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
# Already Trained and Tested combination (1, 0, 0, 2, 1, 9), which had val score of 0.6006
#         Current best combo: (1, 0, 0, 2, 1, 9) with val score 0.6006.
#         Has trained 90 of 28800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 0, 2, 1, 9) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.600629
# Max Test Score:
#  0.600629
# Max Combo Index:
#  (1, 0, 0, 2, 1, 9) out of [5, 5, 4, 4, 2, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 0.01, 'ensemble_n_estimators': 25, 'ensemble_max_features': 0.4, 'ensemble_max_samples': 0.7, 'ensemble_weighted': True, 'features': 9}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks')
# % Combos Checked: 90 out of 28800 which is 0.3125%

# %%
jiaocheng.view_best_combo_and_score()
# Out:
# Max Score:
#  0.600629
# Max Test Score:
#  0.600629
# Max Combo Index:
#  (1, 0, 0, 2, 1, 9) out of [5, 5, 4, 4, 2, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 0.01, 'ensemble_n_estimators': 25, 'ensemble_max_features': 0.4, 'ensemble_max_samples': 0.7, 'ensemble_weighted': True, 'features': 9}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks')
# % Combos Checked: 90 out of 28800 which is 0.3125%
