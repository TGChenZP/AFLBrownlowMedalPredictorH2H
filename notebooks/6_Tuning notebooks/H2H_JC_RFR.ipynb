# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'RFR'
TUNING_MODEL = 'jiaocheng'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import JiaoCheng_H2H

# %%
jiaocheng = JiaoCheng_H2H.JiaoCheng()
# Out:
# JiaoCheng Initialised

# %%
from sklearn.ensemble import RandomForestRegressor as RFR

# %%
jiaocheng.read_in_model(RFR, 'Regression')
# Out:
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestRegressor'>, which is a Regression model

# %%
jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85),
    'max_features': (0.4, 0.55, 0.7, 0.85),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# %%
jiaocheng.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
jiaocheng.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
jiaocheng.set_tuning_order(['features', 'max_depth', 'max_features', 'max_samples', 'n_estimators', 'ccp_alpha'])

# %%
jiaocheng.set_hyperparameter_default_values({
    'features': 0,
    'n_estimators': 50,
    'max_depth': 12,
    'max_samples': 0.7,
    'max_features': 0.7,
    'ccp_alpha': 0.01})

# %%
try:
  jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 156 rows
# True

# %%
jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
jiaocheng.train_other_info = train_other_info
jiaocheng.val_other_info = val_other_info
jiaocheng.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
jiaocheng.tune()
# Out:
# Default combo: [1, 2, 2, 2, 3, 0]
#
#
# ROUND 1
#
# Round 2
# Hyperparameter: features (index: 5)
#
# As new Best Combo (1, 2, 2, 2, 3, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 3, 0), which had val score of 0.5954
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5954.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 1), which had val score of 0.5922
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5954.
#         Has trained 156 of 100800 combinations so far
# As new Best Combo (1, 2, 2, 2, 3, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 3, 2), which had val score of 0.6027
#         Current best combo: (1, 2, 2, 2, 3, 2) with val score 0.6027.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 3), which had val score of 0.5713
#         Current best combo: (1, 2, 2, 2, 3, 2) with val score 0.6027.
#         Has trained 156 of 100800 combinations so far
# As new Best Combo (1, 2, 2, 2, 3, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 3, 4), which had val score of 0.6038
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 5), which had val score of 0.6038
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 6), which had val score of 0.5901
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 7), which had val score of 0.5818
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 8), which had val score of 0.6006
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 9), which had val score of 0.5681
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 10), which had val score of 0.588
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 11), which had val score of 0.588
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 12), which had val score of 0.5975
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 13), which had val score of 0.5943
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 14), which had val score of 0.588
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 15), which had val score of 0.566
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 16), which had val score of 0.5943
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 17), which had val score of 0.5786
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 18), which had val score of 0.5776
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 19), which had val score of 0.5891
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 20), which had val score of 0.5713
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 21), which had val score of 0.5996
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 22), which had val score of 0.5964
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 23), which had val score of 0.565
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 24), which had val score of 0.5933
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 25), which had val score of 0.5786
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 26), which had val score of 0.586
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 27), which had val score of 0.5912
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 28), which had val score of 0.5996
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 29), which had val score of 0.5713
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 30), which had val score of 0.5849
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 31), which had val score of 0.5755
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 32), which had val score of 0.5618
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 33), which had val score of 0.5901
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 34), which had val score of 0.5849
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 35), which had val score of 0.5776
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 3, 4) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 3, 4), which had val score of 0.5765
#         Current best combo: (1, 2, 2, 2, 3, 4) with val score 0.6038.
#         Has trained 156 of 100800 combinations so far
# As new Best Combo (1, 1, 2, 2, 3, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 3, 4), which had val score of 0.6069
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 4), which had val score of 0.6038
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 3, 4), which had val score of 0.6069
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 3, 4), which had val score of 0.6027
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 5, 2, 2, 3, 4), which had val score of 0.6027
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 6, 2, 2, 3, 4), which had val score of 0.6027
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 3, 4) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_features (index: 3)
#
# Already Trained and Tested combination (1, 1, 2, 0, 3, 4), which had val score of 0.5356
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 1, 3, 4), which had val score of 0.5608
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 3, 4), which had val score of 0.6069
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 3, 3, 4), which had val score of 0.5786
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_samples (index: 2)
#
# Already Trained and Tested combination (1, 1, 0, 2, 3, 4), which had val score of 0.5933
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 1, 1, 2, 3, 4), which had val score of 0.5985
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 3, 4), which had val score of 0.6069
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 1, 3, 2, 3, 4), which had val score of 0.6017
#         Current best combo: (1, 1, 2, 2, 3, 4) with val score 0.6069.
#         Has trained 156 of 100800 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# As new Best Combo (0, 1, 2, 2, 3, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 1, 2, 2, 3, 4), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 3, 4), which had val score of 0.6069
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (2, 1, 2, 2, 3, 4), which had val score of 0.6059
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (3, 1, 2, 2, 3, 4), which had val score of 0.6006
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (4, 1, 2, 2, 3, 4), which had val score of 0.6069
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
#
# Best combo after this hyperparameter: (0, 1, 2, 2, 3, 4) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ccp_alpha (index: 4)
#
# Already Trained and Tested combination (0, 1, 2, 2, 0, 4), which had val score of 0.5723
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 1, 4), which had val score of 0.5723
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 2, 4), which had val score of 0.5723
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 4), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 4, 4), which had val score of 0.5524
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
#
# Best combo after this hyperparameter: (0, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 3
# Hyperparameter: features (index: 5)
#
# Already Trained and Tested combination (0, 1, 2, 2, 3, 0), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 1), which had val score of 0.6017
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 2), which had val score of 0.5985
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 3), which had val score of 0.5776
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 4), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 5), which had val score of 0.5702
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 6), which had val score of 0.5849
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 7), which had val score of 0.5755
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 8), which had val score of 0.6048
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 9), which had val score of 0.5734
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 10), which had val score of 0.5618
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 11), which had val score of 0.586
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 12), which had val score of 0.5964
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 13), which had val score of 0.5744
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 14), which had val score of 0.5818
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 15), which had val score of 0.5922
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 16), which had val score of 0.5901
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 17), which had val score of 0.5828
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 18), which had val score of 0.5744
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 19), which had val score of 0.5786
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 20), which had val score of 0.5755
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 21), which had val score of 0.5639
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 22), which had val score of 0.588
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 23), which had val score of 0.5744
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 24), which had val score of 0.587
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 25), which had val score of 0.5891
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 26), which had val score of 0.5713
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 27), which had val score of 0.5744
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 28), which had val score of 0.5849
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 29), which had val score of 0.5587
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 30), which had val score of 0.5723
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 31), which had val score of 0.5681
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 32), which had val score of 0.5901
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 33), which had val score of 0.5943
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 34), which had val score of 0.586
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 35), which had val score of 0.5713
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 156 of 100800 combinations so far
#
# Best combo after this hyperparameter: (0, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 157 of 100800: (0, 0, 2, 2, 3, 4), taking 2.12 seconds to get val score of 0.5514
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Already Trained and Tested combination (0, 1, 2, 2, 3, 4), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 157 of 100800 combinations so far
# Trained and Tested combination 158 of 100800: (0, 2, 2, 2, 3, 4), taking 7.3 seconds to get val score of 0.586
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Trained and Tested combination 159 of 100800: (0, 3, 2, 2, 3, 4), taking 51.87 seconds to get val score of 0.5964
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Trained and Tested combination 160 of 100800: (0, 4, 2, 2, 3, 4), taking 87.6 seconds to get val score of 0.5839
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Trained and Tested combination 161 of 100800: (0, 5, 2, 2, 3, 4), taking 89.39 seconds to get val score of 0.5839
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Trained and Tested combination 162 of 100800: (0, 6, 2, 2, 3, 4), taking 89.84 seconds to get val score of 0.5839
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
#
# Best combo after this hyperparameter: (0, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_features (index: 3)
#
# Trained and Tested combination 163 of 100800: (0, 1, 2, 0, 3, 4), taking 2.88 seconds to get val score of 0.5042
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Trained and Tested combination 164 of 100800: (0, 1, 2, 1, 3, 4), taking 2.88 seconds to get val score of 0.5786
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Already Trained and Tested combination (0, 1, 2, 2, 3, 4), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 164 of 100800 combinations so far
# Trained and Tested combination 165 of 100800: (0, 1, 2, 3, 3, 4), taking 5.79 seconds to get val score of 0.5839
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
#
# Best combo after this hyperparameter: (0, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_samples (index: 2)
#
# Trained and Tested combination 166 of 100800: (0, 1, 0, 2, 3, 4), taking 2.57 seconds to get val score of 0.6059
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Trained and Tested combination 167 of 100800: (0, 1, 1, 2, 3, 4), taking 4.36 seconds to get val score of 0.586
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
# Already Trained and Tested combination (0, 1, 2, 2, 3, 4), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 167 of 100800 combinations so far
# Trained and Tested combination 168 of 100800: (0, 1, 3, 2, 3, 4), taking 3.88 seconds to get val score of 0.5922
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608
#
# Best combo after this hyperparameter: (0, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 1, 2, 2, 3, 4), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 3, 4), which had val score of 0.6069
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
# Already Trained and Tested combination (2, 1, 2, 2, 3, 4), which had val score of 0.6059
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
# Already Trained and Tested combination (3, 1, 2, 2, 3, 4), which had val score of 0.6006
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
# Already Trained and Tested combination (4, 1, 2, 2, 3, 4), which had val score of 0.6069
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
#
# Best combo after this hyperparameter: (0, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: ccp_alpha (index: 4)
#
# Already Trained and Tested combination (0, 1, 2, 2, 0, 4), which had val score of 0.5723
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 1, 4), which had val score of 0.5723
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 2, 4), which had val score of 0.5723
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 3, 4), which had val score of 0.608
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
# Already Trained and Tested combination (0, 1, 2, 2, 4, 4), which had val score of 0.5524
#         Current best combo: (0, 1, 2, 2, 3, 4) with val score 0.608.
#         Has trained 168 of 100800 combinations so far
#
# Best combo after this hyperparameter: (0, 1, 2, 2, 3, 4) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.607966
# Max Test Score:
#  0.611111
# Max Combo Index:
#  (0, 1, 2, 2, 3, 4) out of [5, 7, 4, 4, 5, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 4}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances')
# % Combos Checked: 168 out of 100800 which is 0.166667%

# %%
jiaocheng.view_best_combo_and_score()
# Out:
# Max Score:
#  0.607966
# Max Test Score:
#  0.611111
# Max Combo Index:
#  (0, 1, 2, 2, 3, 4) out of [5, 7, 4, 4, 5, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 4}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances')
# % Combos Checked: 168 out of 100800 which is 0.166667%
