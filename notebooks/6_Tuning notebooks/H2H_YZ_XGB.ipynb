# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'XGB'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %%
from collections import defaultdict as dd
import numpy as np


def get_brownlow_accuracy_metric(obs_y, pred_y):

    """ Helper to evaluate Brownlow Accuracy Metrics """

    brownlow_accuracy_metric = 0 # overall metric

    for game_id in set(obs_y['game_id']): # every game

        # initialise tallies
        obs_leaderboard = dd(int)
        pred_leaderboard = dd(int)
        
        # get H2H for one game
        obs_game_data = obs_y[obs_y['game_id'] == game_id]
        pred_game_data = pred_y[pred_y['game_id'] == game_id] 

        # for every head to head, get data
        for row in obs_game_data.iterrows(): # first recover actual Brownlow votes
            if row[1]['Brownlow Votes'] > 0:
                obs_leaderboard[row[1]['player1']] += 1
                obs_leaderboard[row[1]['player2']] -= 1

            elif row[1]['Brownlow Votes'] < 0:
                obs_leaderboard[row[1]['player1']] -= 1
                obs_leaderboard[row[1]['player2']] += 1
        
        for row in pred_game_data.iterrows(): # then get predicted votes
            if row[1]['Predicted Brownlow Votes'] > 0:
                pred_leaderboard[row[1]['player1']] += 1
                pred_leaderboard[row[1]['player2']] -= 1

            elif row[1]['Predicted Brownlow Votes'] < 0:
                pred_leaderboard[row[1]['player1']] -= 1
                pred_leaderboard[row[1]['player2']] += 1
        
        # turn leaderboard into a useable list
        obs_leaderboard = list(obs_leaderboard.items())
        obs_leaderboard.sort(key = lambda x:x[1],  reverse= True)

        pred_leaderboard = list(pred_leaderboard.items())
        pred_leaderboard.sort(key = lambda x:x[1],  reverse= True)

        # finally calculate the statistics of model performance for this game
        for i in range(3):
            if obs_leaderboard[0][0] in pred_leaderboard[i][0]:
                brownlow_accuracy_metric += (3-i) # if 3, add 3; if 2, add 2; if 1, add 1
            
            if obs_leaderboard[1][0] in pred_leaderboard[i][0]:
                brownlow_accuracy_metric += 2-abs(i-2) # if 3, add 1; if 2, add 2; if 1, add 1
        
            if obs_leaderboard[2][0] in pred_leaderboard[i][0]:
                brownlow_accuracy_metric += (i+1)/3 # if 1/3, add 1; if 2/3, add 2; if 1, add 1   
        
    return brownlow_accuracy_metric/(len(set(obs_y['game_id']))*6) # scale it by game, and also by max score each game could have acquired

# %%
import pandas as pd
import numpy as np
import statistics as s
import copy
import time
import pickle
import random

from scipy.spatial.distance import cdist
from scipy.stats import t

from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, balanced_accuracy_score





class YangZhouB:

    def __init__(self):
        """ Initialise class """
        self._initialise_objects()

        print('YangZhouB Initialised')



    def _initialise_objects(self):
        """ Helper to initialise objects """
        self.train_x = None
        self.train_y = None
        self.val_x = None
        self.val_y = None
        self.test_x = None
        self.test_y = None
        self.tuning_result = None
        self.model = None
        self.parameter_choices = None
        self.hyperparameters = None
        self.feature_n_ningxiang_score_dict = None
        self.non_tuneable_parameter_choices = list()
        self.checked = None
        self.result = None
        self.checked_core = None
        self.been_best = None
        self.been_cruised = None
        self.tuning_result_saving_address = None
        self.object_saving_address = None
        self._parameter_value_map_index = None
        self._seed = 19260817
        self.best_score = -np.inf
        self.best_combo = None
        self.best_clf = None
        self.clf_type = None
        self.n_items = None
        self._core = None
        self._cruise_indices = None
        self._cruise_indices_values = None
        self._cruise_combinations = None
        self._restarts = 0
        self._cruising = True
        self._surrounding_vectors = None
        self._total_combos = None
        self._tune_features = False
        self._up_to = 0
        self._n_cruise_coord = None
        self._cruising_up_to = 0
        self._feature_combo_n_index_map = None
        self.best_model_saving_address = None

        self.regression_extra_output_columns = ['Train r2', 'Val r2', 'Test r2', 
            'Train RMSE', 'Val RMSE', 'Test RMSE', 'Train MAPE', 'Val MAPE', 'Test MAPE', 'Time']
        self.classification_extra_output_columns = ['Train accu', 'Val accu', 'Test accu', 
            'Train balanced_accu', 'Val balanced_accu', 'Test balanced_accu', 'Train f1', 'Val f1', 'Test f1', 
            'Train precision', 'Val precision', 'Test precision', 'Train recall', 'Val recall', 'Test recall', 'Time']



    def read_in_data(self, train_x, train_y, val_x, val_y, test_x, test_y):
        """ Reads in train validate test data for tuning """

        self.train_x = train_x
        print("Read in Train X data")

        self.train_y = train_y
        print("Read in Train y data")

        self.val_x = val_x
        print("Read in Val X data")

        self.val_y = val_y
        print("Read in Val y data")

        self.test_x = test_x
        print("Read in Test X data")

        self.test_y = test_y
        print("Read in Test y data")



    def read_in_model(self, model, type):
        """ Reads in underlying model object for tuning, and also read in what type of model it is """

        assert type == 'Classification' or type == 'Regression' # check

        # record
        self.model = model
        self.clf_type = type 

        print(f'Successfully read in model {self.model}, which is a {self.clf_type} model')



    def set_hyperparameters(self, parameter_choices):
        """ Input hyperparameter choices """

        self.parameter_choices = parameter_choices
        self._sort_hyperparameter_choices()

        self.hyperparameters = list(parameter_choices.keys())

        # automatically calculate how many different values in each hyperparameter
        self.n_items = [len(parameter_choices[key]) for key in self.hyperparameters]
        self.num_hyperparameters = {hyperparameter:len(parameter_choices[hyperparameter]) for hyperparameter in self.hyperparameters}
        self._total_combos = np.prod(self.n_items)

        # automatically setup checked and result arrays and tuning result dataframe
        self._get_checked_and_result_array()
        self._setup_tuning_result_df()

        print("Successfully recorded hyperparameter choices")


    
    def _sort_hyperparameter_choices(self):
        """ Helper to ensure all hyperparameter choice values are in order from lowest to highest """

        for key in self.parameter_choices:
            tmp = copy.deepcopy(list(self.parameter_choices[key]))
            tmp.sort()
            self.parameter_choices[key] = tuple(tmp)



    def _get_checked_and_result_array(self):
        """ Helper to set up checked and result array """

        self.checked = np.zeros(shape=self.n_items)
        self.result = np.zeros(shape=self.n_items)
        self.checked_core = np.zeros(shape=self.n_items)
        self.been_best = np.zeros(shape=self.n_items) # strictly for last part of Guidance Algorithm
        self.been_cruised = np.zeros(shape=self.n_items)



    def _setup_tuning_result_df(self):
        """ Helper to set up tuning result dataframe """

        tune_result_columns = copy.deepcopy(self.hyperparameters)

        if self._tune_features:
            tune_result_columns.append('feature combo ningxiang score')

        # Different set of metric columns for different types of models
        if self.clf_type == 'Classification':
            tune_result_columns.extend(self.classification_extra_output_columns)
        elif self.clf_type == 'Regression':
            tune_result_columns.extend(self.regression_extra_output_columns)

        self.tuning_result = pd.DataFrame({col:list() for col in tune_result_columns})



    def set_non_tuneable_hyperparameters(self, non_tuneable_hyperparameter_choice):
        """ Input Non tuneable hyperparameter choice """

        if type(non_tuneable_hyperparameter_choice) is not dict:
            print('non_tuneable_hyeprparameters_choice must be dict, please try again')
            return
        
        for nthp in non_tuneable_hyperparameter_choice:
            if type(non_tuneable_hyperparameter_choice[nthp]) in (set, list, tuple, dict):
                print('non_tuneable_hyperparameters_choice must not be of array-like type')
                return

        self.non_tuneable_parameter_choices = non_tuneable_hyperparameter_choice

        print("Successfully recorded non_tuneable_hyperparameter choices")



    def set_features(self, ningxiang_output):
        """ Input features """
    
        if type(ningxiang_output) is not dict:
            print("Please ensure NingXiang output is a dict")
            return
        
        if not self.hyperparameters:
            print("Missing hyperparameter choices, please run .set_hyperparameters() first")
            return
        
        for feature in list(ningxiang_output.keys())[-1]:
            if feature not in list(self.train_x.columns):
                print(f'feature {feature} in ningxiang output is not in train_x. Please try again')
                return
            if feature not in list(self.val_x.columns):
                print(f'feature {feature} in ningxiang output is not in val_x. Please try again')
                return
            if feature not in list(self.test_x.columns):
                print(f'feature {feature} in ningxiang output is not in test_x. Please try again')
                return
        
        # sort ningxiang just for safety, and store up
        ningxiang_output_sorted = self._sort_features(ningxiang_output)
        self.feature_n_ningxiang_score_dict = ningxiang_output_sorted

        # activate this switch
        self._tune_features = True

        # update previous internal structures based on first set of hyperparameter choices
        ##here used numbers instead of tuples as the values in parameter_choices; thus need another mapping to get map back to the features
        self.parameter_choices['features'] = tuple([i for i in range(len(ningxiang_output_sorted))])
        self._feature_combo_n_index_map = {i: list(ningxiang_output_sorted.keys())[i] for i in range(len(ningxiang_output_sorted))}

        self.hyperparameters = list(self.parameter_choices.keys())

        # automatically calculate how many different values in each hyperparameter
        self.n_items = [len(self.parameter_choices[key]) for key in self.hyperparameters]
        self.num_hyperparameters = {hyperparameter:len(self.parameter_choices[hyperparameter]) for hyperparameter in self.hyperparameters}
        self._total_combos = np.prod(self.n_items)

        # automatically calculate all combinations and setup checked and result arrays and tuning result dataframe
        self._get_checked_and_result_array()
        self._setup_tuning_result_df()

        print("Successfully recorded tuneable feature combination choices and updated relevant internal structures")


    
    def _sort_features(self, ningxiang_output):
        """ Helper for sorting features based on NingXiang values (input dict output dict) """

        ningxiang_output_list = [(key, ningxiang_output[key]) for key in ningxiang_output]

        ningxiang_output_list.sort(key = lambda x:x[1])

        ningxiang_output_sorted = {x[0]:x[1] for x in ningxiang_output_list}

        return ningxiang_output_sorted



    def _get_core(self):
        """ Helper to calculate core """
        self._core = [int(i/2) for i in self.n_items]



    def _get_cruise_combinations(self):
        """ Helper to cruise combinations """

        self._get_cruise_indices_values()
        self._generate_cruise_combinations() # first get cruise indicies, then use indicies to get combinations

        self._n_cruise_coord = len(self._cruise_combinations)



    def _get_cruise_indices_values(self):
        """ Helper to get cruise indices values of each dimension which serves as building blocks for cruise combinations """

        self._cruise_indices = dict()
        for hyperparameter in self.hyperparameters:
            self._cruise_indices[hyperparameter] = self._get_cruise_indices_1d(d_val = self.num_hyperparameters[hyperparameter], max_jump = 5)

        self._cruise_indices_values = list(self._cruise_indices.values())



    def _get_cruise_indices_1d(self, d_val, max_jump = 5): 
        """ Helper that returns the appropriate cruise indices based on the number of values in dimension. Second argument controls maximum split size, defaulted to 5 """

        assert type(d_val) is int and type(max_jump) is int, "Error: type of input(s) is not int"
        assert max_jump >= 1, "Error: max_jump must be >= 1"

        gap = d_val - 1
        split = ((gap-1)//max_jump)

        jump = self._find_gaps(split, gap)

        cruise_indices_1d = self._find_cruise_indices_1d(jump)

        return cruise_indices_1d



    def _find_gaps(self, split, gap):
        """ Helper that finds the size of jumps between each element of the final cruise indices, as evenly split as possible with jump size <= 5 """

        if split > 0:
            jump = [gap//(split+1) for i in range(split+1)]
            diff = gap - sum(jump)
            if diff:
                for i in range(diff):
                    jump[i] += 1
        else:
            jump = [gap]

        return jump



    def _find_cruise_indices_1d(self, jump):
        """ Helper that finds the actual cruise_indices based on gaps """

        cruise_indices_1d = [0]
        for i in range(len(jump)):
            cruise_indices_1d.append(sum(jump[:i+1]))

        if cruise_indices_1d == [0, 0]:
            cruise_indices_1d = [0]
            
        return cruise_indices_1d



    def _generate_cruise_combinations(self):
        """ Helper that generates the actual cruise combinations based on cruise indicies """
        ##ALGORITHM: how to generate all combinations of any dimensions given each dimension has different values
        self._cruise_combinations = [[]]
        for i in range(len(self._cruise_indices_values)):

            tmp = copy.deepcopy(self._cruise_combinations)
            self._cruise_combinations = list()

            for x in tmp:

                for k in self._cruise_indices_values[i]:
                    y = copy.deepcopy(x)
                    
                    y.append(k)

                    self._cruise_combinations.append(y)



    def _sort_cruise_combos(self, max_combo):
        """ sort the cruise combos based on Euclidean distance from current max"""

        edist = list(cdist([max_combo], self._cruise_combinations).flatten())
        ordered_cruise_combos = [(self._cruise_combinations[i], edist[i]) for i in range(len(self._cruise_combinations))]

        ordered_cruise_combos.sort(reverse=True, key=lambda x: x[1])

        sorted_cruise_combos = [ordered_cruise_combos[i][0] for i in range(len(ordered_cruise_combos))]

        return sorted_cruise_combos

    

    def _get_max_surrounding_mean_sd(self):
        """ Helper to get the surrounding mean and sd given the current maximum """

        best_combo_surrounding_combos = self._get_surrounding_step_combos(self.best_combo)
        best_combo_surrounding_scores = [self.best_score]
        for combo in best_combo_surrounding_combos:
            best_combo_surrounding_scores.append(self.result[tuple(combo)])

        max_surrounding_mean = s.mean(best_combo_surrounding_scores)
        max_surrounding_sd = s.stdev(best_combo_surrounding_scores)

        return max_surrounding_mean, max_surrounding_sd



    def _cruise_warning_threshold(self, max_surrounding_mean, max_surrounding_sd, max_surrounding_n):
        """ Helper that gets the warning threshold by (mean of best_combo surrounds - halfwidth) """

        # use 0.95 (one sided test)
        qt = t.ppf(0.95, max_surrounding_n-1) 
        halfwidth = max_surrounding_sd * qt * 1/np.sqrt(max_surrounding_n)

        return max_surrounding_mean - halfwidth



    def _CruiseSystem(self):
        """ Helper that performs cruising """

        # get cruise combos in sorted order (furthest away from current max)
        sorted_cruise_combos = self._sort_cruise_combos(self.best_combo)

        # calculate warning threshold by getting max_surrounding_sd first
        max_surrounding_mean, max_surrounding_sd = self._get_max_surrounding_mean_sd()

        warning_threshold = self._cruise_warning_threshold(max_surrounding_mean, max_surrounding_sd, len(self._surrounding_vectors))

        # check each cruise combo
        for cruise_combo in sorted_cruise_combos:

            # only search if it hasn't been cruised before (if has then is not an artifect of significance)
            if not self.been_cruised[tuple(cruise_combo)]:
                
                self._cruising_up_to += 1
                print(f'Cruising Coordrdinate {self._cruising_up_to} of {self._n_cruise_coord}\n')
                
                self.been_cruised[tuple(cruise_combo)] = 2 # actually been cruised

                # if above warning threshold, then stop cruise and restart guide
                if self.result[tuple(cruise_combo)] >= warning_threshold:
                   
                    print(f"Cruise suspended due to suspicious case")
                    
                    return cruise_combo


        # if reach here then all cruise indicies checked. can safely say end cruise
        self._cruising = False

        return



    def _get_core(self):
        """ Helper to calculate core """

        self._core = [int(i/2) for i in self.n_items]



    def _new_combos(self, core, vector):
        """ Helper that gets particular COORDINATE using a move in direction of VECTOR from particular CORE """

        assert len(core) == len(vector)

        new_combo = list()
        for i in range(len(vector)):
            val = core[i] + vector[i]
            if val >= self.n_items[i] or val < 0: # check whether combo is still in the field
                return False
            new_combo.append(val)

        return new_combo



    def _xlnx(self, x):
        """ Helper that returns x*ln(x), rounding up to next int """
        y = int(x*np.log(x))+1
        
        return y



    def _find_new_core(self, surrounding_combos, core):
        """ Helper that finds new cores - only those candidates with difference between core and treatment < 0.005 """

        new_cores = []
        tmp_new_cores = list()
        
        for i in range(len(surrounding_combos)): 

            diff = self.result[tuple(core)] - self.result[tuple(surrounding_combos[i])]

            if diff <= 0.005:
                if self.checked_core[ tuple(surrounding_combos[i]) ] == 0:
                    tmp_new_cores.append([tuple(surrounding_combos[i]), diff])
                        
        # # sort the tmp new cores list according to p values
        # tmp_new_cores.sort(key = lambda x:x[1])

        # # calculate how many new cores to accept according to the dimension of the grid (x = dim; accept x*ln(x))
        # n_accept = self._xlnx(len(core))
        
        for i in range(len(tmp_new_cores)):
            # if i >= n_accept:
            #     break

            new_cores.append(tmp_new_cores[i][0])
            self.checked_core[ tmp_new_cores[i][0] ] = 1

        return new_cores



    def _get_surrounding_step_vectors(self, core):
        """ find all horizontal steps """

        all_steps = list()

        for i in range(len(core)):
            for val in [-1, 1]:
                tmp = [0 for i in range(len(core))]
                tmp[i] = val
        
                all_steps.append(tmp)
        
        return all_steps
    


    def _get_surrounding_step_combos(self, core):
        """ find all vectors that are one horizontal steps away from core """

        surrounding_combos = list()
        for step in self._surrounding_vectors:

            add = 1
            candidate_surrounding_combo = list()

            for i in range(len(core)):
                new_index = core[i]+step[i]
                if new_index < 0 or new_index >= self.n_items[i]:
                    add = 0
                    break
                else:
                    candidate_surrounding_combo.append(new_index)

            if add:    
                surrounding_combos.append(candidate_surrounding_combo)

        return surrounding_combos



    def _get_new_cores(self, core):
        """ Helper that gets new cores given old cores """

        # if (should be rare) case where core has been a core before, then skip. For prevention of infinite loops
        # 2 means actual checked core, 1 means appended to checked core list but not checked
        if self.checked_core[tuple(core)] == 2:
            return
        else:
            self.checked_core[tuple(core)] = 2 # actually been checked as a core

        surrounding_combos = self._get_surrounding_step_combos(core)

        # actually tune the surrounding combos
        for combo in surrounding_combos:
            
            if self.checked[tuple(combo)] == 0:
                self._up_to += 1
                self._train_and_test_combo(combo)
            else:
                self._check_already_trained_best_score(combo)

        # perform welch test and return surrounding combos that should be used as new core
        new_cores = self._find_new_core(surrounding_combos, core)

        return new_cores  



    def _GuidanceSystem(self, core):
        """ Helper that performs guidance search """

        if self._restarts == 0:
            print("Guidance: initial round \n")
        else:
            print("Guidance: round", self._restarts, '\n')

        print('\tround', self._restarts, 'iteration: ', 0, '\n')

        # first get a surrounding 3^d tuned
        new_cores = self._get_new_cores(core)
        self.been_cruised[tuple(core)] = 1 # represent don't need to be added as a to cruised - but not cruised, rather a core

        round = 1
        while new_cores: # while new cores are being added
            print('\tround', self._restarts, "iteration: ", round, "\n") 
            round += 1

            old_new_cores = copy.deepcopy(new_cores)
            new_cores = list()

            # for each of the new cores, 'recursively' tune and grab new cores; but each Iteration doesn't end until all cores of current round has been checked
            for new_core in old_new_cores:
                
                new_new_cores = self._get_new_cores(new_core)

                if not new_new_cores:
                    new_new_cores = []

                self.been_cruised[tuple(core)] == 1
                
                for new_new_core in new_new_cores:
                    if self.checked_core[tuple(new_new_core)] == 0:
                        new_cores.append(new_new_core)
                        self.checked_core[tuple(new_new_core)] = 1 # represent added to checked core - to prevent repeated added to core


        # for current max, get 3^d block. if new max happens to be found, continue to do 3^d block until no new max is found
        # just a cheap way to flesh out the max (the goal of YangZhouB)
        while self.been_best[tuple(self.best_combo)] == 0:

            self.been_best[tuple(self.best_combo)] = 1 
    
            surrounding_combos = self._get_surrounding_step_combos(self.best_combo)
            for combo in surrounding_combos:
                
                if self.checked[tuple(combo)] == 0:
                    self._up_to += 1
                    self._train_and_test_combo(combo)
                else:
                    self._check_already_trained_best_score(combo)

        # print information of this round 

        print('% Combos Checked Thus Far:', int(sum(self.checked.reshape((np.prod(self.n_items))))), 'out of', np.prod(self.n_items), 'which is', f'{np.mean(self.checked).round(8)*100}%')



    def tune(self, key_stats_only = False):
        """ Begin tuning """

        if self.train_x is None or self.train_y is None or self.val_x is None or self.val_y is None or self.test_x is None or self.test_y is None:
            print(" Missing one of the datasets, please run .read_in_data() ")
            return

        if self.model is None:
            print(" Missing model, please run .read_in_model() ")
            return

        if self.tuning_result_saving_address is None:
            print("Missing tuning result csv saving address, please run .set_tuning_result_saving_address() first")

        if self.best_model_saving_address is None:
            print("Missing best model saving address, please run .set_best_model_saving_address() first")

        self.key_stats_only = key_stats_only

        print("BEGIN TUNING\n\n") 
        
        # FIRST: get all cruise combinations as well as core, and tune all these
        self._get_core()
        self._get_cruise_combinations() 

        first_round_combinations = copy.deepcopy(self._cruise_combinations)
        first_round_combinations.append(self._core) 

        random.seed(self._seed)
        random.shuffle(first_round_combinations)

        print("STAGE ZERO: Tune all Cruise combinations\n\n")
        for combo in first_round_combinations:
            
            if not self.checked[tuple(combo)]:

                self._up_to += 1
                self._train_and_test_combo(combo)
            
            else:
                self._check_already_trained_best_score(combo)
        

        # SECOND: from the core combo, begin guidance system
        self._surrounding_vectors = self._get_surrounding_step_vectors(self._core)

        print('\n')
        print("STAGE ONE: Begin initial Guidance system\n\n")

        self._restarts = 0
        self._GuidanceSystem(self._core) # Initial Round of Guidance
        self._restarts += 1

        # THIRD: Recursively Cruise and restart Guide if find a combo that is within halfwidth of mean of best combo surrounds
        print("STAGE TWO: Begin Cruise system\n\n")
        self._cruising_up_to = 0
        self._cruising = True
        while self._cruising:
            suspicious_case_combo = self._CruiseSystem()

            if self._cruising:
                self._GuidanceSystem(tuple(suspicious_case_combo))
                self._restarts += 1

        # FINALLY: Final extensive guidance search around maxes.
        print("FINAL STAGE: Begin final Guidance system\n\n")
        old_best_score = copy.deepcopy(self.best_score)
        self._restarts = 'FINAL'

        self._GuidanceSystem(self.best_combo)

        while(self.best_score-old_best_score > 0):
            old_best_score = copy.deepcopy(self.best_score)
            self._GuidanceSystem(self.best_combo)



        # Display final information
        print("TUNING FINISHED\n")

        print('Max Score: \n', self.best_score)
        print('Max Combo: \n', self.best_combo)

        print('% Combos Checked:', int(sum(self.checked.reshape((np.prod(self.n_items))))), 'out of', np.prod(self.n_items), 'which is', f'{np.mean(self.checked).round(8)*100}%')
    


    def tune_parallel(self, part, splits, key_stats_only = False):
        """ Begin tuning in Parallel """

        assert type(part) is int and type(splits) is int

        if part <= 0 or part > splits:
            print("Part must be within [1, splits]")
            return

        if self.train_x is None or self.train_y is None or self.val_x is None or self.val_y is None or self.test_x is None or self.test_y is None:
            print(" Missing one of the datasets, please run .read_in_data() ")
            return

        if self.model is None:
            print(" Missing model, please run .read_in_model() ")
            return

        if self.tuning_result_saving_address is None:
            print("Missing tuning result csv saving address, please run .set_tuning_result_saving_address() first")

        if self.best_model_saving_address is None:
            print("Missing best model saving address, please run .set_best_model_saving_address() first")

        self.key_stats_only = key_stats_only

        print("BEGIN TUNING\n\n") 
        
        # FIRST: get all cruise combinations as well as core, and tune all these
        self._get_core()
        self._get_cruise_combinations() 

        first_round_combinations = copy.deepcopy(self._cruise_combinations)
        first_round_combinations.append(self._core) 

        random.seed(self._seed)
        random.shuffle(first_round_combinations)

        parallel_combo_to_tune = copy.deepcopy(first_round_combinations)
        start_index = int((part-1)/splits * len(first_round_combinations))
        end_index = int(part/splits * len(first_round_combinations))
        parallel_combo_to_tune = parallel_combo_to_tune[start_index:end_index]

        print(f'Parallel tuning part {part} of Cruise: set to tune {len(parallel_combo_to_tune)} combinations')

        print("STAGE ZERO: Tune all Cruise combinations\n\n")
        for combo in parallel_combo_to_tune:
            
            if not self.checked[tuple(combo)]:
                self._up_to += 1
                self._train_and_test_combo(combo)
            
            else:
                self._check_already_trained_best_score(combo)


        # Display final information
        print(f"PARALLEL TUNING PART {part} OF CRUISE FINISHED\n")

        print('Max Score: \n', self.best_score)
        print('Max Combo: \n', self.best_combo)

        print('% Combos Checked:', int(sum(self.checked.reshape((np.prod(self.n_items))))), 'out of', np.prod(self.n_items), 'which is', f'{np.mean(self.checked).round(8)*100}%')



    def _train_and_test_combo(self, combo):
        """ Helper to train and test each combination as part of tune() """

        combo = tuple(combo)
        
        params = {self.hyperparameters[i]:self.parameter_choices[self.hyperparameters[i]][combo[i]] for i in range(len(self.hyperparameters))}
        
        
        if self._tune_features == True:
            del params['features']
            tmp_train_x = self.train_x[list(self._feature_combo_n_index_map[combo[-1]])] 
            tmp_val_x = self.val_x[list(self._feature_combo_n_index_map[combo[-1]])]
            tmp_test_x = self.test_x[list(self._feature_combo_n_index_map[combo[-1]])]

            # add non tuneable parameters
            for nthp in self.non_tuneable_parameter_choices:
                params[nthp] = self.non_tuneable_parameter_choices[nthp]

            # initialise object
            clf = self.model(**params)

            params['features'] = [list(self._feature_combo_n_index_map[combo[-1]])] 
            params['feature combo ningxiang score'] = self.feature_n_ningxiang_score_dict[self._feature_combo_n_index_map[combo[-1]]]

        else:
            tmp_train_x = self.train_x
            tmp_val_x = self.val_x
            tmp_test_x = self.test_x

            # add non tuneable parameters
            for nthp in self.non_tuneable_parameter_choices:
                params[nthp] = self.non_tuneable_parameter_choices[nthp]

            # initialise object
            clf = self.model(**params)

        # get time and fit
        start = time.time()
        clf.fit(tmp_train_x, self.train_y)
        end = time.time()

        # get predicted labels/values for three datasets
        train_pred = clf.predict(tmp_train_x)
        val_pred = clf.predict(tmp_val_x)
        test_pred = clf.predict(tmp_test_x)
  
        train_obs_df = copy.deepcopy(train_other_info)
        val_obs_df = copy.deepcopy(val_other_info)
        test_obs_df = copy.deepcopy(test_other_info)

        train_obs_df['Brownlow Votes'] = list(self.train_y)
        val_obs_df['Brownlow Votes'] = list(self.val_y)
        test_obs_df['Brownlow Votes'] = list(self.test_y)

        train_pred_df = copy.deepcopy(train_other_info)
        val_pred_df = copy.deepcopy(val_other_info)
        test_pred_df = copy.deepcopy(test_other_info)

        train_pred_df['Predicted Brownlow Votes'] = list(train_pred)
        val_pred_df['Predicted Brownlow Votes'] = list(val_pred)
        test_pred_df['Predicted Brownlow Votes'] = list(test_pred)

        # get scores and time used
        time_used = end-start

        # build output dictionary and save result
        df_building_dict = params


        if self.clf_type == 'Regression':

            train_brownlow_score = val_brownlow_score = test_brownlow_score = train_score = val_score = \
            test_score = train_rmse = val_rmse = test_rmse = train_mape = val_mape = test_mape = 0

            try:
                train_brownlow_score = get_brownlow_accuracy_metric(train_obs_df, train_pred_df)
            except:
                pass
            try:
                val_brownlow_score = get_brownlow_accuracy_metric(val_obs_df, val_pred_df)
            except:
                pass
            try:
                test_brownlow_score = get_brownlow_accuracy_metric(test_obs_df, test_pred_df)
            except:
                pass

            try:
                train_score = r2_score(self.train_y, train_pred)
            except:
                pass
            try:
                val_score = r2_score(self.val_y, val_pred)
            except:
                pass
            try:
                test_score = r2_score(self.test_y, test_pred)
            except:
                pass
            
            try:
                train_rmse = np.sqrt(mean_squared_error(self.train_y, train_pred))
            except:
                pass
            try:
                val_rmse = np.sqrt(mean_squared_error(self.val_y, val_pred))
            except:
                pass
            try:
                test_rmse = np.sqrt(mean_squared_error(self.test_y, test_pred))
            except:
                pass

            if self.key_stats_only == False:
                try:
                    train_mape = mean_absolute_percentage_error(self.train_y, train_pred)
                except:
                    pass
                try:
                    val_mape = mean_absolute_percentage_error(self.val_y, val_pred)
                except:
                    pass
                try:
                    test_mape = mean_absolute_percentage_error(self.test_y, test_pred)
                except:
                    pass
            
            df_building_dict['Train r2'] = [np.round(train_score, 6)]
            df_building_dict['Val r2'] = [np.round(val_score, 6)]
            df_building_dict['Test r2'] = [np.round(test_score, 6)]
            df_building_dict['Train RMSE'] = [np.round(train_rmse, 6)]
            df_building_dict['Val RMSE'] = [np.round(val_rmse, 6)]
            df_building_dict['Test RMSE'] = [np.round(test_rmse, 6)]
            df_building_dict['Train Brownlow Metric'] = [np.round(train_brownlow_score, 6)]
            df_building_dict['Val Brownlow Metric'] = [np.round(val_brownlow_score, 6)]
            df_building_dict['Test Brownlow Metric'] = [np.round(test_brownlow_score, 6)]
            
            if self.key_stats_only == False:
                df_building_dict['Train MAPE'] = [np.round(train_mape, 6)]
                df_building_dict['Val MAPE'] = [np.round(val_mape, 6)]
                df_building_dict['Test MAPE'] = [np.round(test_mape, 6)]

        
        elif self.clf_type == 'Classification':

            train_score = val_score = test_score = train_bal_accu = val_bal_accu = test_bal_accu = train_f1 = val_f1 = test_f1 = \
                train_precision = val_precision = test_precision = train_recall = val_recall = test_recall = 0

            try:    
                train_score = accuracy_score(self.train_y, train_pred)
            except:
                pass
            try:
                val_score = accuracy_score(self.val_y, val_pred)
            except:
                pass
            try:
                test_score = accuracy_score(self.test_y, test_pred)
            except:
                pass

            try:
                train_bal_accu = balanced_accuracy_score(self.train_y, train_pred)
            except:
                pass
            try:
                val_bal_accu = balanced_accuracy_score(self.val_y, val_pred)
            except:
                pass
            try:
                test_bal_accu = balanced_accuracy_score(self.test_y, test_pred)
            except:
                pass
            
            try:
                train_f1 = f1_score(self.train_y, train_pred, average='weighted')
            except:
                pass
            try:
                val_f1 = f1_score(self.val_y, val_pred, average='weighted')
            except:
                pass
            try:
                test_f1 = f1_score(self.test_y, test_pred, average='weighted')
            except:
                pass
            
            try:
                train_precision = precision_score(self.train_y, train_pred, average='weighted')
            except:
                pass
            try:
                val_precision = precision_score(self.val_y, val_pred, average='weighted')
            except:
                pass
            try:
                test_precision = precision_score(self.test_y, test_pred, average='weighted')
            except:
                pass

            try:
                train_recall = recall_score(self.train_y, train_pred, average='weighted')
            except:
                pass
            try:
                val_recall = recall_score(self.val_y, val_pred, average='weighted')
            except:
                pass
            try:
                test_recall = recall_score(self.test_y, test_pred, average='weighted')
            except:
                pass

            df_building_dict['Train accu'] = [np.round(train_score, 6)]
            df_building_dict['Val accu'] = [np.round(val_score, 6)]
            df_building_dict['Test accu'] = [np.round(test_score, 6)]
            df_building_dict['Train balanced_accuracy'] = [np.round(train_bal_accu, 6)]
            df_building_dict['Val balanced_accuracy'] = [np.round(val_bal_accu, 6)]
            df_building_dict['Test balanced_accuracy'] = [np.round(test_bal_accu, 6)]
            df_building_dict['Train f1'] = [np.round(train_f1, 6)]
            df_building_dict['Val f1'] = [np.round(val_f1, 6)]
            df_building_dict['Test f1'] = [np.round(test_f1, 6)]
            df_building_dict['Train precision'] = [np.round(train_precision, 6)]
            df_building_dict['Val precision'] = [np.round(val_precision, 6)]
            df_building_dict['Test precision'] = [np.round(test_precision, 6)]
            df_building_dict['Train recall'] = [np.round(train_recall, 6)]
            df_building_dict['Val recall'] = [np.round(val_recall, 6)]
            df_building_dict['Test recall'] = [np.round(test_recall, 6)]


        df_building_dict['Time'] = [np.round(time_used, 2)]


        tmp = pd.DataFrame(df_building_dict)


        self.tuning_result = self.tuning_result.append(tmp)
        self._save_tuning_result()

        # update best score stats
        if val_brownlow_score > self.best_score: 
            self.best_score = val_brownlow_score
            self.best_clf = clf
            self.best_combo = combo
            self._save_best_model()

        # update internal governing DataFrames
        self.checked[combo] = 1
        self.result[combo] = val_brownlow_score

        self._up_to += 1

        print(f'''Trained and Tested combination {self._up_to} of {self._total_combos}: {combo}, taking {np.round(time_used,2)} seconds to get val score of {np.round(val_brownlow_score,4)}
        Current best combo: {self.best_combo} with val score {np.round(self.best_score, 4)}''')



    def _check_already_trained_best_score(self, combo):
        """ Helper for checking whether an already trained combo is best score """
        
        combo = tuple(combo)
        
        # update best score stats
        if self.result[combo] > self.best_score: 
            self.best_score = self.result[combo]
            self.best_clf = None
            print(f"As new Best Combo {combo} was read in, best_clf is set to None")
            self.best_combo = combo

        print(f'''Already Trained and Tested combination {combo}, which had val score of {np.round(self.result[combo],4)}
        Current best combo: {self.best_combo} with val score {np.round(self.best_score, 4)}. 
        Has trained {self._up_to} of {self._total_combos} combinations so far''')



    def _save_tuning_result(self):
        """ Helper to export tuning result csv """

        tuning_result_saving_address_split = self.tuning_result_saving_address.split('.csv')[0]

        self.tuning_result.to_csv(f'{tuning_result_saving_address_split}.csv', index=False)

    

    def view_best_combo_and_score(self):
        """ View best combination and its validation score """
        
        print(f'(Current) Best combo: {self.best_combo} with val score {self.best_score}')



    def read_in_tuning_result_df(self, address): 
        """ Read in tuning result csv and read data into checked and result arrays """

        if self.parameter_choices is None:
            print("Missing parameter_choices to build parameter_value_map_index, please run set_hyperparameters() first")
            return
        
        if self.clf_type is None:
            print('Missing clf_type. Please run .read_in_model() first.')
            return

        self.tuning_result = pd.read_csv(address)
        
        self._up_to = 0

        self._create_parameter_value_map_index()

        # read DataFrame data into internal governing DataFrames of YangZhouB
        for row in self.tuning_result.iterrows():

            self._up_to += 1
    
            combo = list()
            for hyperparam in self.hyperparameters:
                if hyperparam == 'features':
                    
                    # reverse two dicts
                    index_n_feature_combo_map = {self._feature_combo_n_index_map[key]:key for key in self._feature_combo_n_index_map}
                    # special input
                    combo.append(index_n_feature_combo_map[tuple(self._str_to_list(row[1]['features']))])
                    
                else:
                    combo.append(self._parameter_value_map_index[hyperparam][row[1][hyperparam]])

            combo = tuple(combo)
            
            self.checked[combo] = 1
            
            if self.clf_type == 'Regression':
                self.result[combo] = row[1]['Val Brownlow Metric']
            elif self.clf_type == 'Classification':
                self.result[combo] = row[1]['Val accu']
        
        print(f"Successfully read in tuning result of {len(self.tuning_result)} rows")



    def _str_to_list(self, string):
        """ Helper to convert string to list"""

        out = list()
        for feature in string.split(', '):
            out.append(feature.strip('[').strip(']').strip("'"))
        
        return out

    
    
    def _create_parameter_value_map_index(self):
        """ Helper to create parameter-value index map """

        self._parameter_value_map_index = dict()
        for key in self.parameter_choices.keys():
            tmp = dict()
            for i in range(len(self.parameter_choices[key])):
                tmp[self.parameter_choices[key][i]] = i
            self._parameter_value_map_index[key] = tmp


    
    def set_tuning_result_saving_address(self, address):
        """ Read in where to save tuning object """

        self.tuning_result_saving_address = address
        print('Successfully set tuning output address')



    def set_best_model_saving_address(self, address):
        """ Read in where to save best model  """

        self.best_model_saving_address = address
        print('Successfully set best model output address')

    

    def _save_best_model(self):
        """ Helper to save best model as a pickle """

        best_model_saving_address_split = self.best_model_saving_address.split('.pickle')[0]

        with open(f'{best_model_saving_address_split}.pickle', 'wb') as f:
            pickle.dump(self.best_clf, f)

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
yangzhou = YangZhouB()
# Out:
# YangZhouB Initialised

# %%
from xgboost import XGBRegressor as XGB

# %%
yangzhou.read_in_model(XGB, 'Regression')
# Out:
# Successfully read in model <class 'xgboost.sklearn.XGBRegressor'>, which is a Regression model

# %%
yangzhou.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': (25, 50, 100, 20),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85),
    'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# %%
yangzhou.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
yangzhou.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': 2})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
yangzhou.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  yangzhou.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/yangzhou_BrownlowH2H_{MODEL}.csv')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 886 rows
# True

# %%
yangzhou.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/yangzhou_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
yangzhou.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/yangzhou_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
yangzhou.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (0, 3, 3, 3, 4, 0, 25) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 3, 3, 3, 4, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 3, 4, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 0, 4, 5, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 4, 5, 5), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 0, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 0, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 0, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 0, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 0, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 0, 5, 0), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 4, 5, 25), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 0, 5, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 0, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 0, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 5, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 0, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 0, 5, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 0, 4, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 4, 5, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 0, 4, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 4, 5, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 4, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 4, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 4, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 0, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 0, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 0, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 0, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 4, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 5, 20), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 4, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 0, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 0, 5, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 4, 5, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 0, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 4, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 0, 0, 5, 35), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 4, 5, 25), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 3, 0, 5, 35), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 0, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 0, 0, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 0, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 0, 4, 5, 10), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 0, 5, 35), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 4, 5, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 0, 4, 5, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 0, 4, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 0, 5, 35), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 4, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 4, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 0, 4, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 0, 4, 5, 0), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 0, 0, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 5, 10), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 0, 5, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 0, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 4, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 4, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 4, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 4, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 0, 4, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 3, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 0, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 3, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 0, 0, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 4, 5, 0), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 4, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 5, 20), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 0, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 0, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 4, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 0, 5, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 0, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 0, 0, 5, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 0, 0, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 0, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 4, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 5, 20), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 4, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 4, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 4, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 5, 0), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 0, 4, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 4, 5, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 5, 35), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 0, 5, 20), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 4, 5, 20), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 0, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 4, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 5, 5), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 0, 5, 0), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 0, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 0, 4, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 0, 4, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 4, 5, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 0, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 3, 0, 5, 25), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 4, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 0, 5, 25), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 4, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 0, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 0, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 0, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 4, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 4, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 4, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 0, 4, 5, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 4, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 0, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 0, 4, 5, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 4, 5, 0), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 0, 4, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 0, 0, 0, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 4, 5, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 4, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 3, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 0, 0, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 0, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 0, 4, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 4, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 0, 4, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 4, 5, 35), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 0, 5, 5), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 4, 5, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 3, 0, 5, 5), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 0, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 5, 5), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 0, 5, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 4, 0, 20), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 5, 25), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 4, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 0, 0, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 3, 0, 4, 5, 35), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 0, 4, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 4, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 5, 0), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 5, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 0, 0, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 0, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 4, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 0, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 3, 0, 0, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 3, 0, 0, 5, 10), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 0, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 0, 5, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 0, 0, 5, 30), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 4, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 3, 4, 5, 15), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 6, 0, 0, 4, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 0, 4, 5, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 15), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 0, 3, 3, 0, 5, 0), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 0, 0, 0, 5), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 3, 3, 3, 0, 0, 25), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 0, 0, 5, 10), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5, 5), which had val score of 0.0
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 3, 3, 0, 0, 30), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 4, 5, 35), which had val score of 0.2117
#         Current best combo: (0, 3, 3, 3, 4, 0, 25) with val score 0.2117.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 5, 15), which had val score of 0.0
# ...
#
# Cruising Coordrdinate 392 of 768
#
# Cruising Coordrdinate 393 of 768
#
# Cruising Coordrdinate 394 of 768
#
# Cruising Coordrdinate 395 of 768
#
# Cruising Coordrdinate 396 of 768
#
# Cruising Coordrdinate 397 of 768
#
# Cruising Coordrdinate 398 of 768
#
# Cruising Coordrdinate 399 of 768
#
# Cruising Coordrdinate 400 of 768
#
# Cruising Coordrdinate 401 of 768
#
# Cruising Coordrdinate 402 of 768
#
# Cruising Coordrdinate 403 of 768
#
# Cruising Coordrdinate 404 of 768
#
# Cruising Coordrdinate 405 of 768
#
# Cruising Coordrdinate 406 of 768
#
# Cruising Coordrdinate 407 of 768
#
# Cruising Coordrdinate 408 of 768
#
# Cruising Coordrdinate 409 of 768
#
# Cruising Coordrdinate 410 of 768
#
# Cruising Coordrdinate 411 of 768
#
# Cruising Coordrdinate 412 of 768
#
# Cruising Coordrdinate 413 of 768
#
# Cruising Coordrdinate 414 of 768
#
# Cruising Coordrdinate 415 of 768
#
# Cruising Coordrdinate 416 of 768
#
# Cruising Coordrdinate 417 of 768
#
# Cruising Coordrdinate 418 of 768
#
# Cruising Coordrdinate 419 of 768
#
# Cruising Coordrdinate 420 of 768
#
# Cruising Coordrdinate 421 of 768
#
# Cruising Coordrdinate 422 of 768
#
# Cruising Coordrdinate 423 of 768
#
# Cruising Coordrdinate 424 of 768
#
# Cruising Coordrdinate 425 of 768
#
# Cruising Coordrdinate 426 of 768
#
# Cruising Coordrdinate 427 of 768
#
# Cruising Coordrdinate 428 of 768
#
# Cruising Coordrdinate 429 of 768
#
# Cruising Coordrdinate 430 of 768
#
# Cruising Coordrdinate 431 of 768
#
# Cruising Coordrdinate 432 of 768
#
# Cruising Coordrdinate 433 of 768
#
# Cruising Coordrdinate 434 of 768
#
# Cruising Coordrdinate 435 of 768
#
# Cruising Coordrdinate 436 of 768
#
# Cruising Coordrdinate 437 of 768
#
# Cruising Coordrdinate 438 of 768
#
# Cruising Coordrdinate 439 of 768
#
# Cruising Coordrdinate 440 of 768
#
# Cruising Coordrdinate 441 of 768
#
# Cruising Coordrdinate 442 of 768
#
# Cruising Coordrdinate 443 of 768
#
# Cruising Coordrdinate 444 of 768
#
# Cruising Coordrdinate 445 of 768
#
# Cruising Coordrdinate 446 of 768
#
# Cruising Coordrdinate 447 of 768
#
# Cruising Coordrdinate 448 of 768
#
# Cruising Coordrdinate 449 of 768
#
# Cruising Coordrdinate 450 of 768
#
# Cruising Coordrdinate 451 of 768
#
# Cruising Coordrdinate 452 of 768
#
# Cruising Coordrdinate 453 of 768
#
# Cruising Coordrdinate 454 of 768
#
# Cruising Coordrdinate 455 of 768
#
# Cruising Coordrdinate 456 of 768
#
# Cruising Coordrdinate 457 of 768
#
# Cruising Coordrdinate 458 of 768
#
# Cruising Coordrdinate 459 of 768
#
# Cruising Coordrdinate 460 of 768
#
# Cruising Coordrdinate 461 of 768
#
# Cruising Coordrdinate 462 of 768
#
# Cruising Coordrdinate 463 of 768
#
# Cruising Coordrdinate 464 of 768
#
# Cruising Coordrdinate 465 of 768
#
# Cruising Coordrdinate 466 of 768
#
# Cruising Coordrdinate 467 of 768
#
# Cruising Coordrdinate 468 of 768
#
# Cruising Coordrdinate 469 of 768
#
# Cruising Coordrdinate 470 of 768
#
# Cruising Coordrdinate 471 of 768
#
# Cruising Coordrdinate 472 of 768
#
# Cruising Coordrdinate 473 of 768
#
# Cruising Coordrdinate 474 of 768
#
# Cruising Coordrdinate 475 of 768
#
# Cruising Coordrdinate 476 of 768
#
# Cruising Coordrdinate 477 of 768
#
# Cruising Coordrdinate 478 of 768
#
# Cruising Coordrdinate 479 of 768
#
# Cruising Coordrdinate 480 of 768
#
# Cruising Coordrdinate 481 of 768
#
# Cruising Coordrdinate 482 of 768
#
# Cruising Coordrdinate 483 of 768
#
# Cruising Coordrdinate 484 of 768
#
# Cruising Coordrdinate 485 of 768
#
# Cruising Coordrdinate 486 of 768
#
# Cruising Coordrdinate 487 of 768
#
# Cruising Coordrdinate 488 of 768
#
# Cruising Coordrdinate 489 of 768
#
# Cruising Coordrdinate 490 of 768
#
# Cruising Coordrdinate 491 of 768
#
# Cruising Coordrdinate 492 of 768
#
# Cruising Coordrdinate 493 of 768
#
# Cruising Coordrdinate 494 of 768
#
# Cruising Coordrdinate 495 of 768
#
# Cruising Coordrdinate 496 of 768
#
# Cruising Coordrdinate 497 of 768
#
# Cruising Coordrdinate 498 of 768
#
# Cruising Coordrdinate 499 of 768
#
# Cruising Coordrdinate 500 of 768
#
# Cruising Coordrdinate 501 of 768
#
# Cruising Coordrdinate 502 of 768
#
# Cruising Coordrdinate 503 of 768
#
# Cruising Coordrdinate 504 of 768
#
# Cruising Coordrdinate 505 of 768
#
# Cruising Coordrdinate 506 of 768
#
# Cruising Coordrdinate 507 of 768
#
# Cruising Coordrdinate 508 of 768
#
# Cruising Coordrdinate 509 of 768
#
# Cruising Coordrdinate 510 of 768
#
# Cruising Coordrdinate 511 of 768
#
# Cruising Coordrdinate 512 of 768
#
# Cruising Coordrdinate 513 of 768
#
# Cruising Coordrdinate 514 of 768
#
# Cruising Coordrdinate 515 of 768
#
# Cruising Coordrdinate 516 of 768
#
# Cruising Coordrdinate 517 of 768
#
# Cruising Coordrdinate 518 of 768
#
# Cruising Coordrdinate 519 of 768
#
# Cruising Coordrdinate 520 of 768
#
# Cruising Coordrdinate 521 of 768
#
# Cruising Coordrdinate 522 of 768
#
# Cruising Coordrdinate 523 of 768
#
# Cruising Coordrdinate 524 of 768
#
# Cruising Coordrdinate 525 of 768
#
# Cruising Coordrdinate 526 of 768
#
# Cruising Coordrdinate 527 of 768
#
# Cruising Coordrdinate 528 of 768
#
# Cruising Coordrdinate 529 of 768
#
# Cruising Coordrdinate 530 of 768
#
# Cruising Coordrdinate 531 of 768
#
# Cruising Coordrdinate 532 of 768
#
# Cruising Coordrdinate 533 of 768
#
# Cruising Coordrdinate 534 of 768
#
# Cruising Coordrdinate 535 of 768
#
# Cruising Coordrdinate 536 of 768
#
# Cruising Coordrdinate 537 of 768
#
# Cruising Coordrdinate 538 of 768
#
# Cruising Coordrdinate 539 of 768
#
# Cruising Coordrdinate 540 of 768
#
# Cruising Coordrdinate 541 of 768
#
# Cruising Coordrdinate 542 of 768
#
# Cruising Coordrdinate 543 of 768
#
# Cruising Coordrdinate 544 of 768
#
# Cruising Coordrdinate 545 of 768
#
# Cruising Coordrdinate 546 of 768
#
# Cruising Coordrdinate 547 of 768
#
# Cruising Coordrdinate 548 of 768
#
# Cruising Coordrdinate 549 of 768
#
# Cruising Coordrdinate 550 of 768
#
# Cruising Coordrdinate 551 of 768
#
# Cruising Coordrdinate 552 of 768
#
# Cruising Coordrdinate 553 of 768
#
# Cruising Coordrdinate 554 of 768
#
# Cruising Coordrdinate 555 of 768
#
# Cruising Coordrdinate 556 of 768
#
# Cruising Coordrdinate 557 of 768
#
# Cruising Coordrdinate 558 of 768
#
# Cruising Coordrdinate 559 of 768
#
# Cruising Coordrdinate 560 of 768
#
# Cruising Coordrdinate 561 of 768
#
# Cruising Coordrdinate 562 of 768
#
# Cruising Coordrdinate 563 of 768
#
# Cruising Coordrdinate 564 of 768
#
# Cruising Coordrdinate 565 of 768
#
# Cruising Coordrdinate 566 of 768
#
# Cruising Coordrdinate 567 of 768
#
# Cruising Coordrdinate 568 of 768
#
# Cruising Coordrdinate 569 of 768
#
# Cruising Coordrdinate 570 of 768
#
# Cruising Coordrdinate 571 of 768
#
# Cruising Coordrdinate 572 of 768
#
# Cruising Coordrdinate 573 of 768
#
# Cruising Coordrdinate 574 of 768
#
# Cruising Coordrdinate 575 of 768
#
# Cruising Coordrdinate 576 of 768
#
# Cruising Coordrdinate 577 of 768
#
# Cruising Coordrdinate 578 of 768
#
# Cruising Coordrdinate 579 of 768
#
# Cruising Coordrdinate 580 of 768
#
# Cruising Coordrdinate 581 of 768
#
# Cruising Coordrdinate 582 of 768
#
# Cruising Coordrdinate 583 of 768
#
# Cruising Coordrdinate 584 of 768
#
# Cruising Coordrdinate 585 of 768
#
# Cruising Coordrdinate 586 of 768
#
# Cruising Coordrdinate 587 of 768
#
# Cruising Coordrdinate 588 of 768
#
# Cruising Coordrdinate 589 of 768
#
# Cruising Coordrdinate 590 of 768
#
# Cruising Coordrdinate 591 of 768
#
# Cruising Coordrdinate 592 of 768
#
# Cruising Coordrdinate 593 of 768
#
# Cruising Coordrdinate 594 of 768
#
# Cruising Coordrdinate 595 of 768
#
# Cruising Coordrdinate 596 of 768
#
# Cruising Coordrdinate 597 of 768
#
# Cruising Coordrdinate 598 of 768
#
# Cruising Coordrdinate 599 of 768
#
# Cruising Coordrdinate 600 of 768
#
# Cruising Coordrdinate 601 of 768
#
# Cruising Coordrdinate 602 of 768
#
# Cruising Coordrdinate 603 of 768
#
# Cruising Coordrdinate 604 of 768
#
# Cruising Coordrdinate 605 of 768
#
# Cruising Coordrdinate 606 of 768
#
# Cruising Coordrdinate 607 of 768
#
# Cruising Coordrdinate 608 of 768
#
# Cruising Coordrdinate 609 of 768
#
# Cruising Coordrdinate 610 of 768
#
# Cruising Coordrdinate 611 of 768
#
# Cruising Coordrdinate 612 of 768
#
# Cruising Coordrdinate 613 of 768
#
# Cruising Coordrdinate 614 of 768
#
# Cruising Coordrdinate 615 of 768
#
# Cruising Coordrdinate 616 of 768
#
# Cruising Coordrdinate 617 of 768
#
# Cruising Coordrdinate 618 of 768
#
# Cruising Coordrdinate 619 of 768
#
# Cruising Coordrdinate 620 of 768
#
# Cruising Coordrdinate 621 of 768
#
# Cruising Coordrdinate 622 of 768
#
# Cruising Coordrdinate 623 of 768
#
# Cruising Coordrdinate 624 of 768
#
# Cruising Coordrdinate 625 of 768
#
# Cruising Coordrdinate 626 of 768
#
# Cruising Coordrdinate 627 of 768
#
# Cruising Coordrdinate 628 of 768
#
# Cruising Coordrdinate 629 of 768
#
# Cruising Coordrdinate 630 of 768
#
# Cruising Coordrdinate 631 of 768
#
# Cruising Coordrdinate 632 of 768
#
# Cruising Coordrdinate 633 of 768
#
# Cruising Coordrdinate 634 of 768
#
# Cruising Coordrdinate 635 of 768
#
# Cruising Coordrdinate 636 of 768
#
# Cruising Coordrdinate 637 of 768
#
# Cruising Coordrdinate 638 of 768
#
# Cruising Coordrdinate 639 of 768
#
# Cruising Coordrdinate 640 of 768
#
# Cruising Coordrdinate 641 of 768
#
# Cruising Coordrdinate 642 of 768
#
# Cruising Coordrdinate 643 of 768
#
# Cruising Coordrdinate 644 of 768
#
# Cruising Coordrdinate 645 of 768
#
# Cruising Coordrdinate 646 of 768
#
# Cruising Coordrdinate 647 of 768
#
# Cruising Coordrdinate 648 of 768
#
# Cruising Coordrdinate 649 of 768
#
# Cruising Coordrdinate 650 of 768
#
# Cruising Coordrdinate 651 of 768
#
# Cruising Coordrdinate 652 of 768
#
# Cruising Coordrdinate 653 of 768
#
# Cruising Coordrdinate 654 of 768
#
# Cruising Coordrdinate 655 of 768
#
# Cruising Coordrdinate 656 of 768
#
# Cruising Coordrdinate 657 of 768
#
# Cruising Coordrdinate 658 of 768
#
# Cruising Coordrdinate 659 of 768
#
# Cruising Coordrdinate 660 of 768
#
# Cruising Coordrdinate 661 of 768
#
# Cruising Coordrdinate 662 of 768
#
# Cruising Coordrdinate 663 of 768
#
# Cruising Coordrdinate 664 of 768
#
# Cruising Coordrdinate 665 of 768
#
# Cruising Coordrdinate 666 of 768
#
# Cruising Coordrdinate 667 of 768
#
# Cruising Coordrdinate 668 of 768
#
# Cruising Coordrdinate 669 of 768
#
# Cruising Coordrdinate 670 of 768
#
# Cruising Coordrdinate 671 of 768
#
# Cruising Coordrdinate 672 of 768
#
# Cruising Coordrdinate 673 of 768
#
# Cruising Coordrdinate 674 of 768
#
# Cruising Coordrdinate 675 of 768
#
# Cruising Coordrdinate 676 of 768
#
# Cruising Coordrdinate 677 of 768
#
# Cruising Coordrdinate 678 of 768
#
# Cruising Coordrdinate 679 of 768
#
# Cruising Coordrdinate 680 of 768
#
# Cruising Coordrdinate 681 of 768
#
# Cruising Coordrdinate 682 of 768
#
# Cruising Coordrdinate 683 of 768
#
# Cruising Coordrdinate 684 of 768
#
# Cruising Coordrdinate 685 of 768
#
# Cruising Coordrdinate 686 of 768
#
# Cruising Coordrdinate 687 of 768
#
# Cruising Coordrdinate 688 of 768
#
# Cruising Coordrdinate 689 of 768
#
# Cruising Coordrdinate 690 of 768
#
# Cruising Coordrdinate 691 of 768
#
# Cruising Coordrdinate 692 of 768
#
# Cruising Coordrdinate 693 of 768
#
# Cruising Coordrdinate 694 of 768
#
# Cruising Coordrdinate 695 of 768
#
# Cruising Coordrdinate 696 of 768
#
# Cruising Coordrdinate 697 of 768
#
# Cruising Coordrdinate 698 of 768
#
# Cruising Coordrdinate 699 of 768
#
# Cruising Coordrdinate 700 of 768
#
# Cruising Coordrdinate 701 of 768
#
# Cruising Coordrdinate 702 of 768
#
# Cruising Coordrdinate 703 of 768
#
# Cruising Coordrdinate 704 of 768
#
# Cruising Coordrdinate 705 of 768
#
# Cruising Coordrdinate 706 of 768
#
# Cruising Coordrdinate 707 of 768
#
# Cruising Coordrdinate 708 of 768
#
# Cruising Coordrdinate 709 of 768
#
# Cruising Coordrdinate 710 of 768
#
# Cruising Coordrdinate 711 of 768
#
# Cruising Coordrdinate 712 of 768
#
# Cruising Coordrdinate 713 of 768
#
# Cruising Coordrdinate 714 of 768
#
# Cruising Coordrdinate 715 of 768
#
# Cruising Coordrdinate 716 of 768
#
# Cruising Coordrdinate 717 of 768
#
# Cruising Coordrdinate 718 of 768
#
# Cruising Coordrdinate 719 of 768
#
# Cruising Coordrdinate 720 of 768
#
# Cruising Coordrdinate 721 of 768
#
# Cruising Coordrdinate 722 of 768
#
# Cruising Coordrdinate 723 of 768
#
# Cruising Coordrdinate 724 of 768
#
# Cruising Coordrdinate 725 of 768
#
# Cruising Coordrdinate 726 of 768
#
# Cruising Coordrdinate 727 of 768
#
# Cruising Coordrdinate 728 of 768
#
# Cruising Coordrdinate 729 of 768
#
# Cruising Coordrdinate 730 of 768
#
# Cruising Coordrdinate 731 of 768
#
# Cruising Coordrdinate 732 of 768
#
# Cruising Coordrdinate 733 of 768
#
# Cruising Coordrdinate 734 of 768
#
# Cruising Coordrdinate 735 of 768
#
# Cruising Coordrdinate 736 of 768
#
# Cruising Coordrdinate 737 of 768
#
# Cruising Coordrdinate 738 of 768
#
# Cruising Coordrdinate 739 of 768
#
# Cruising Coordrdinate 740 of 768
#
# Cruising Coordrdinate 741 of 768
#
# Cruising Coordrdinate 742 of 768
#
# Cruising Coordrdinate 743 of 768
#
# Cruising Coordrdinate 744 of 768
#
# Cruising Coordrdinate 745 of 768
#
# Cruising Coordrdinate 746 of 768
#
# Cruising Coordrdinate 747 of 768
#
# Cruising Coordrdinate 748 of 768
#
# Cruising Coordrdinate 749 of 768
#
# Cruising Coordrdinate 750 of 768
#
# Cruising Coordrdinate 751 of 768
#
# Cruising Coordrdinate 752 of 768
#
# Cruising Coordrdinate 753 of 768
#
# Cruising Coordrdinate 754 of 768
#
# Cruising Coordrdinate 755 of 768
#
# Cruising Coordrdinate 756 of 768
#
# Cruising Coordrdinate 757 of 768
#
# Cruising Coordrdinate 758 of 768
#
# Cruising Coordrdinate 759 of 768
#
# Cruising Coordrdinate 760 of 768
#
# Cruising Coordrdinate 761 of 768
#
# Cruising Coordrdinate 762 of 768
#
# Cruising Coordrdinate 763 of 768
#
# Cruising Coordrdinate 764 of 768
#
# Cruising Coordrdinate 765 of 768
#
# Cruising Coordrdinate 766 of 768
#
# Cruising Coordrdinate 767 of 768
#
# Cruising Coordrdinate 768 of 768
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (1, 4, 3, 2, 2, 3, 18), which had val score of 0.5933
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 2, 3, 18), which had val score of 0.6038
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 3, 3, 2, 2, 3, 18), which had val score of 0.5839
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 5, 3, 2, 2, 3, 18), which had val score of 0.5891
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 2, 2, 2, 3, 18), which had val score of 0.5912
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 3, 1, 2, 3, 18), which had val score of 0.5818
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 3, 3, 2, 3, 18), which had val score of 0.5744
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 1, 3, 18), which had val score of 0.588
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 3, 3, 18), which had val score of 0.5964
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 2, 2, 18), which had val score of 0.5776
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 2, 4, 18), which had val score of 0.5409
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 2, 3, 17), which had val score of 0.6048
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 2, 3, 19), which had val score of 0.5786
#         Current best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.6195.
#         Has trained 886 of 483840 combinations so far
# % Combos Checked Thus Far: 886 out of 483840 which is 0.183118%
# TUNING FINISHED
#
# Max Score:
#  0.619497
# Max Combo:
#  (2, 4, 3, 2, 2, 3, 18)
# % Combos Checked: 886 out of 483840 which is 0.183118%

# %%
yangzhou.view_best_combo_and_score()
# Out:
# (Current) Best combo: (2, 4, 3, 2, 2, 3, 18) with val score 0.619497
