# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'EXTRFR'
TUNING_MODEL = 'guangan'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import GuangAn_H2H

# %%
guangan = GuangAn_H2H.GuangAn()
# Out:
# GuangAn Initialised

# %%
from sklearn.ensemble import ExtraTreesRegressor as EXTRFR

# %%
guangan.read_in_model(EXTRFR, 'Regression')
# Out:
# Successfully read in model <class 'sklearn.ensemble._forest.ExtraTreesRegressor'>, which is a Regression model

# %%
guangan.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': set(range(25, 401)),
    'max_depth': set(range(3, 193)),
    'max_samples': (0.40, 0.85),
    'max_features': (0.4, 0.85),
    'ccp_alpha': (-8, -1)
}

# %%
guangan.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
guangan.read_in_transform({'ccp_alpha': '10^'})
# Out:
# Updated transform dictionary: {'n_estimators': False, 'max_depth': False, 'max_samples': False, 'max_features': False, 'ccp_alpha': '10^'}

# %%
guangan.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1, 'bootstrap': True})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
guangan.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  guangan.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv', f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 4161 rows
# True

# %%
guangan.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
guangan.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
guangan.train_other_info = train_other_info
guangan.val_other_info = val_other_info
guangan.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
guangan.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 104, 'max_samples': 0.6671875, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6111
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 104, 'max_samples': 0.6671875, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6111
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 104, 'max_samples': 0.6671875, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6111
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 104, 'max_samples': 0.6671875, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6111
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 99, 'max_depth': 103, 'max_samples': 0.663671875, 'max_features': 0.607421875, 'ccp_alpha': -7.8359375, 'features': 31}, which had val score of 0.5776
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Pred centre score: 0.6053322735195591
# Actual centre score: 0.5775681341719078
#
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 105, 'max_depth': 100, 'max_samples': 0.656640625, 'max_features': 0.6003906250000001, 'ccp_alpha': -7.9453125, 'features': 31}, which had val score of 0.6059
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Pred centre score: 0.5998606221399481
# Actual centre score: 0.6058700209643606
#
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 105, 'max_depth': 100, 'max_samples': 0.656640625, 'max_features': 0.6003906250000001, 'ccp_alpha': -7.8359375, 'features': 31}, which had val score of 0.6059
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Pred centre score: 0.5998607363737988
# Actual centre score: 0.6058700209643606
#
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 105, 'max_depth': 100, 'max_samples': 0.656640625, 'max_features': 0.607421875, 'ccp_alpha': -7.9453125, 'features': 31}, which had val score of 0.6059
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Pred centre score: 0.5998604880197455
# Actual centre score: 0.6058700209643606
#
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.5912
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 31}, which had val score of 0.6006
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 105, 'max_depth': 100, 'max_samples': 0.656640625, 'max_features': 0.607421875, 'ccp_alpha': -7.8359375, 'features': 31}, which had val score of 0.6059
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Pred centre score: 0.5998606005384602
# Actual centre score: 0.6058700209643606
#
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 31}, which had val score of 0.6038
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4161 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.6671875, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 31}, which had val score of 0.6111
# ...
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.6671875, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.6671875, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.6671875, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 104, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6132
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 104, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 32}, which had val score of 0.6132
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 104, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6132
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 104, 'max_samples': 0.66015625, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 32}, which had val score of 0.6132
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 104, 'max_samples': 0.6671875, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 104, 'max_samples': 0.6671875, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.78125, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 104, 'max_samples': 0.6671875, 'max_features': 0.6109375, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 104, 'max_samples': 0.6671875, 'max_features': 0.6109375, 'ccp_alpha': -7.78125, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4220 combinations so far
# Trained and Tested combination 4221: {'n_estimators': [105], 'max_depth': [103], 'max_samples': [0.663671875], 'max_features': [0.607421875], 'ccp_alpha': [1.4590242156305607e-08], 'features': [32]}, taking 132.71 seconds to get val score of 0.6143
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63
# Pred centre score: 0.612862448470148
# Actual centre score: 0.6142557651991614
#
# FIT!
#
# Begin Cruise
# Cruise Round
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.5996
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.5996
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.5891
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.5891
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.6143
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6143
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6153
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.5996
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.5996
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.5891
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.5891
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.6143
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 102, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6143
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.6101
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6101
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.5996
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.5996
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.5807
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.5807
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.6132
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 98, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6132
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.6101
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6101
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.5996
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.653125, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.5996
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.5807
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.596875, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.5807
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -8.0, 'features': 32}, which had val score of 0.6132
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 108, 'max_depth': 101, 'max_samples': 0.66015625, 'max_features': 0.6039062500000001, 'ccp_alpha': -7.890625, 'features': 32}, which had val score of 0.6132
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# Already Trained and Tested combination {'n_estimators': 105, 'max_depth': 100, 'max_samples': 0.656640625, 'max_features': 0.6003906250000001, 'ccp_alpha': -7.9453125, 'features': 32}, which had val score of 0.6164
#         Current best combo: (25, 98, 0.7375, 0.5125, -8.0, 18) with val score 0.63.
#         Has trained 4221 combinations so far
# TUNING FINISHED
#
# Max Score:
#  0.6299790356394129
# Max Test Score:
#  0.629979
# Max Combo Index:
#  (25, 98, 0.7375, 0.5125, -8.0, 18)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 98, 'max_samples': 0.7375, 'max_features': 0.5125, 'ccp_alpha': -8.0, 'features': 18}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances', 'Tackles Inside 50', 'Rebound 50s', 'One Percenters', 'Goal Assists', 'Uncontested Possessions', 'Frees Agains')
# # Combos Checked: 4221

# %%
guangan.view_best_combo_and_score()
# Out:
# Max Score:
#  0.6299790356394129
# Max Test Score:
#  0.629979
# Max Combo Index:
#  (25, 98, 0.7375, 0.5125, -8.0, 18)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 98, 'max_samples': 0.7375, 'max_features': 0.5125, 'ccp_alpha': -8.0, 'features': 18}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances', 'Tackles Inside 50', 'Rebound 50s', 'One Percenters', 'Goal Assists', 'Uncontested Possessions', 'Frees Agains')
# # Combos Checked: 4221
