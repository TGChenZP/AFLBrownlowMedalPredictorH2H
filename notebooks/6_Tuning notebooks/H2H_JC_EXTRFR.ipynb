# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'EXTRFR'
TUNING_MODEL = 'jiaocheng'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import JiaoCheng_H2H

# %%
jiaocheng = JiaoCheng_H2H.JiaoCheng()
# Out:
# JiaoCheng Initialised

# %%
from sklearn.ensemble import ExtraTreesRegressor as EXTRFR

# %%
jiaocheng.read_in_model(EXTRFR, 'Regression')
# Out:
# Successfully read in model <class 'sklearn.ensemble._forest.ExtraTreesRegressor'>, which is a Regression model

# %%
jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85),
    'max_features': (0.4, 0.55, 0.7, 0.85),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# %%
jiaocheng.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1, 'bootstrap': True})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
jiaocheng.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
jiaocheng.set_tuning_order(['features', 'max_depth', 'max_features', 'max_samples', 'n_estimators', 'ccp_alpha'])

# %%
jiaocheng.set_hyperparameter_default_values({
    'features': 0,
    'n_estimators': 50,
    'max_depth': 12,
    'max_samples': 0.7,
    'max_features': 0.7,
    'ccp_alpha': 0.01})

# %%
try:
  jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
  print('True')
except:
  print('False')
# Out:
# False

# %%
jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
jiaocheng.train_other_info = train_other_info
jiaocheng.val_other_info = val_other_info
jiaocheng.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
jiaocheng.tune()
# Out:
# Default combo: [1, 2, 2, 2, 3, 0]
#
#
# ROUND 1
#
# Round 2
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 1 of 100800: (1, 2, 2, 2, 3, 0), taking 7.6 seconds to get val score of 0.5828
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 2 of 100800: (1, 2, 2, 2, 3, 1), taking 6.46 seconds to get val score of 0.5807
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 3 of 100800: (1, 2, 2, 2, 3, 2), taking 7.53 seconds to get val score of 0.5713
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 4 of 100800: (1, 2, 2, 2, 3, 3), taking 8.56 seconds to get val score of 0.5723
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 5 of 100800: (1, 2, 2, 2, 3, 4), taking 8.0 seconds to get val score of 0.5765
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 6 of 100800: (1, 2, 2, 2, 3, 5), taking 10.21 seconds to get val score of 0.5734
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 7 of 100800: (1, 2, 2, 2, 3, 6), taking 12.81 seconds to get val score of 0.5744
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 8 of 100800: (1, 2, 2, 2, 3, 7), taking 13.16 seconds to get val score of 0.5734
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 9 of 100800: (1, 2, 2, 2, 3, 8), taking 13.79 seconds to get val score of 0.5765
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 10 of 100800: (1, 2, 2, 2, 3, 9), taking 15.84 seconds to get val score of 0.5765
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 11 of 100800: (1, 2, 2, 2, 3, 10), taking 16.76 seconds to get val score of 0.5702
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 12 of 100800: (1, 2, 2, 2, 3, 11), taking 17.41 seconds to get val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 13 of 100800: (1, 2, 2, 2, 3, 12), taking 19.61 seconds to get val score of 0.5776
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 14 of 100800: (1, 2, 2, 2, 3, 13), taking 19.4 seconds to get val score of 0.5786
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 15 of 100800: (1, 2, 2, 2, 3, 14), taking 19.77 seconds to get val score of 0.5744
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 16 of 100800: (1, 2, 2, 2, 3, 15), taking 21.93 seconds to get val score of 0.5765
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 17 of 100800: (1, 2, 2, 2, 3, 16), taking 24.0 seconds to get val score of 0.5723
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 18 of 100800: (1, 2, 2, 2, 3, 17), taking 26.01 seconds to get val score of 0.5776
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 19 of 100800: (1, 2, 2, 2, 3, 18), taking 27.43 seconds to get val score of 0.5744
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 20 of 100800: (1, 2, 2, 2, 3, 19), taking 26.24 seconds to get val score of 0.5692
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 21 of 100800: (1, 2, 2, 2, 3, 20), taking 29.8 seconds to get val score of 0.5807
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 22 of 100800: (1, 2, 2, 2, 3, 21), taking 29.66 seconds to get val score of 0.5828
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 23 of 100800: (1, 2, 2, 2, 3, 22), taking 34.11 seconds to get val score of 0.5639
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 24 of 100800: (1, 2, 2, 2, 3, 23), taking 32.02 seconds to get val score of 0.5755
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 25 of 100800: (1, 2, 2, 2, 3, 24), taking 32.28 seconds to get val score of 0.5828
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 26 of 100800: (1, 2, 2, 2, 3, 25), taking 33.66 seconds to get val score of 0.5692
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 27 of 100800: (1, 2, 2, 2, 3, 26), taking 36.39 seconds to get val score of 0.5681
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 28 of 100800: (1, 2, 2, 2, 3, 27), taking 36.57 seconds to get val score of 0.5713
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 29 of 100800: (1, 2, 2, 2, 3, 28), taking 38.01 seconds to get val score of 0.5755
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 30 of 100800: (1, 2, 2, 2, 3, 29), taking 39.09 seconds to get val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 31 of 100800: (1, 2, 2, 2, 3, 30), taking 40.25 seconds to get val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 32 of 100800: (1, 2, 2, 2, 3, 31), taking 36.81 seconds to get val score of 0.5765
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 33 of 100800: (1, 2, 2, 2, 3, 32), taking 41.17 seconds to get val score of 0.5807
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 34 of 100800: (1, 2, 2, 2, 3, 33), taking 44.83 seconds to get val score of 0.5765
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 35 of 100800: (1, 2, 2, 2, 3, 34), taking 43.9 seconds to get val score of 0.5723
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 36 of 100800: (1, 2, 2, 2, 3, 35), taking 44.38 seconds to get val score of 0.5629
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 3, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 37 of 100800: (1, 0, 2, 2, 3, 0), taking 2.36 seconds to get val score of 0.5744
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 38 of 100800: (1, 1, 2, 2, 3, 0), taking 2.48 seconds to get val score of 0.5765
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Already Trained and Tested combination (1, 2, 2, 2, 3, 0), which had val score of 0.5828
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828.
#         Has trained 38 of 100800 combinations so far
# Trained and Tested combination 39 of 100800: (1, 3, 2, 2, 3, 0), taking 46.08 seconds to get val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 40 of 100800: (1, 4, 2, 2, 3, 0), taking 48.62 seconds to get val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 41 of 100800: (1, 5, 2, 2, 3, 0), taking 46.2 seconds to get val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
# Trained and Tested combination 42 of 100800: (1, 6, 2, 2, 3, 0), taking 46.43 seconds to get val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 3, 0) with val score 0.5828
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 3, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_features (index: 3)
#
# Trained and Tested combination 43 of 100800: (1, 2, 2, 0, 3, 0), taking 3.95 seconds to get val score of 0.5839
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839
# Trained and Tested combination 44 of 100800: (1, 2, 2, 1, 3, 0), taking 3.06 seconds to get val score of 0.5839
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839
# Already Trained and Tested combination (1, 2, 2, 2, 3, 0), which had val score of 0.5828
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839.
#         Has trained 44 of 100800 combinations so far
# Trained and Tested combination 45 of 100800: (1, 2, 2, 3, 3, 0), taking 7.24 seconds to get val score of 0.5828
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839
#
# Best combo after this hyperparameter: (1, 2, 2, 0, 3, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_samples (index: 2)
#
# Trained and Tested combination 46 of 100800: (1, 2, 0, 0, 3, 0), taking 2.39 seconds to get val score of 0.5713
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839
# Trained and Tested combination 47 of 100800: (1, 2, 1, 0, 3, 0), taking 2.89 seconds to get val score of 0.5797
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839
# Already Trained and Tested combination (1, 2, 2, 0, 3, 0), which had val score of 0.5839
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839.
#         Has trained 47 of 100800 combinations so far
# Trained and Tested combination 48 of 100800: (1, 2, 3, 0, 3, 0), taking 4.86 seconds to get val score of 0.5818
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839
#
# Best combo after this hyperparameter: (1, 2, 2, 0, 3, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 49 of 100800: (0, 2, 2, 0, 3, 0), taking 3.25 seconds to get val score of 0.5671
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839
# Already Trained and Tested combination (1, 2, 2, 0, 3, 0), which had val score of 0.5839
#         Current best combo: (1, 2, 2, 0, 3, 0) with val score 0.5839.
#         Has trained 49 of 100800 combinations so far
# Trained and Tested combination 50 of 100800: (2, 2, 2, 0, 3, 0), taking 8.44 seconds to get val score of 0.587
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587
# Trained and Tested combination 51 of 100800: (3, 2, 2, 0, 3, 0), taking 14.86 seconds to get val score of 0.5776
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587
# Trained and Tested combination 52 of 100800: (4, 2, 2, 0, 3, 0), taking 28.4 seconds to get val score of 0.5713
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587
#
# Best combo after this hyperparameter: (2, 2, 2, 0, 3, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ccp_alpha (index: 4)
#
# Trained and Tested combination 53 of 100800: (2, 2, 2, 0, 0, 0), taking 5.99 seconds to get val score of 0.5734
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587
# Trained and Tested combination 54 of 100800: (2, 2, 2, 0, 1, 0), taking 6.17 seconds to get val score of 0.5734
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587
# Trained and Tested combination 55 of 100800: (2, 2, 2, 0, 2, 0), taking 6.42 seconds to get val score of 0.5797
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587
# Already Trained and Tested combination (2, 2, 2, 0, 3, 0), which had val score of 0.587
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587.
#         Has trained 55 of 100800 combinations so far
# Trained and Tested combination 56 of 100800: (2, 2, 2, 0, 4, 0), taking 6.45 seconds to get val score of 0.5577
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587
#
# Best combo after this hyperparameter: (2, 2, 2, 0, 3, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 3
# Hyperparameter: features (index: 5)
#
# Already Trained and Tested combination (2, 2, 2, 0, 3, 0), which had val score of 0.587
#         Current best combo: (2, 2, 2, 0, 3, 0) with val score 0.587.
#         Has trained 56 of 100800 combinations so far
# Trained and Tested combination 57 of 100800: (2, 2, 2, 0, 3, 1), taking 8.13 seconds to get val score of 0.5964
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 58 of 100800: (2, 2, 2, 0, 3, 2), taking 12.73 seconds to get val score of 0.5702
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 59 of 100800: (2, 2, 2, 0, 3, 3), taking 11.15 seconds to get val score of 0.5786
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 60 of 100800: (2, 2, 2, 0, 3, 4), taking 9.78 seconds to get val score of 0.5797
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 61 of 100800: (2, 2, 2, 0, 3, 5), taking 17.43 seconds to get val score of 0.5818
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 62 of 100800: (2, 2, 2, 0, 3, 6), taking 17.08 seconds to get val score of 0.5828
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 63 of 100800: (2, 2, 2, 0, 3, 7), taking 18.7 seconds to get val score of 0.587
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 64 of 100800: (2, 2, 2, 0, 3, 8), taking 18.23 seconds to get val score of 0.5922
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 65 of 100800: (2, 2, 2, 0, 3, 9), taking 21.7 seconds to get val score of 0.5891
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 66 of 100800: (2, 2, 2, 0, 3, 10), taking 23.43 seconds to get val score of 0.5786
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 67 of 100800: (2, 2, 2, 0, 3, 11), taking 23.44 seconds to get val score of 0.5881
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 68 of 100800: (2, 2, 2, 0, 3, 12), taking 25.86 seconds to get val score of 0.5786
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 69 of 100800: (2, 2, 2, 0, 3, 13), taking 26.78 seconds to get val score of 0.587
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 70 of 100800: (2, 2, 2, 0, 3, 14), taking 27.47 seconds to get val score of 0.5807
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 71 of 100800: (2, 2, 2, 0, 3, 15), taking 30.67 seconds to get val score of 0.5765
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 72 of 100800: (2, 2, 2, 0, 3, 16), taking 29.07 seconds to get val score of 0.5807
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 73 of 100800: (2, 2, 2, 0, 3, 17), taking 32.51 seconds to get val score of 0.5849
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 74 of 100800: (2, 2, 2, 0, 3, 18), taking 34.32 seconds to get val score of 0.5797
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 75 of 100800: (2, 2, 2, 0, 3, 19), taking 35.26 seconds to get val score of 0.5734
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 76 of 100800: (2, 2, 2, 0, 3, 20), taking 35.36 seconds to get val score of 0.5849
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 77 of 100800: (2, 2, 2, 0, 3, 21), taking 36.16 seconds to get val score of 0.5755
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 78 of 100800: (2, 2, 2, 0, 3, 22), taking 40.66 seconds to get val score of 0.5786
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 79 of 100800: (2, 2, 2, 0, 3, 23), taking 40.97 seconds to get val score of 0.5849
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 80 of 100800: (2, 2, 2, 0, 3, 24), taking 39.52 seconds to get val score of 0.5839
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 81 of 100800: (2, 2, 2, 0, 3, 25), taking 46.15 seconds to get val score of 0.5839
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 82 of 100800: (2, 2, 2, 0, 3, 26), taking 45.76 seconds to get val score of 0.5881
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 83 of 100800: (2, 2, 2, 0, 3, 27), taking 49.6 seconds to get val score of 0.5891
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 84 of 100800: (2, 2, 2, 0, 3, 28), taking 45.36 seconds to get val score of 0.5776
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 85 of 100800: (2, 2, 2, 0, 3, 29), taking 48.84 seconds to get val score of 0.5765
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 86 of 100800: (2, 2, 2, 0, 3, 30), taking 51.71 seconds to get val score of 0.5776
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 87 of 100800: (2, 2, 2, 0, 3, 31), taking 51.17 seconds to get val score of 0.566
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 88 of 100800: (2, 2, 2, 0, 3, 32), taking 53.95 seconds to get val score of 0.5849
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 89 of 100800: (2, 2, 2, 0, 3, 33), taking 52.98 seconds to get val score of 0.5786
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 90 of 100800: (2, 2, 2, 0, 3, 34), taking 56.37 seconds to get val score of 0.586
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
# Trained and Tested combination 91 of 100800: (2, 2, 2, 0, 3, 35), taking 58.51 seconds to get val score of 0.5849
#         Current best combo: (2, 2, 2, 0, 3, 1) with val score 0.5964
#
# Best combo after this hyperparameter: (2, 2, 2, 0, 3, 1) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 92 of 100800: (2, 0, 2, 0, 3, 1), taking 2.08 seconds to get val score of 0.5985
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 93 of 100800: (2, 1, 2, 0, 3, 1), taking 4.6 seconds to get val score of 0.5881
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Already Trained and Tested combination (2, 2, 2, 0, 3, 1), which had val score of 0.5964
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985.
#         Has trained 93 of 100800 combinations so far
# Trained and Tested combination 94 of 100800: (2, 3, 2, 0, 3, 1), taking 189.68 seconds to get val score of 0.5755
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 95 of 100800: (2, 4, 2, 0, 3, 1), taking 348.99 seconds to get val score of 0.587
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 96 of 100800: (2, 5, 2, 0, 3, 1), taking 353.9 seconds to get val score of 0.587
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 97 of 100800: (2, 6, 2, 0, 3, 1), taking 353.61 seconds to get val score of 0.587
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
#
# Best combo after this hyperparameter: (2, 0, 2, 0, 3, 1) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_features (index: 3)
#
# Already Trained and Tested combination (2, 0, 2, 0, 3, 1), which had val score of 0.5985
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985.
#         Has trained 97 of 100800 combinations so far
# Trained and Tested combination 98 of 100800: (2, 0, 2, 1, 3, 1), taking 2.78 seconds to get val score of 0.5807
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 99 of 100800: (2, 0, 2, 2, 3, 1), taking 4.61 seconds to get val score of 0.5807
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 100 of 100800: (2, 0, 2, 3, 3, 1), taking 3.17 seconds to get val score of 0.5807
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
#
# Best combo after this hyperparameter: (2, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_samples (index: 2)
#
# Trained and Tested combination 101 of 100800: (2, 0, 0, 0, 3, 1), taking 2.53 seconds to get val score of 0.5933
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 102 of 100800: (2, 0, 1, 0, 3, 1), taking 2.03 seconds to get val score of 0.5933
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Already Trained and Tested combination (2, 0, 2, 0, 3, 1), which had val score of 0.5985
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985.
#         Has trained 102 of 100800 combinations so far
# Trained and Tested combination 103 of 100800: (2, 0, 3, 0, 3, 1), taking 3.41 seconds to get val score of 0.5933
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
#
# Best combo after this hyperparameter: (2, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 104 of 100800: (0, 0, 2, 0, 3, 1), taking 0.53 seconds to get val score of 0.566
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 105 of 100800: (1, 0, 2, 0, 3, 1), taking 1.2 seconds to get val score of 0.5797
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Already Trained and Tested combination (2, 0, 2, 0, 3, 1), which had val score of 0.5985
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985.
#         Has trained 105 of 100800 combinations so far
# Trained and Tested combination 106 of 100800: (3, 0, 2, 0, 3, 1), taking 4.44 seconds to get val score of 0.5912
#         Current best combo: (2, 0, 2, 0, 3, 1) with val score 0.5985
# Trained and Tested combination 107 of 100800: (4, 0, 2, 0, 3, 1), taking 10.09 seconds to get val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
#
# Best combo after this hyperparameter: (4, 0, 2, 0, 3, 1) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: ccp_alpha (index: 4)
#
# Trained and Tested combination 108 of 100800: (4, 0, 2, 0, 0, 1), taking 9.63 seconds to get val score of 0.5912
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 109 of 100800: (4, 0, 2, 0, 1, 1), taking 10.66 seconds to get val score of 0.5912
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 110 of 100800: (4, 0, 2, 0, 2, 1), taking 9.9 seconds to get val score of 0.5912
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Already Trained and Tested combination (4, 0, 2, 0, 3, 1), which had val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 110 of 100800 combinations so far
# Trained and Tested combination 111 of 100800: (4, 0, 2, 0, 4, 1), taking 10.9 seconds to get val score of 0.5577
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
#
# Best combo after this hyperparameter: (4, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 3
#
# Round 4
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 112 of 100800: (4, 0, 2, 0, 3, 0), taking 9.96 seconds to get val score of 0.5839
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Already Trained and Tested combination (4, 0, 2, 0, 3, 1), which had val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 112 of 100800 combinations so far
# Trained and Tested combination 113 of 100800: (4, 0, 2, 0, 3, 2), taking 11.73 seconds to get val score of 0.586
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 114 of 100800: (4, 0, 2, 0, 3, 3), taking 12.62 seconds to get val score of 0.5985
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 115 of 100800: (4, 0, 2, 0, 3, 4), taking 11.99 seconds to get val score of 0.5776
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 116 of 100800: (4, 0, 2, 0, 3, 5), taking 14.38 seconds to get val score of 0.5734
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 117 of 100800: (4, 0, 2, 0, 3, 6), taking 16.45 seconds to get val score of 0.5818
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 118 of 100800: (4, 0, 2, 0, 3, 7), taking 20.23 seconds to get val score of 0.5818
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 119 of 100800: (4, 0, 2, 0, 3, 8), taking 19.57 seconds to get val score of 0.5828
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 120 of 100800: (4, 0, 2, 0, 3, 9), taking 16.61 seconds to get val score of 0.5849
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 121 of 100800: (4, 0, 2, 0, 3, 10), taking 21.03 seconds to get val score of 0.5881
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 122 of 100800: (4, 0, 2, 0, 3, 11), taking 20.57 seconds to get val score of 0.5849
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 123 of 100800: (4, 0, 2, 0, 3, 12), taking 24.53 seconds to get val score of 0.5849
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 124 of 100800: (4, 0, 2, 0, 3, 13), taking 22.07 seconds to get val score of 0.5922
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 125 of 100800: (4, 0, 2, 0, 3, 14), taking 22.42 seconds to get val score of 0.5692
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 126 of 100800: (4, 0, 2, 0, 3, 15), taking 26.98 seconds to get val score of 0.5797
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 127 of 100800: (4, 0, 2, 0, 3, 16), taking 26.75 seconds to get val score of 0.5807
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 128 of 100800: (4, 0, 2, 0, 3, 17), taking 29.03 seconds to get val score of 0.5776
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 129 of 100800: (4, 0, 2, 0, 3, 18), taking 30.73 seconds to get val score of 0.5975
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 130 of 100800: (4, 0, 2, 0, 3, 19), taking 30.31 seconds to get val score of 0.5734
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 131 of 100800: (4, 0, 2, 0, 3, 20), taking 34.15 seconds to get val score of 0.5901
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 132 of 100800: (4, 0, 2, 0, 3, 21), taking 32.03 seconds to get val score of 0.5744
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 133 of 100800: (4, 0, 2, 0, 3, 22), taking 37.1 seconds to get val score of 0.5639
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 134 of 100800: (4, 0, 2, 0, 3, 23), taking 40.33 seconds to get val score of 0.5839
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 135 of 100800: (4, 0, 2, 0, 3, 24), taking 38.7 seconds to get val score of 0.5786
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 136 of 100800: (4, 0, 2, 0, 3, 25), taking 40.68 seconds to get val score of 0.5901
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 137 of 100800: (4, 0, 2, 0, 3, 26), taking 41.25 seconds to get val score of 0.5818
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 138 of 100800: (4, 0, 2, 0, 3, 27), taking 45.86 seconds to get val score of 0.5881
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 139 of 100800: (4, 0, 2, 0, 3, 28), taking 44.7 seconds to get val score of 0.5891
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 140 of 100800: (4, 0, 2, 0, 3, 29), taking 42.15 seconds to get val score of 0.5807
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 141 of 100800: (4, 0, 2, 0, 3, 30), taking 47.38 seconds to get val score of 0.5723
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 142 of 100800: (4, 0, 2, 0, 3, 31), taking 47.11 seconds to get val score of 0.5849
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 143 of 100800: (4, 0, 2, 0, 3, 32), taking 52.4 seconds to get val score of 0.5765
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 144 of 100800: (4, 0, 2, 0, 3, 33), taking 51.03 seconds to get val score of 0.5881
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 145 of 100800: (4, 0, 2, 0, 3, 34), taking 51.09 seconds to get val score of 0.5713
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 146 of 100800: (4, 0, 2, 0, 3, 35), taking 53.58 seconds to get val score of 0.5912
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
#
# Best combo after this hyperparameter: (4, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (4, 0, 2, 0, 3, 1), which had val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 146 of 100800 combinations so far
# Trained and Tested combination 147 of 100800: (4, 1, 2, 0, 3, 1), taking 14.37 seconds to get val score of 0.5797
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 148 of 100800: (4, 2, 2, 0, 3, 1), taking 28.38 seconds to get val score of 0.5734
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 149 of 100800: (4, 3, 2, 0, 3, 1), taking 752.94 seconds to get val score of 0.5702
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 150 of 100800: (4, 4, 2, 0, 3, 1), taking 1396.51 seconds to get val score of 0.5797
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 151 of 100800: (4, 5, 2, 0, 3, 1), taking 1393.64 seconds to get val score of 0.5797
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 152 of 100800: (4, 6, 2, 0, 3, 1), taking 1389.46 seconds to get val score of 0.5797
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
#
# Best combo after this hyperparameter: (4, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: max_features (index: 3)
#
# Already Trained and Tested combination (4, 0, 2, 0, 3, 1), which had val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 152 of 100800 combinations so far
# Trained and Tested combination 153 of 100800: (4, 0, 2, 1, 3, 1), taking 11.9 seconds to get val score of 0.5849
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 154 of 100800: (4, 0, 2, 2, 3, 1), taking 12.28 seconds to get val score of 0.5849
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 155 of 100800: (4, 0, 2, 3, 3, 1), taking 14.32 seconds to get val score of 0.5818
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
#
# Best combo after this hyperparameter: (4, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: max_samples (index: 2)
#
# Trained and Tested combination 156 of 100800: (4, 0, 0, 0, 3, 1), taking 6.34 seconds to get val score of 0.5975
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Trained and Tested combination 157 of 100800: (4, 0, 1, 0, 3, 1), taking 9.4 seconds to get val score of 0.6006
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
# Already Trained and Tested combination (4, 0, 2, 0, 3, 1), which had val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 157 of 100800 combinations so far
# Trained and Tested combination 158 of 100800: (4, 0, 3, 0, 3, 1), taking 10.84 seconds to get val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038
#
# Best combo after this hyperparameter: (4, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 0, 2, 0, 3, 1), which had val score of 0.566
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 3, 1), which had val score of 0.5797
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
# Already Trained and Tested combination (2, 0, 2, 0, 3, 1), which had val score of 0.5985
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
# Already Trained and Tested combination (3, 0, 2, 0, 3, 1), which had val score of 0.5912
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 3, 1), which had val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: ccp_alpha (index: 4)
#
# Already Trained and Tested combination (4, 0, 2, 0, 0, 1), which had val score of 0.5912
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 1, 1), which had val score of 0.5912
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 2, 1), which had val score of 0.5912
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 3, 1), which had val score of 0.6038
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 4, 1), which had val score of 0.5577
#         Current best combo: (4, 0, 2, 0, 3, 1) with val score 0.6038.
#         Has trained 158 of 100800 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 2, 0, 3, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.6037735849056604
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-da8904d98750> in <cell line: 1>()
# ----> 1 jiaocheng.tune()
#
# /content/drive/My Drive/LAB/BrownlowH2H/PrivatePackages/JiaoCheng_H2H.py in tune(self, key_stats_only)
#     455
#     456         # Display final information
# --> 457         self.view_best_combo_and_score()
#     458
#     459
#
# /content/drive/My Drive/LAB/BrownlowH2H/PrivatePackages/JiaoCheng_H2H.py in view_best_combo_and_score(self)
#     760         elif self.clf_type == 'Regression':
#     761             max_val_id = self.tuning_result['Val Brownlow Metric'].idxmax()
# --> 762             print('Max Test Score: \n', self.tung_result.iloc[max_val_id]['Test Brownlow Metric'])
#     763
#     764         print('Max Combo Index: \n', self.best_combo, 'out of', self.n_items, '(note best combo is 0-indexed)')
#
# AttributeError: 'JiaoCheng' object has no attribute 'tung_result'

# %%
jiaocheng.view_best_combo_and_score()
