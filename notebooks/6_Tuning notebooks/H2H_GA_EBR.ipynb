# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'EBR'
TUNING_MODEL = 'guangan'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import GuangAn_H2H

# %%
guangan = GuangAn_H2H.GuangAn()
# Out:
# GuangAn Initialised

# %%
# !pip install interpret
# Out:
# Collecting interpret
#   Downloading interpret-0.4.4-py3-none-any.whl (1.4 kB)
# Collecting interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4 (from interpret)
#   Downloading interpret_core-0.4.4-py3-none-any.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 22.5 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (5.15.0)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (5.9.5)
# Collecting treeinterpreter>=0.2.2 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading treeinterpreter-0.2.3-py2.py3-none-any.whl (6.0 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.3.2)
# Collecting skope-rules>=1.0.1 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading skope_rules-1.0.1-py3-none-any.whl (14 kB)
# Collecting shap>=0.28.5 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading shap-0.42.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 37.1 MB/s eta 0:00:00
# Collecting dill>=0.2.5 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.0 MB/s eta 0:00:00
# Collecting dash>=1.0.0 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading dash-2.12.1-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 87.1 MB/s eta 0:00:00
# Collecting dash-core-components>=1.0.0 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components>=1.0.0 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-table>=4.1.0 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-cytoscape>=0.1.1 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading dash_cytoscape-0.3.0-py3-none-any.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 88.2 MB/s eta 0:00:00
# Collecting gevent>=1.3.6 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading gevent-23.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 78.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.31.0)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (5.5.6)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (7.34.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.23.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.10.1)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.2.2)
# Collecting SALib>=1.3.3 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading salib-1.4.7-py3-none-any.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.0/758.0 kB 56.6 MB/s eta 0:00:00
# Collecting lime>=0.1.1.33 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 31.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.2.5)
# Collecting Werkzeug<2.3.0 (from dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (4.7.1)
# Collecting retrying (from dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.5.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (67.7.2)
# Collecting zope.event (from gevent>=1.3.6->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Collecting zope.interface (from gevent>=1.3.6->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading zope.interface-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: greenlet>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gevent>=1.3.6->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.0.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (6.3.2)
# Collecting jedi>=0.16 (from ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (4.8.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (4.66.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.10/dist-packages (from lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.19.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=3.8.1->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=3.8.1->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2023.7.22)
# Collecting multiprocess (from SALib>=1.3.3->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18.1->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.2.0)
# Collecting slicer==0.0.7 (from shap>=0.28.5->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap>=0.28.5->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap>=0.28.5->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.2.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (8.1.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.19.2->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2023.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (1.4.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<2.3.0->dash>=1.0.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (2.1.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (5.3.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (23.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap>=0.28.5->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (0.39.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret) (3.10.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=ecb49cdff318b6b112f95c246ec6bb6232c63f7fa7079cb8171734c8c0a3943f
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# Installing collected packages: treeinterpreter, interpret-core, dash-table, dash-html-components, dash-core-components, zope.interface, zope.event, Werkzeug, slicer, retrying, jedi, dill, ansi2html, multiprocess, gevent, skope-rules, shap, SALib, lime, dash, dash-cytoscape, interpret
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.3.7
#     Uninstalling Werkzeug-2.3.7:
#       Successfully uninstalled Werkzeug-2.3.7
# Successfully installed SALib-1.4.7 Werkzeug-2.2.3 ansi2html-1.8.0 dash-2.12.1 dash-core-components-2.0.0 dash-cytoscape-0.3.0 dash-html-components-2.0.0 dash-table-5.0.0 dill-0.3.7 gevent-23.7.0 interpret-0.4.4 interpret-core-0.4.4 jedi-0.19.0 lime-0.2.0.1 multiprocess-0.70.15 retrying-1.3.4 shap-0.42.1 skope-rules-1.0.1 slicer-0.0.7 treeinterpreter-0.2.3 zope.event-5.0 zope.interface-6.0

# %%
from interpret.glassbox import ExplainableBoostingRegressor as EBR

# %%
guangan.read_in_model(EBR, 'Regression')
# Out:
# Successfully read in model <class 'interpret.glassbox._ebm._ebm.ExplainableBoostingRegressor'>, which is a Regression model

# %%
guangan.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'max_bins': set(range(4, 4097)),
    'min_samples_leaf': set(range(2, 33)),
    'interactions': set(range(2, 9)),
    'max_leaves': (2, 4),
    'learning_rate': (-6, 1),
    'max_rounds': set(range(25, 201)),

}

# %%
guangan.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
guangan.read_in_transform({'learning_rate': '10^', 'max_leaves': '10^'})
# Out:
# Updated transform dictionary: {'max_bins': False, 'min_samples_leaf': False, 'interactions': False, 'max_leaves': '10^', 'learning_rate': '10^', 'max_rounds': False}

# %%
guangan.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
guangan.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  guangan.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv', f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 9873 rows
# True

# %%
guangan.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
guangan.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
guangan.train_other_info = train_other_info
guangan.val_other_info = val_other_info
guangan.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
guangan.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 9873 combinations so far
# Pred centre score: 0.607489474722567
# Actual centre score: 0.6079664570230608
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.75, 'max_rounds': 157, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 157, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.75, 'max_rounds': 157, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 157, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2274, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.015625, 'learning_rate': -0.6953125, 'max_rounds': 159, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.6086518304325614
# Actual centre score: 0.6037735849056604
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.75, 'max_rounds': 163, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 163, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.75, 'max_rounds': 163, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 163, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2274, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.015625, 'learning_rate': -0.6953125, 'max_rounds': 162, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.6086562682173318
# Actual centre score: 0.6037735849056604
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.53125, 'max_rounds': 157, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 157, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.53125, 'max_rounds': 157, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 157, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2274, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.015625, 'learning_rate': -0.5859375, 'max_rounds': 159, 'features': 3}, which had val score of 0.608
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.6074898843173817
# Actual centre score: 0.6079664570230608
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.53125, 'max_rounds': 163, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 163, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.53125, 'max_rounds': 163, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 163, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2274, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.015625, 'learning_rate': -0.5859375, 'max_rounds': 162, 'features': 3}, which had val score of 0.608
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.6074935752837725
# Actual centre score: 0.6079664570230608
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 157, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.75, 'max_rounds': 157, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 157, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.75, 'max_rounds': 157, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2274, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.046875, 'learning_rate': -0.6953125, 'max_rounds': 159, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.6086412041639284
# Actual centre score: 0.6037735849056604
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 163, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.75, 'max_rounds': 163, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.75, 'max_rounds': 163, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.75, 'max_rounds': 160, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.75, 'max_rounds': 163, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2274, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.046875, 'learning_rate': -0.6953125, 'max_rounds': 162, 'features': 3}, which had val score of 0.6038
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.6086457074921884
# Actual centre score: 0.6037735849056604
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 157, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.53125, 'max_rounds': 157, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 157, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 157, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.53125, 'max_rounds': 157, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2274, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.046875, 'learning_rate': -0.5859375, 'max_rounds': 159, 'features': 3}, which had val score of 0.608
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.6074810089289426
# Actual centre score: 0.6079664570230608
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 163, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2242, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.53125, 'max_rounds': 163, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.53125, 'max_rounds': 163, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 160, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.640625, 'max_rounds': 163, 'features': 3}, which had val score of 0.6122
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.53125, 'max_rounds': 160, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2306, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.53125, 'max_rounds': 163, 'features': 3}, which had val score of 0.6017
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2274, 'min_samples_leaf': 12, 'interactions': 6, 'max_leaves': 2.046875, 'learning_rate': -0.5859375, 'max_rounds': 162, 'features': 3}, which had val score of 0.608
# ...
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 157, 'features': 4}, which had val score of 0.5828
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 157, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 157, 'features': 4}, which had val score of 0.5828
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 157, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2146, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.046875, 'learning_rate': -0.3671875, 'max_rounds': 159, 'features': 4}, which had val score of 0.5807
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.582987277783241
# Actual centre score: 0.5807127882599581
#
# FIT!
#
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 163, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 163, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 163, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 163, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 163, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 163, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 163, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 163, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2146, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.046875, 'learning_rate': -0.3671875, 'max_rounds': 162, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Pred centre score: 0.5823853376406749
# Actual centre score: 0.5838574423480084
#
# FIT!
#
# Begin Cruise
# Cruise Round
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 163, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 163, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 163, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2114, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 163, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.421875, 'max_rounds': 163, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.03125, 'learning_rate': -0.3125, 'max_rounds': 163, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 160, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.421875, 'max_rounds': 163, 'features': 4}, which had val score of 0.5797
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 160, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2178, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0625, 'learning_rate': -0.3125, 'max_rounds': 163, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# Already Trained and Tested combination {'max_bins': 2146, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.046875, 'learning_rate': -0.3671875, 'max_rounds': 162, 'features': 4}, which had val score of 0.5839
#         Current best combo: (2050, 11, 6, 2.0, -0.3125, 157, 3) with val score 0.6184.
#         Has trained 9873 combinations so far
# TUNING FINISHED
#
# Max Score:
#  0.6184486373165619
# Max Test Score:
#  0.618449
# Max Combo Index:
#  (2050, 11, 6, 2.0, -0.3125, 157, 3)
# Max Combo Hyperparamer Combination:
#  {'max_bins': 2050, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.3125, 'max_rounds': 157, 'features': 3}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts')
# # Combos Checked: 9873

# %%
guangan.view_best_combo_and_score()
# Out:
# Max Score:
#  0.6184486373165619
# Max Test Score:
#  0.618449
# Max Combo Index:
#  (2050, 11, 6, 2.0, -0.3125, 157, 3)
# Max Combo Hyperparamer Combination:
#  {'max_bins': 2050, 'min_samples_leaf': 11, 'interactions': 6, 'max_leaves': 2.0, 'learning_rate': -0.3125, 'max_rounds': 157, 'features': 3}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts')
# # Combos Checked: 9873
