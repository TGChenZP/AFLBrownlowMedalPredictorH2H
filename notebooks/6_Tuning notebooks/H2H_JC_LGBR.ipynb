# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'LGBR'
TUNING_MODEL = 'jiaocheng'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import JiaoCheng_H2H

# %%
jiaocheng = JiaoCheng_H2H.JiaoCheng()
# Out:
# JiaoCheng Initialised

# %%
from lightgbm import LGBMRegressor as LGBR

# %%
jiaocheng.read_in_model(LGBR, 'Regression')
# Out:
# Successfully read in model <class 'lightgbm.sklearn.LGBMRegressor'>, which is a Regression model

# %%
jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)

}

# %%
jiaocheng.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
jiaocheng.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
jiaocheng.set_tuning_order(['features', 'max_depth', 'colsample_bytree', 'subsample', 'n_estimators', 'reg_alpha', 'learning_rate'])

# %%
jiaocheng.set_hyperparameter_default_values({
    'features': 0,
    'n_estimators': 50,
    'max_depth': 12,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'learning_rate': 0.1,
    'reg_alpha': 0.01}
  )

# %%
try:
  jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 112 rows
# True

# %%
jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
jiaocheng.train_other_info = train_other_info
jiaocheng.val_other_info = val_other_info
jiaocheng.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
jiaocheng.tune()
# Out:
# Default combo: [1, 2, 2, 2, 4, 2, 0]
#
#
# ROUND 1
#
# Round 2
# Hyperparameter: features (index: 6)
#
# As new Best Combo (1, 2, 2, 2, 4, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 0), which had val score of 0.566
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score 0.566.
#         Has trained 112 of 604800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 1), which had val score of 0.5742
#         Current best combo: (1, 2, 2, 2, 4, 2, 1) with val score 0.5742.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 2), which had val score of 0.5715
#         Current best combo: (1, 2, 2, 2, 4, 2, 1) with val score 0.5742.
#         Has trained 112 of 604800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 3), which had val score of 0.5757
#         Current best combo: (1, 2, 2, 2, 4, 2, 3) with val score 0.5757.
#         Has trained 112 of 604800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 4), which had val score of 0.5769
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 5), which had val score of 0.5752
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 6), which had val score of 0.571
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 7), which had val score of 0.5734
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 8), which had val score of 0.5689
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 9), which had val score of 0.5714
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 10), which had val score of 0.5752
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 11), which had val score of 0.5723
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 12), which had val score of 0.5755
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 13), which had val score of 0.5709
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 14), which had val score of 0.5744
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score 0.5769.
#         Has trained 112 of 604800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 15), which had val score of 0.5778
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score 0.5778.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 16), which had val score of 0.5733
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score 0.5778.
#         Has trained 112 of 604800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 17) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 18), which had val score of 0.5786
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 19), which had val score of 0.5713
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 20), which had val score of 0.5725
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 21), which had val score of 0.5753
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 22), which had val score of 0.5744
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 23), which had val score of 0.5749
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 24), which had val score of 0.575
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 25), which had val score of 0.5712
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 26), which had val score of 0.574
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 27), which had val score of 0.5707
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 28), which had val score of 0.5685
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 29), which had val score of 0.5699
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 30), which had val score of 0.5738
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 31), which had val score of 0.5729
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 32), which had val score of 0.5729
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 33), which had val score of 0.5741
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 34), which had val score of 0.5704
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 35), which had val score of 0.577
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 17) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 17), which had val score of 0.5754
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 4, 2, 17), which had val score of 0.5767
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 4, 2, 17), which had val score of 0.5791
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 4, 2, 17), which had val score of 0.5791
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 5, 2, 2, 4, 2, 17), which had val score of 0.5791
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 6, 2, 2, 4, 2, 17), which had val score of 0.5791
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (1, 2, 2, 0, 4, 2, 17), which had val score of 0.5604
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 1, 4, 2, 17), which had val score of 0.5684
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 3, 4, 2, 17), which had val score of 0.5769
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 2, 0, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 1, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 3, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 2, 2, 2, 4, 2, 17), which had val score of 0.5718
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 4, 2, 17), which had val score of 0.576
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 4, 2, 17), which had val score of 0.5711
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (4, 2, 2, 2, 4, 2, 17), which had val score of 0.5635
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (1, 2, 2, 2, 4, 0, 17), which had val score of 0.5789
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 1, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 2, 17) with val score 0.5797.
#         Has trained 112 of 604800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 3, 17) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 4, 17), which had val score of 0.5788
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 5, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (1, 2, 2, 2, 0, 3, 17), which had val score of 0.0
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 3, 17), which had val score of 0.0
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 2, 3, 17), which had val score of 0.0046
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 3, 17), which had val score of 0.3176
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 3
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 0), which had val score of 0.566
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 1), which had val score of 0.5743
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 2), which had val score of 0.5714
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 3), which had val score of 0.5758
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 4), which had val score of 0.5782
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 5), which had val score of 0.5751
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 6), which had val score of 0.5713
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 7), which had val score of 0.5746
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 8), which had val score of 0.569
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 9), which had val score of 0.5724
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 10), which had val score of 0.5744
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 11), which had val score of 0.5738
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 12), which had val score of 0.5745
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 13), which had val score of 0.5712
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 14), which had val score of 0.5738
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 15), which had val score of 0.5789
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 16), which had val score of 0.575
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 18), which had val score of 0.5792
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 19), which had val score of 0.5713
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 20), which had val score of 0.5737
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 21), which had val score of 0.5721
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 22), which had val score of 0.5744
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 23), which had val score of 0.5748
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 24), which had val score of 0.5727
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 25), which had val score of 0.5718
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 26), which had val score of 0.5739
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 27), which had val score of 0.5705
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 28), which had val score of 0.5688
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 29), which had val score of 0.5695
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 30), which had val score of 0.5723
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 31), which had val score of 0.5728
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 32), which had val score of 0.5728
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 33), which had val score of 0.576
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 34), which had val score of 0.5709
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 35), which had val score of 0.576
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 4, 3, 17), which had val score of 0.5754
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 4, 3, 17), which had val score of 0.5763
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 4, 3, 17), which had val score of 0.5792
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 4, 3, 17), which had val score of 0.5792
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 5, 2, 2, 4, 3, 17), which had val score of 0.5792
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 6, 2, 2, 4, 3, 17), which had val score of 0.5792
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (1, 2, 2, 0, 4, 3, 17), which had val score of 0.5608
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 1, 4, 3, 17), which had val score of 0.5679
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 3, 4, 3, 17), which had val score of 0.5769
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 2, 0, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 1, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 3, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 17), which had val score of 0.5718
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 4, 3, 17), which had val score of 0.5774
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 4, 3, 17), which had val score of 0.5689
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (4, 2, 2, 2, 4, 3, 17), which had val score of 0.5611
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (1, 2, 2, 2, 4, 0, 17), which had val score of 0.5789
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 1, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of 0.5797
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 4, 17), which had val score of 0.5788
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 5, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (1, 2, 2, 2, 0, 3, 17), which had val score of 0.0
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 3, 17), which had val score of 0.0
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 2, 3, 17), which had val score of 0.0046
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 3, 3, 17), which had val score of 0.3176
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 3, 17), which had val score of 0.5799
#         Current best combo: (1, 2, 2, 2, 4, 3, 17) with val score 0.5799.
#         Has trained 112 of 604800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 3, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.579909
# Max Test Score:
#  0.579909
# Max Combo Index:
#  (1, 2, 2, 2, 4, 3, 17) out of [5, 7, 4, 4, 5, 6, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 17}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances', 'Tackles Inside 50', 'Rebound 50s', 'One Percenters', 'Goal Assists', 'Uncontested Possessions')
# % Combos Checked: 112 out of 604800 which is 0.018519%

# %%
jiaocheng.view_best_combo_and_score()
# Out:
# Max Score:
#  0.579909
# Max Test Score:
#  0.579909
# Max Combo Index:
#  (1, 2, 2, 2, 4, 3, 17) out of [5, 7, 4, 4, 5, 6, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 17}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances', 'Tackles Inside 50', 'Rebound 50s', 'One Percenters', 'Goal Assists', 'Uncontested Possessions')
# % Combos Checked: 112 out of 604800 which is 0.018519%
