# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'LGBR'
TUNING_MODEL = 'guangan'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import GuangAn_H2H

# %%
guangan = GuangAn_H2H.GuangAn()
# Out:
# GuangAn Initialised

# %%
from lightgbm import LGBMRegressor as LGBR

# %%
guangan.read_in_model(LGBR, 'Regression')
# Out:
# Successfully read in model <class 'lightgbm.sklearn.LGBMRegressor'>, which is a Regression model

# %%
guangan.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': set(range(25, 401)),
    'max_depth': set(range(3, 193)),
    'subsample': (0.4, 0.85),
    'colsample_bytree': (0.4, 0.85),
    'learning_rate': (-8, -1),
    'reg_alpha': (-4, 1)

}

# %%
guangan.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
guangan.read_in_transform({'learning_rate': '10^', 'reg_alpha': '10^'})
# Out:
# Updated transform dictionary: {'n_estimators': False, 'max_depth': False, 'subsample': False, 'colsample_bytree': False, 'learning_rate': '10^', 'reg_alpha': '10^'}

# %%
guangan.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
guangan.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  guangan.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv', f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 12283 rows
# True

# %%
guangan.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
guangan.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
guangan.train_other_info = train_other_info
guangan.val_other_info = val_other_info
guangan.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
guangan.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# [LightGBM] [Info] Total Bins 547
# [LightGBM] [Info] Number of data points in the train set: 475844, number of used features: 15
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 12290: {'n_estimators': [272], 'max_depth': [12], 'subsample': [0.4140625], 'colsample_bytree': [0.5125], 'learning_rate': [2.053525026457146e-07], 'reg_alpha': [2.371373705661655], 'features': [12]}, taking 7.68 seconds to get val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12290 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6174
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12290 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.6875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12290 combinations so far
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018930 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 547
# [LightGBM] [Info] Number of data points in the train set: 475844, number of used features: 15
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 12291: {'n_estimators': [272], 'max_depth': [12], 'subsample': [0.4140625], 'colsample_bytree': [0.51953125], 'learning_rate': [2.053525026457146e-07], 'reg_alpha': [2.371373705661655], 'features': [12]}, taking 10.09 seconds to get val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017692 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 547
# [LightGBM] [Info] Number of data points in the train set: 475844, number of used features: 15
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 12292: {'n_estimators': [269], 'max_depth': [11], 'subsample': [0.410546875], 'colsample_bytree': [0.516015625], 'learning_rate': [1.8105582430271218e-07], 'reg_alpha': [2.1673921695684175], 'features': [12]}, taking 10.07 seconds to get val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258
# Pred centre score: 0.6184168987893979
# Actual centre score: 0.619496855345912
#
# FIT!
#
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.608
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.608
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.608
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.608
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6111
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6111
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6111
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12292 combinations so far
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017575 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 547
# [LightGBM] [Info] Number of data points in the train set: 475844, number of used features: 15
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 12293: {'n_estimators': [272], 'max_depth': [9], 'subsample': [0.4140625], 'colsample_bytree': [0.5265624999999999], 'learning_rate': [1.2409377607517196e-07], 'reg_alpha': [1.9809567785503388], 'features': [12]}, taking 8.35 seconds to get val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12293 combinations so far
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018420 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 547
# [LightGBM] [Info] Number of data points in the train set: 475844, number of used features: 15
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 12294: {'n_estimators': [272], 'max_depth': [9], 'subsample': [0.4140625], 'colsample_bytree': [0.5265624999999999], 'learning_rate': [1.5963385442879422e-07], 'reg_alpha': [1.9809567785503388], 'features': [12]}, taking 10.17 seconds to get val score of 0.6111
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6205
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6205
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6205
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12294 combinations so far
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.099699 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 547
# [LightGBM] [Info] Number of data points in the train set: 475844, number of used features: 15
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 12295: {'n_estimators': [272], 'max_depth': [12], 'subsample': [0.4140625], 'colsample_bytree': [0.5265624999999999], 'learning_rate': [1.2409377607517196e-07], 'reg_alpha': [1.9809567785503388], 'features': [12]}, taking 9.21 seconds to get val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.21875, 'features': 12}, which had val score of 0.6205
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12295 combinations so far
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017615 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 547
# [LightGBM] [Info] Number of data points in the train set: 475844, number of used features: 15
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 12296: {'n_estimators': [272], 'max_depth': [12], 'subsample': [0.4140625], 'colsample_bytree': [0.5265624999999999], 'learning_rate': [1.5963385442879422e-07], 'reg_alpha': [1.9809567785503388], 'features': [12]}, taking 10.1 seconds to get val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017790 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 547
# [LightGBM] [Info] Number of data points in the train set: 475844, number of used features: 15
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 12297: {'n_estimators': [269], 'max_depth': [11], 'subsample': [0.410546875], 'colsample_bytree': [0.5230468749999999], 'learning_rate': [1.4074646633398433e-07], 'reg_alpha': [1.8105582430271219], 'features': [12]}, taking 10.14 seconds to get val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258
# Pred centre score: 0.6177211650130128
# Actual centre score: 0.619496855345912
#
# FIT!
#
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.608
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.608
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.608
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.608
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12297 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5265624999999999, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
# ...
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 266, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6111
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6111
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6111
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6132
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6111
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 9, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6174
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.40703125, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6174
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.5125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6174
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.90625, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6195
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.296875, 'features': 12}, which had val score of 0.6226
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 272, 'max_depth': 12, 'subsample': 0.4140625, 'colsample_bytree': 0.51953125, 'learning_rate': -6.796875, 'reg_alpha': 0.375, 'features': 12}, which had val score of 0.6174
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# Already Trained and Tested combination {'n_estimators': 269, 'max_depth': 11, 'subsample': 0.410546875, 'colsample_bytree': 0.516015625, 'learning_rate': -6.8515625, 'reg_alpha': 0.3359375, 'features': 12}, which had val score of 0.6101
#         Current best combo: (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12) with val score 0.6258.
#         Has trained 12368 combinations so far
# TUNING FINISHED
#
# Max Score:
#  0.6257861635220127
# Max Test Score:
#  0.625786
# Max Combo Index:
#  (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 284, 'max_depth': 15, 'subsample': 0.428125, 'colsample_bytree': 0.5406249999999999, 'learning_rate': -6.6875, 'reg_alpha': 0.0625, 'features': 12}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances')
# # Combos Checked: 12368

# %%
guangan.view_best_combo_and_score()
# Out:
# Max Score:
#  0.6257861635220127
# Max Test Score:
#  0.625786
# Max Combo Index:
#  (284, 15, 0.428125, 0.5406249999999999, -6.6875, 0.0625, 12)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 284, 'max_depth': 15, 'subsample': 0.428125, 'colsample_bytree': 0.5406249999999999, 'learning_rate': -6.6875, 'reg_alpha': 0.0625, 'features': 12}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances')
# # Combos Checked: 12368
