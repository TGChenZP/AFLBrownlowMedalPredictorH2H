# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'DNN'
TUNING_MODEL = 'guangan'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import GuangAn_H2H

# %%
guangan = GuangAn_H2H.GuangAn()
# Out:
# GuangAn Initialised

# %%
from models.DenseNeuralNetwork import DNN_shrink_sk as DNN

# %%
guangan.read_in_model(DNN, 'Regression')
# Out:
# Successfully read in model <class 'models.DenseNeuralNetwork.DNN_shrink_sk'>, which is a Regression model

# %%
guangan.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_hidden_layers': {1, 2, 3, 4, 5},
    'alpha': (-8, -1),
    'learning_rate_init': (-4, -1),
    'activation': ('relu', 'logistic')

}

# %%
guangan.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
guangan.read_in_transform({'learning_rate_init': '10^', 'alpha': '10^'})
# Out:
# Updated transform dictionary: {'n_hidden_layers': False, 'alpha': '10^', 'learning_rate_init': '10^', 'activation': False}

# %%
guangan.read_in_categorical(['activation'])
# Out:
# Updated categorical dictionary: {'n_hidden_layers': False, 'alpha': False, 'learning_rate_init': False, 'activation': True}
# Updated original bounds dict: [({1, 2, 3, 4, 5}, 'n_hidden_layers'), ((-8, -1), 'alpha'), ((-4, -1), 'learning_rate_init'), ({'values': ('logistic', 'relu')}, 'activation')]

# %%
guangan.set_non_tuneable_hyperparameters({'random_state': 19260817, 'max_iter': 1000, 'learning_rate': 'adaptive', 'batch_size': 'auto'})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
guangan.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  guangan.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv', f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 1096 rows
# True

# %%
guangan.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
guangan.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
guangan.train_other_info = train_other_info
guangan.val_other_info = val_other_info
guangan.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
guangan.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 5}, which had val score of 0.608
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.34375, 'activation': 'logistic', 'features': 6}, which had val score of 0.5985
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5940262723860605
# Actual centre score: 0.5985324947589099
#
# FIT!
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.6875, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.6875, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.6875, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.6875, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.34375, 'activation': 'logistic', 'features': 8}, which had val score of 0.566
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5814164813780213
# Actual centre score: 0.5660377358490566
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}, which had val score of 0.6048
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 7}, which had val score of 0.6017
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}, which had val score of 0.6048
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 7}, which had val score of 0.6017
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.03125, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 6}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.6014493845143045
# Actual centre score: 0.591194968553459
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 7}, which had val score of 0.6017
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 9}, which had val score of 0.5629
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 7}, which had val score of 0.6017
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 9}, which had val score of 0.5629
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.03125, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 8}, which had val score of 0.5891
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5881374249006692
# Actual centre score: 0.589098532494759
#
# FIT!
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 5}, which had val score of 0.608
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 5}, which had val score of 0.5996
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.03125, 'learning_rate_init': -3.34375, 'activation': 'logistic', 'features': 6}, which had val score of 0.5985
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.592873366393498
# Actual centre score: 0.5985324947589099
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.03125, 'learning_rate_init': -3.34375, 'activation': 'logistic', 'features': 8}, which had val score of 0.5597
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5814119874036456
# Actual centre score: 0.559748427672956
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}, which had val score of 0.6048
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 7}, which had val score of 0.6017
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}, which had val score of 0.6048
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 7}, which had val score of 0.6017
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.59375, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 6}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.6014379097201643
# Actual centre score: 0.591194968553459
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 7}, which had val score of 0.6017
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 9}, which had val score of 0.5629
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 7}, which had val score of 0.6017
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 9}, which had val score of 0.5629
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.59375, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 8}, which had val score of 0.5891
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5881156972338615
# Actual centre score: 0.589098532494759
#
# FIT!
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 5}, which had val score of 0.5996
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 5}, which had val score of 0.6048
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.59375, 'learning_rate_init': -3.34375, 'activation': 'logistic', 'features': 6}, which had val score of 0.5985
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5924571258039312
# Actual centre score: 0.5985324947589099
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.8125, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 7}, which had val score of 0.6143
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 9}, which had val score of 0.5755
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 7}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.375, 'learning_rate_init': -3.25, 'activation': 'logistic', 'features': 9}, which had val score of 0.5681
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -5.59375, 'learning_rate_init': -3.34375, 'activation': 'logistic', 'features': 8}, which had val score of 0.5597
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.58140734499834
# Actual centre score: 0.559748427672956
#
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 14}, which had val score of 0.5692
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 16}, which had val score of 0.5922
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 14}, which had val score of 0.5797
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5744
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 14}, which had val score of 0.5807
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 16}, which had val score of 0.5839
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 14}, which had val score of 0.5618
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.90625, 'learning_rate_init': -2.40625, 'activation': 'relu', 'features': 15}, which had val score of 0.5964
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5789105743576274
# Actual centre score: 0.5964360587002097
#
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 16}, which had val score of 0.5922
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 18}, which had val score of 0.5367
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5744
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 18}, which had val score of 0.5901
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 16}, which had val score of 0.5839
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 18}, which had val score of 0.5241
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 18}, which had val score of 0.544
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.90625, 'learning_rate_init': -2.40625, 'activation': 'relu', 'features': 17}, which had val score of 0.5597
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5666325303698316
# Actual centre score: 0.559748427672956
#
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 14}, which had val score of 0.5797
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5744
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 14}, which had val score of 0.6006
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 16}, which had val score of 0.5587
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 14}, which had val score of 0.5618
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 14}, which had val score of 0.6006
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 16}, which had val score of 0.5797
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.90625, 'learning_rate_init': -2.21875, 'activation': 'relu', 'features': 15}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5803792310722078
# Actual centre score: 0.5911949685534591
#
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5744
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 18}, which had val score of 0.5901
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 16}, which had val score of 0.5587
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -7.125, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 18}, which had val score of 0.544
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 18}, which had val score of 0.544
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 16}, which had val score of 0.5797
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 18}, which had val score of 0.5482
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.90625, 'learning_rate_init': -2.21875, 'activation': 'relu', 'features': 17}, which had val score of 0.5891
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5660236898834484
# Actual centre score: 0.589098532494759
#
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 14}, which had val score of 0.5807
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 16}, which had val score of 0.5839
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 14}, which had val score of 0.5618
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 14}, which had val score of 0.5985
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 16}, which had val score of 0.5723
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 14}, which had val score of 0.5535
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.6132
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.46875, 'learning_rate_init': -2.40625, 'activation': 'relu', 'features': 15}, which had val score of 0.5629
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5816184822228582
# Actual centre score: 0.5628930817610063
#
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 16}, which had val score of 0.5839
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 18}, which had val score of 0.5241
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 18}, which had val score of 0.544
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 16}, which had val score of 0.5723
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.5, 'activation': 'relu', 'features': 18}, which had val score of 0.5566
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.6132
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 18}, which had val score of 0.5765
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.46875, 'learning_rate_init': -2.40625, 'activation': 'relu', 'features': 17}, which had val score of 0.5797
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5694242030207162
# Actual centre score: 0.5796645702306081
#
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 14}, which had val score of 0.5618
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 14}, which had val score of 0.6006
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 16}, which had val score of 0.5797
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 14}, which had val score of 0.5535
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.6132
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 14}, which had val score of 0.5629
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.25, 'learning_rate_init': -2.125, 'activation': 'relu', 'features': 16}, which had val score of 0.5713
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.46875, 'learning_rate_init': -2.21875, 'activation': 'relu', 'features': 15}, which had val score of 0.5597
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Pred centre score: 0.5790907220454715
# Actual centre score: 0.559748427672956
#
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 16}, which had val score of 0.5912
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1096 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 3, 'alpha': -6.6875, 'learning_rate_init': -2.3125, 'activation': 'relu', 'features': 18}, which had val score of 0.544
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
# ...
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1171 combinations so far
# Trained and Tested combination 1172: {'n_hidden_layers': [5], 'alpha': [1.8105582430271218e-07], 'learning_rate_init': [0.0003459891660869932], 'activation': ['logistic'], 'features': [5]}, taking 41.59 seconds to get val score of 0.5933
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.5990927002435934
# Actual centre score: 0.5932914046121593
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.6875, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6216
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1172 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.6875, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1172 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.578125, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6216
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1172 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.578125, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1172 combinations so far
# Trained and Tested combination 1173: {'n_hidden_layers': [5], 'alpha': [2.329096592460546e-07], 'learning_rate_init': [0.0003105900223624705], 'activation': ['logistic'], 'features': [5]}, taking 47.97 seconds to get val score of 0.6279
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.6168787111166688
# Actual centre score: 0.6278825995807128
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.6875, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1173 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.6875, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1173 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.578125, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1173 combinations so far
# Trained and Tested combination 1174: {'n_hidden_layers': [5], 'alpha': [2.6416483203860925e-07], 'learning_rate_init': [0.0003651741272548377], 'activation': ['logistic'], 'features': [5]}, taking 41.89 seconds to get val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Trained and Tested combination 1175: {'n_hidden_layers': [5], 'alpha': [2.329096592460546e-07], 'learning_rate_init': [0.0003459891660869932], 'activation': ['logistic'], 'features': [5]}, taking 41.99 seconds to get val score of 0.5933
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.5990931837578577
# Actual centre score: 0.5932914046121593
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.578125, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6216
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1175 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.578125, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1175 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6216
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1175 combinations so far
# Trained and Tested combination 1176: {'n_hidden_layers': [5], 'alpha': [3.398208328942559e-07], 'learning_rate_init': [0.00032781211513934584], 'activation': ['logistic'], 'features': [5]}, taking 45.04 seconds to get val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Trained and Tested combination 1177: {'n_hidden_layers': [5], 'alpha': [2.9961427410043636e-07], 'learning_rate_init': [0.0003105900223624705], 'activation': ['logistic'], 'features': [5]}, taking 46.97 seconds to get val score of 0.6279
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.6168787426521088
# Actual centre score: 0.6278825995807128
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.578125, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1177 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.578125, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1177 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1177 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1177 combinations so far
# Trained and Tested combination 1178: {'n_hidden_layers': [5], 'alpha': [2.9961427410043636e-07], 'learning_rate_init': [0.0003459891660869932], 'activation': ['logistic'], 'features': [5]}, taking 41.85 seconds to get val score of 0.5933
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.5990936721702677
# Actual centre score: 0.5932914046121593
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6216
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1178 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1178 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.359375, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6216
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1178 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.359375, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1178 combinations so far
# Trained and Tested combination 1179: {'n_hidden_layers': [5], 'alpha': [3.854228868623106e-07], 'learning_rate_init': [0.0003105900223624705], 'activation': ['logistic'], 'features': [5]}, taking 48.82 seconds to get val score of 0.6279
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.6168787744816708
# Actual centre score: 0.6278825995807128
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1179 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.46875, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1179 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.359375, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1179 combinations so far
# Trained and Tested combination 1180: {'n_hidden_layers': [5], 'alpha': [4.37144481261109e-07], 'learning_rate_init': [0.0003651741272548377], 'activation': ['logistic'], 'features': [5]}, taking 41.25 seconds to get val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Trained and Tested combination 1181: {'n_hidden_layers': [5], 'alpha': [3.854228868623106e-07], 'learning_rate_init': [0.0003459891660869932], 'activation': ['logistic'], 'features': [5]}, taking 42.46 seconds to get val score of 0.5933
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.5990941653500146
# Actual centre score: 0.5932914046121593
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.359375, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6216
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1181 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.359375, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1181 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.53125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6216
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1181 combinations so far
# Trained and Tested combination 1182: {'n_hidden_layers': [5], 'alpha': [5.62341325190349e-07], 'learning_rate_init': [0.00032781211513934584], 'activation': ['logistic'], 'features': [5]}, taking 45.51 seconds to get val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Trained and Tested combination 1183: {'n_hidden_layers': [5], 'alpha': [4.958068241684656e-07], 'learning_rate_init': [0.0003105900223624705], 'activation': ['logistic'], 'features': [5]}, taking 46.24 seconds to get val score of 0.6279
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.616878806595649
# Actual centre score: 0.6278825995807128
#
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.359375, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1183 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.359375, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1183 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.484375, 'activation': 'logistic', 'features': 5}, which had val score of 0.6122
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1183 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -6.25, 'learning_rate_init': -3.4375, 'activation': 'logistic', 'features': 5}, which had val score of 0.586
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1183 combinations so far
# Trained and Tested combination 1184: {'n_hidden_layers': [5], 'alpha': [4.958068241684656e-07], 'learning_rate_init': [0.0003459891660869932], 'activation': ['logistic'], 'features': [5]}, taking 42.35 seconds to get val score of 0.5933
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279
# Pred centre score: 0.5990946631526569
# Actual centre score: 0.5932914046121593
#
# Begin Cruise
# Cruise Round
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -7.5625, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}, which had val score of 0.6048
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1184 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -7.5625, 'learning_rate_init': -3.578125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6195
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1184 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -7.453125, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}, which had val score of 0.6048
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1184 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -7.453125, 'learning_rate_init': -3.578125, 'activation': 'logistic', 'features': 5}, which had val score of 0.6195
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1184 combinations so far
# Already Trained and Tested combination {'n_hidden_layers': 5, 'alpha': -7.5078125, 'learning_rate_init': -3.6015625, 'activation': 'logistic', 'features': 5}, which had val score of 0.6048
#         Current best combo: (5, -4.5, -3.625, 'logistic', 5) with val score 0.6279.
#         Has trained 1184 combinations so far
# TUNING FINISHED
#
# Max Score:
#  0.6278825995807128
# Max Test Score:
#  0.627883
# Max Combo Index:
#  (5, -4.5, -3.625, 'logistic', 5)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50')
# # Combos Checked: 1184

# %%
guangan.view_best_combo_and_score()
# Out:
# Max Score:
#  0.6278825995807128
# Max Test Score:
#  0.627883
# Max Combo Index:
#  (5, -4.5, -3.625, 'logistic', 5)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 5, 'alpha': -4.5, 'learning_rate_init': -3.625, 'activation': 'logistic', 'features': 5}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50')
# # Combos Checked: 1184
