# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'DNN'
TUNING_MODEL = 'jiaocheng'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import JiaoCheng_H2H

# %%
jiaocheng = JiaoCheng_H2H.JiaoCheng()
# Out:
# JiaoCheng Initialised

# %%
from models.DenseNeuralNetwork import DNN_shrink_sk as DNN

# %%
jiaocheng.read_in_model(DNN, 'Regression')
# Out:
# Successfully read in model <class 'models.DenseNeuralNetwork.DNN_shrink_sk'>, which is a Regression model

# %%
jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_hidden_layers': (1, 2, 3, 4, 5),
    'alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'learning_rate_init': (0.0001, 0.001, 0.01, 0.1),
    'activation': ('relu', 'logistic')

}

# %%
jiaocheng.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'max_iter': 1000, 'learning_rate': 'adaptive', 'batch_size': 'auto'})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
jiaocheng.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
jiaocheng.set_tuning_order(['features', 'activation', 'n_hidden_layers', 'alpha', 'learning_rate_init'])

# %%
jiaocheng.set_hyperparameter_default_values({
    'features': 0,
    'activation': 'logistic',
    'n_hidden_layers': 1,
    'alpha': 0.0001,
    'learning_rate_init': 0.001}
  )

# %%
try:
  jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 88 rows
# True

# %%
jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
jiaocheng.train_other_info = train_other_info
jiaocheng.val_other_info = val_other_info
jiaocheng.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
jiaocheng.tune()
# Out:
# Default combo: [0, 2, 1, 0, 0]
#
#
# ROUND 1
#
# Round 2
# Hyperparameter: features (index: 4)
#
# As new Best Combo (0, 2, 1, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 2, 1, 0, 0), which had val score of 0.5828
#         Current best combo: (0, 2, 1, 0, 0) with val score 0.5828.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 1), which had val score of 0.5493
#         Current best combo: (0, 2, 1, 0, 0) with val score 0.5828.
#         Has trained 88 of 7200 combinations so far
# As new Best Combo (0, 2, 1, 0, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 2, 1, 0, 2), which had val score of 0.588
#         Current best combo: (0, 2, 1, 0, 2) with val score 0.588.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 3), which had val score of 0.5713
#         Current best combo: (0, 2, 1, 0, 2) with val score 0.588.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 4), which had val score of 0.5577
#         Current best combo: (0, 2, 1, 0, 2) with val score 0.588.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 5), which had val score of 0.5692
#         Current best combo: (0, 2, 1, 0, 2) with val score 0.588.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 6), which had val score of 0.5472
#         Current best combo: (0, 2, 1, 0, 2) with val score 0.588.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 7), which had val score of 0.5535
#         Current best combo: (0, 2, 1, 0, 2) with val score 0.588.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 8), which had val score of 0.5818
#         Current best combo: (0, 2, 1, 0, 2) with val score 0.588.
#         Has trained 88 of 7200 combinations so far
# As new Best Combo (0, 2, 1, 0, 9) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 2, 1, 0, 9), which had val score of 0.5933
#         Current best combo: (0, 2, 1, 0, 9) with val score 0.5933.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 10), which had val score of 0.5891
#         Current best combo: (0, 2, 1, 0, 9) with val score 0.5933.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 11), which had val score of 0.5556
#         Current best combo: (0, 2, 1, 0, 9) with val score 0.5933.
#         Has trained 88 of 7200 combinations so far
# As new Best Combo (0, 2, 1, 0, 12) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 2, 1, 0, 12), which had val score of 0.5975
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 13), which had val score of 0.5681
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 14), which had val score of 0.5503
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 15), which had val score of 0.5713
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 16), which had val score of 0.5765
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 17), which had val score of 0.5597
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 18), which had val score of 0.5503
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 19), which had val score of 0.5514
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 20), which had val score of 0.5618
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 21), which had val score of 0.5335
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 22), which had val score of 0.5639
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 23), which had val score of 0.5314
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 24), which had val score of 0.5335
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 25), which had val score of 0.566
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 26), which had val score of 0.5587
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 27), which had val score of 0.566
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 28), which had val score of 0.5451
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 29), which had val score of 0.5398
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 30), which had val score of 0.5503
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 31), which had val score of 0.5566
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 32), which had val score of 0.543
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 33), which had val score of 0.5597
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 34), which had val score of 0.5545
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 35), which had val score of 0.5451
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 12) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: activation (index: 3)
#
# Already Trained and Tested combination (0, 2, 1, 0, 12), which had val score of 0.5975
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 1, 12), which had val score of 0.5765
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 12) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_hidden_layers (index: 0)
#
# Already Trained and Tested combination (0, 2, 1, 0, 12), which had val score of 0.5975
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (1, 2, 1, 0, 12), which had val score of 0.5608
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (2, 2, 1, 0, 12), which had val score of 0.5723
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (3, 2, 1, 0, 12), which had val score of 0.5577
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (4, 2, 1, 0, 12), which had val score of 0.5618
#         Current best combo: (0, 2, 1, 0, 12) with val score 0.5975.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 12) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 1)
#
# As new Best Combo (0, 0, 1, 0, 12) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 1, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 12), which had val score of 0.5975
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 12), which had val score of 0.5975
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 4, 1, 0, 12), which had val score of 0.5577
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 1, 0, 12) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate_init (index: 2)
#
# Already Trained and Tested combination (0, 0, 0, 0, 12), which had val score of 0.5639
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 12), which had val score of 0.5765
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 12), which had val score of 0.5671
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 1, 0, 12) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 3
# Hyperparameter: features (index: 4)
#
# Already Trained and Tested combination (0, 0, 1, 0, 0), which had val score of 0.5828
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 1), which had val score of 0.5493
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 2), which had val score of 0.588
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 3), which had val score of 0.5713
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 4), which had val score of 0.5577
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 5), which had val score of 0.5692
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 6), which had val score of 0.5472
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 7), which had val score of 0.5535
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 8), which had val score of 0.5818
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 9), which had val score of 0.5933
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 10), which had val score of 0.5922
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 11), which had val score of 0.5556
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 13), which had val score of 0.5681
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 14), which had val score of 0.5503
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 15), which had val score of 0.5713
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 16), which had val score of 0.5765
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 17), which had val score of 0.5472
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 18), which had val score of 0.5503
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 19), which had val score of 0.5472
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 20), which had val score of 0.5618
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 21), which had val score of 0.5346
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 22), which had val score of 0.5608
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 23), which had val score of 0.5283
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 24), which had val score of 0.5335
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 25), which had val score of 0.566
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 26), which had val score of 0.5639
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 27), which had val score of 0.566
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 28), which had val score of 0.5451
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 29), which had val score of 0.588
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 30), which had val score of 0.5472
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 31), which had val score of 0.5367
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 32), which had val score of 0.5398
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 33), which had val score of 0.5597
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 34), which had val score of 0.5388
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 35), which had val score of 0.5639
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 1, 0, 12) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: activation (index: 3)
#
# Already Trained and Tested combination (0, 0, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 1, 12), which had val score of 0.5828
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 1, 0, 12) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_hidden_layers (index: 0)
#
# Already Trained and Tested combination (0, 0, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (1, 0, 1, 0, 12), which had val score of 0.5608
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (2, 0, 1, 0, 12), which had val score of 0.5723
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 12), which had val score of 0.5776
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 12), which had val score of 0.588
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 1, 0, 12) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: alpha (index: 1)
#
# Already Trained and Tested combination (0, 0, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 1, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 12), which had val score of 0.5975
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 12), which had val score of 0.5975
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 4, 1, 0, 12), which had val score of 0.5577
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 1, 0, 12) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate_init (index: 2)
#
# Already Trained and Tested combination (0, 0, 0, 0, 12), which had val score of 0.5639
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 12), which had val score of 0.6006
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 12), which had val score of 0.5765
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 12), which had val score of 0.5671
#         Current best combo: (0, 0, 1, 0, 12) with val score 0.6006.
#         Has trained 88 of 7200 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 1, 0, 12) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.600629
# Max Test Score:
#  0.600629
# Max Combo Index:
#  (0, 0, 1, 0, 12) out of [5, 5, 4, 2, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 1, 'alpha': 1e-08, 'learning_rate_init': 0.001, 'activation': 'logistic', 'features': 12}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances')
# % Combos Checked: 88 out of 7200 which is 1.2222220000000001%

# %%
jiaocheng.view_best_combo_and_score()
# Out:
# Max Score:
#  0.600629
# Max Test Score:
#  0.600629
# Max Combo Index:
#  (0, 0, 1, 0, 12) out of [5, 5, 4, 2, 36] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 1, 'alpha': 1e-08, 'learning_rate_init': 0.001, 'activation': 'logistic', 'features': 12}
# Max Combo Features:
#  ('AFLCA_votes', 'Disposals', 'Contested Possessions', 'Goals', 'Centre Clearances', 'Intercepts', 'Clearances', 'Marks Inside 50', 'Hitouts', 'Handballs', 'Behinds', 'Contested Marks', 'Bounces', 'Ineffective Disposals', 'Stoppage Clearances')
# % Combos Checked: 88 out of 7200 which is 1.2222220000000001%
