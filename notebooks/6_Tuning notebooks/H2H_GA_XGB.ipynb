# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'XGB'
TUNING_MODEL = 'guangan'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import GuangAn_H2H

# %%
guangan = GuangAn_H2H.GuangAn()
# Out:
# GuangAn Initialised

# %%
from xgboost import XGBRegressor as XGB

# %%
guangan.read_in_model(XGB, 'Regression')
# Out:
# Successfully read in model <class 'xgboost.sklearn.XGBRegressor'>, which is a Regression model

# %%
guangan.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': set(range(25, 201)),
    'max_depth': set(range(3, 97)),
    'subsample': (0.4, 0.85),
    'colsample_bytree': (0.4, 0.85),
    'gamma': (-8, -1),
    'eta': (-4, 1)
}

# %%
guangan.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
guangan.read_in_transform({'eta': '10^', 'gamma': '10^'})
# Out:
# Updated transform dictionary: {'n_estimators': False, 'max_depth': False, 'subsample': False, 'colsample_bytree': False, 'gamma': '10^', 'eta': '10^'}

# %%
guangan.set_non_tuneable_hyperparameters({'random_state': 19260817})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
guangan.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  guangan.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv', f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 3050 rows
# True

# %%
guangan.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
guangan.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
guangan.train_other_info = train_other_info
guangan.val_other_info = val_other_info
guangan.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
guangan.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5723
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5556
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5723
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5765
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5765
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5482
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5692
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5545
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5702
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5503
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5723
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5451
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5723
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5692
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5723
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5692
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5587
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5755
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5587
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5535
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5577
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5535
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5577
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5964
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.608
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.6038
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.6122
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.586
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5797
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5881
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5975
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5975
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.586
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5996
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5786
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.608
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5744
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.609
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5881
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.6006
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5975
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.6059
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5975
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5996
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.6048
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5954
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5744
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.6101
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5933
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.6027
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5755
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 35}, which had val score of 0.5776
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5828
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5964
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 69, 'max_depth': 73, 'subsample': 0.7375, 'colsample_bytree': 0.7375, 'gamma': -6.25, 'eta': -2.75, 'features': 27}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Pred centre score: 0.3901759415089208
# Actual centre score: 0.2117400419287212
#
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 0}, which had val score of 0.566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5556
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': 1, 'features': 0}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': 1, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 0}, which had val score of 0.566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5556
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': 1, 'features': 0}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': 1, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 0}, which had val score of 0.5702
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': 1, 'features': 0}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -8, 'eta': 1, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 0}, which had val score of 0.5702
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': 1, 'features': 0}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.85, 'gamma': -4.5, 'eta': 1, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 0}, which had val score of 0.566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': -1.5, 'features': 18}, which had val score of 0.5566
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# Already Trained and Tested combination {'n_estimators': 25, 'max_depth': 50, 'subsample': 0.85, 'colsample_bytree': 0.625, 'gamma': -8, 'eta': 1, 'features': 0}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3050 combinations so far
# ...
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 113, 'max_depth': 50, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -1.5, 'features': 35}, which had val score of 0.6069
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5818
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5807
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -1.5, 'features': 18}, which had val score of 0.5818
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -1.5, 'features': 35}, which had val score of 0.5807
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5723
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -1.5, 'features': 18}, which had val score of 0.5723
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -1.5, 'features': 35}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5734
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -1.5, 'features': 18}, which had val score of 0.5734
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -1.5, 'features': 35}, which had val score of 0.5671
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5692
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5692
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -1.5, 'features': 18}, which had val score of 0.5692
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.625, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -1.5, 'features': 35}, which had val score of 0.5692
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5744
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.5797
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3051 combinations so far
# Trained and Tested combination 3052: {'n_estimators': [200], 'max_depth': [50], 'subsample': [0.4], 'colsample_bytree': [0.4], 'gamma': [0.1], 'eta': [0.0001], 'features': [35]}, taking 1150.08 seconds to get val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': -1, 'eta': -1.5, 'features': 18}, which had val score of 0.5577
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3052 combinations so far
# Trained and Tested combination 3053: {'n_estimators': [200], 'max_depth': [50], 'subsample': [0.4], 'colsample_bytree': [0.4], 'gamma': [0.1], 'eta': [0.03162277660168379], 'features': [35]}, taking 1566.71 seconds to get val score of 0.5776
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3053 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -4, 'features': 35}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3053 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 18}, which had val score of 0.5786
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3053 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -4.5, 'eta': -1.5, 'features': 35}, which had val score of 0.6017
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3053 combinations so far
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -4, 'features': 18}, which had val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3053 combinations so far
# Trained and Tested combination 3054: {'n_estimators': [200], 'max_depth': [50], 'subsample': [0.4], 'colsample_bytree': [0.625], 'gamma': [0.1], 'eta': [0.0001], 'features': [35]}, taking 1665.29 seconds to get val score of 0.2117
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237
# Already Trained and Tested combination {'n_estimators': 200, 'max_depth': 50, 'subsample': 0.4, 'colsample_bytree': 0.625, 'gamma': -1, 'eta': -1.5, 'features': 18}, which had val score of 0.5786
#         Current best combo: (113, 50, 0.85, 0.85, -1, -1.5, 35) with val score 0.6237.
#         Has trained 3054 combinations so far

# %%
guangan.view_best_combo_and_score()
