# %% [markdown]
# # 6. Tuning

# %%
MODEL = 'CBR'
TUNING_MODEL = 'guangan'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
py_file_location = "./drive/My Drive/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

py_file_location = "./drive/My Drive/LAB/BrownlowH2H/PrivatePackages"
sys.path.append(os.path.abspath(py_file_location))

import NingXiang

import pandas as pd

# %%
ningxiang = NingXiang.NingXiang()
# Out:
# NingXiang Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/train_data.parquet')
val_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/val_data.parquet')
test_data = pd.read_parquet('./drive/My Drive/LAB/BrownlowH2H/data/curated/modelling/test_data.parquet')

# %%
train_other_info = train_data[['game_id', 'player1', 'player2']]
val_other_info = val_data[['game_id', 'player1', 'player2']]
test_other_info = test_data[['game_id', 'player1', 'player2']]

# %%
train_x = train_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
train_y = train_data['Brownlow Votes']
val_x = val_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
val_y = val_data['Brownlow Votes']
test_x = test_data.drop(['game_id', 'player1', 'player2', 'Brownlow Votes'], axis=1)
test_y = test_data['Brownlow Votes']

# %%
# ningxiang.read_in_train_data(train_x, train_y)
# ningxiang.set_model_type("Regression")
# ningxiang_output = ningxiang.get_rf_based_feature_combinations(3)

# with open(f'./drive/My Drive/LAB/BrownlowH2H/models/NingXing_output.pickle', 'rb') as f:
#     ningxiang_output = pickle.load(f)

# %%
with open('./drive/My Drive/LAB/BrownlowH2H/models/H2H_NingXiang.pickle', 'rb') as f:
  ningxiang_output = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
import GuangAn_H2H

# %%
guangan = GuangAn_H2H.GuangAn()
# Out:
# GuangAn Initialised

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.1.1-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.1.1

# %%
from catboost import CatBoostRegressor as CBR

# %%
guangan.read_in_model(CBR, 'Regression')
# Out:
# Successfully read in model <class 'catboost.core.CatBoostRegressor'>, which is a Regression model

# %%
guangan.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %%
parameter_choices = {
    'n_estimators': set(range(25, 401)),
    'max_depth': set(range(2, 17)),
    'subsample': (0.5, 0.85),
    'colsample_bylevel': (0.5, 0.85),
    'max_bin': set(range(64, 256)),
    'reg_lambda': (-4, 0),
    'learning_rate': (-4, 0),

}

# %%
guangan.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded hyperparameter choices

# %%
guangan.read_in_transform({'learning_rate': '10^', 'reg_lambda': '10^'})
# Out:
# Updated transform dictionary: {'n_estimators': False, 'max_depth': False, 'subsample': False, 'colsample_bylevel': False, 'max_bin': False, 'reg_lambda': '10^', 'learning_rate': '10^'}

# %%
guangan.set_non_tuneable_hyperparameters({'random_state': 19260817, 'verbose': False})
# Out:
# Successfully recorded non_tuneable_hyperparameter choices

# %%
guangan.set_features(ningxiang_output)
# Out:
# Successfully recorded tuneable feature combination choices and updated relevant internal structures

# %%
try:
  guangan.read_in_tuning_result_df(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv', f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
  print('True')
except:
  print('False')
# Out:
# Successfully read in tuning result of 10857 rows
# True

# %%
guangan.set_tuning_result_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tuning/{TUNING_MODEL}_BrownlowH2H_{MODEL}.csv')
# Out:
# Successfully set tuning output address

# %%
guangan.set_best_model_saving_address(f'./drive/My Drive/LAB/BrownlowH2H/models/tmp_models/{TUNING_MODEL}_BrownlowH2H_{MODEL}.pickle')
# Out:
# Successfully set best model output address

# %%
guangan.train_other_info = train_other_info
guangan.val_other_info = val_other_info
guangan.test_other_info = test_other_info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
guangan.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination {'n_estimators': 307, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5797
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 260, 'max_depth': 15, 'subsample': 0.71875, 'colsample_bylevel': 0.6312500000000001, 'max_bin': 136, 'reg_lambda': -2.5, 'learning_rate': -0.5, 'features': 23}, which had val score of 0.5755
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Pred centre score: 0.5687717365939685
# Actual centre score: 0.5754716981132074
#
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5943
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5901
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5126
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5335
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5807
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.587
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5168
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5419
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6143
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.609
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5073
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5545
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6038
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5901
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.4969
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5388
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5839
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5922
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5535
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5126
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.587
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5912
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5451
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.543
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6069
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5891
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.522
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5545
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5818
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5933
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5063
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5713
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5891
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5839
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5294
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5639
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5996
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5996
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5157
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5409
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5933
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6038
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5472
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5189
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5535
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5891
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.566
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5419
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5828
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.586
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5618
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5692
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5901
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6017
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5367
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5157
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5828
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6132
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5472
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5577
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5985
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5891
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5367
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 13, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5377
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5996
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5943
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5157
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5461
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6048
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6059
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5346
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5734
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5776
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.609
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5493
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5639
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6006
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6006
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5744
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.6027
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5702
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.587
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5849
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5755
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5755
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5933
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5231
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.521
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5881
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5797
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5377
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5744
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5985
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6006
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5335
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.675, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5818
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5975
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5996
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5786
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5681
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5964
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.587
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5681
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5881
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5996
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6069
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5503
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5451
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5765
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6048
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.543
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5723
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5776
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6195
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5566
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.5618
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5996
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.586
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5304
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.521
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6132
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5922
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 27}, which had val score of 0.5346
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -3.0, 'learning_rate': 0.0, 'features': 35}, which had val score of 0.565
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.675, 'max_bin': 160, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5776
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10857 combinations so far
# ...
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5901
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5776
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 35}, which had val score of 0.5797
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.609
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.6069
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5755
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 35}, which had val score of 0.5839
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5975
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5996
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5776
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 35}, which had val score of 0.5786
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5964
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.7625, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.587
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5702
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 35}, which had val score of 0.5818
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5954
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.586
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5797
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 35}, which had val score of 0.5807
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6048
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10880 combinations so far
# Trained and Tested combination 10881: {'n_estimators': [213], 'max_depth': [16], 'subsample': [0.85], 'colsample_bylevel': [0.5], 'max_bin': [64], 'reg_lambda': [0.01], 'learning_rate': [0.1], 'features': [35]}, taking 220.35 seconds to get val score of 0.6027
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5765
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10881 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 35}, which had val score of 0.5839
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10881 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5933
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10881 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5723
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10881 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5797
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10881 combinations so far
# Trained and Tested combination 10882: {'n_estimators': [213], 'max_depth': [16], 'subsample': [0.85], 'colsample_bylevel': [0.5], 'max_bin': [112], 'reg_lambda': [0.01], 'learning_rate': [0.01], 'features': [35]}, taking 238.14 seconds to get val score of 0.5765
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.5954
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10882 combinations so far
# Trained and Tested combination 10883: {'n_estimators': [213], 'max_depth': [16], 'subsample': [0.85], 'colsample_bylevel': [0.5], 'max_bin': [112], 'reg_lambda': [0.01], 'learning_rate': [0.1], 'features': [35]}, taking 240.27 seconds to get val score of 0.6059
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5797
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10883 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 35}, which had val score of 0.5807
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10883 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6048
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10883 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5881
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10883 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5807
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10883 combinations so far
# Trained and Tested combination 10884: {'n_estimators': [213], 'max_depth': [16], 'subsample': [0.85], 'colsample_bylevel': [0.5875], 'max_bin': [64], 'reg_lambda': [0.01], 'learning_rate': [0.01], 'features': [35]}, taking 249.21 seconds to get val score of 0.5849
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 64, 'reg_lambda': -2.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.608
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10884 combinations so far
# Trained and Tested combination 10885: {'n_estimators': [213], 'max_depth': [16], 'subsample': [0.85], 'colsample_bylevel': [0.5875], 'max_bin': [64], 'reg_lambda': [0.01], 'learning_rate': [0.1], 'features': [35]}, taking 253.68 seconds to get val score of 0.5943
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5933
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10885 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -2.0, 'features': 35}, which had val score of 0.5849
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10885 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 27}, which had val score of 0.6069
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10885 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -3.0, 'learning_rate': -1.0, 'features': 35}, which had val score of 0.5912
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10885 combinations so far
# Already Trained and Tested combination {'n_estimators': 213, 'max_depth': 16, 'subsample': 0.85, 'colsample_bylevel': 0.5875, 'max_bin': 112, 'reg_lambda': -2.0, 'learning_rate': -2.0, 'features': 27}, which had val score of 0.5702
#         Current best combo: (307, 13, 0.675, 0.5875, 160, -4.0, -1.0, 27) with val score 0.6289.
#         Has trained 10885 combinations so far

# %%
guangan.view_best_combo_and_score()
